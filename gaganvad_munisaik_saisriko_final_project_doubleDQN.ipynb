# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import gym
import os
import cityflow
import gym_cityflow
import random

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cpu

# %%
class DQN_network(nn.Module):
    def __init__(self, input_dim, action_dim, hidden_dims=[128, 256, 128]):
        super(DQN_network, self).__init__()

        self.fc1 = nn.Linear(input_dim, hidden_dims[0])
        self.norm1 = nn.LayerNorm(hidden_dims[0])

        self.fc2 = nn.Linear(hidden_dims[0], hidden_dims[1])
        self.norm2 = nn.LayerNorm(hidden_dims[1])

        self.fc3 = nn.Linear(hidden_dims[1], hidden_dims[2])
        self.norm3 = nn.LayerNorm(hidden_dims[2])

        self.out = nn.Linear(hidden_dims[2], action_dim)

    def forward(self, x):
        x = F.relu(self.norm1(self.fc1(x)))
        x = F.relu(self.norm2(self.fc2(x)))
        x = F.relu(self.norm3(self.fc3(x)))
        q_values = self.out(x)
        return q_values

# %%
class MultiAgentReplayBuffer:
    def __init__(self, max_size, num_agents, obs_dim):
        self.max_size = max_size
        self.num_agents = num_agents
        self.obs_dim = obs_dim
        self.idx = 0
        self.size = 0
        self.states      = np.zeros((max_size, num_agents, obs_dim), dtype=np.float32)
        self.next_states = np.zeros((max_size, num_agents, obs_dim), dtype=np.float32)
        self.actions     = np.zeros((max_size, num_agents), dtype=np.int64)
        self.rewards     = np.zeros((max_size, num_agents), dtype=np.float32)
        self.dones       = np.zeros(max_size, dtype=np.float32)

    def store(self, states, actions, next_states, rewards, done):
        self.states[self.idx]      = states
        self.next_states[self.idx] = next_states
        self.actions[self.idx]     = actions
        self.rewards[self.idx]     = rewards
        self.dones[self.idx]       = done
        self.idx = (self.idx + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)

    def sample(self, batch_size):
        idxs = np.random.randint(0, self.size, size=batch_size)
        return (
            self.states[idxs],
            self.actions[idxs],
            self.rewards[idxs],
            self.next_states[idxs],
            self.dones[idxs]
        )

    def __len__(self):
        return self.size

# %%
class DQNAgentManager:
    def __init__(
        self,
        obs_dim,
        action_dim,
        num_agents,
        buffer_size=15000,
        batch_size=128,
        train_freq=4,
        target_update_freq=8,
        lr=1e-4,
        gamma=0.8,
        epsilon_start=1.0,
        epsilon_min=0.25,
        epsilon_decay= None,
        reward_norm_momentum=1e-3,
        reward_norm_eps=1e-8,
        max_grad_norm=1.0
    ):
        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.num_agents = num_agents
        self.batch_size = batch_size
        self.train_freq = train_freq
        self.target_update_freq = target_update_freq
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.r_mean     = 0.0
        self.r_var      = 1.0
        self.r_momentum = reward_norm_momentum
        self.r_eps      = reward_norm_eps
        self.max_grad_norm = max_grad_norm
        self.q_net = DQN_network(obs_dim, action_dim).to(device)
        self.target_net = DQN_network(obs_dim, action_dim).to(device)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.q_net.parameters(), lr=lr)
        self.replay_buffer = MultiAgentReplayBuffer(buffer_size, num_agents, obs_dim)

        self.step_count = 0

    def select_actions(self, obs_batch):
        actions = []
        for obs in obs_batch:
            if np.random.rand() < self.epsilon:
                actions.append(np.random.randint(self.action_dim))
            else:
                with torch.no_grad():
                    obs_t = torch.tensor(obs, dtype=torch.float32, device=device).unsqueeze(0)
                    q = self.q_net(obs_t)
                    actions.append(q.argmax().item())
        return actions

    def store_transition(self, states, actions, next_states, rewards, done):
        raw = np.array(rewards, dtype=np.float32).flatten()
        batch_mean = raw.mean()
        batch_var  = raw.var()
        delta = batch_mean - self.r_mean
        self.r_mean += self.r_momentum * delta
        self.r_var  += self.r_momentum * (batch_var - self.r_var)

        normed = (raw - self.r_mean) / (np.sqrt(self.r_var) + self.r_eps)
        normed = normed.reshape(len(rewards))
        self.replay_buffer.store(states, actions, next_states, normed, done)

    def step(self):
        self.step_count += 1
        if len(self.replay_buffer) >= self.batch_size and self.step_count % self.train_freq == 0:
            self._learn()
        if self.step_count % self.target_update_freq == 0:
            self.target_net.load_state_dict(self.q_net.state_dict())

    def end_episode(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def _learn(self):
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
        bs, na, od = states.shape

        s = torch.FloatTensor(states.reshape(bs*na, od)).to(device)
        a  = torch.LongTensor(actions.reshape(bs*na, 1)).to(device)
        r  = torch.FloatTensor(rewards.reshape(bs*na, 1)).to(device)
        s2 = torch.FloatTensor(next_states.reshape(bs*na, od)).to(device)
        d  = torch.FloatTensor(dones.repeat(na).reshape(bs*na, 1)).to(device)

        q_vals = self.q_net(s).gather(1, a)
        with torch.no_grad():
            best_next_actions = self.q_net(s2).argmax(dim=1, keepdim=True)
            q_target_next     = self.target_net(s2).gather(1, best_next_actions)
            target = r + self.gamma * q_target_next * (1 - d)

        loss = F.mse_loss(q_vals, target)
        self.optimizer.zero_grad()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(self.q_net.parameters(), self.max_grad_norm)
        self.optimizer.step()

# %%
def train_multi_dqn(
    config_path,
    num_agents=16,
    obs_dim=72,
    action_dim=9,
    num_episodes=500,
    max_steps_per_episode=1000,
    buffer_size=15000,
    batch_size=128,
    train_freq=4,
    target_update_freq=8,
    gamma=0.85,
    lr=1e-4,
    epsilon_start=1.0,
    epsilon_min=0.25,
    epsilon_decay=None,
    checkpoint_interval=250, 
    checkpoint_dir="checkpoints"
):
    os.makedirs(checkpoint_dir, exist_ok=True)
    env = gym.make(
        id='cityflow-v0',
        configPath=config_path,
        episodeSteps=max_steps_per_episode
    )
    raw_obs = env.reset()
    intersection_ids = sorted(raw_obs.keys())
    assert len(intersection_ids) == num_agents, (
        f"Expected {num_agents} intersections, but config has {len(intersection_ids)}"
    )

    epsilon_decay = (epsilon_min / epsilon_start) ** (1.0 / num_episodes)

    agent_mgr = DQNAgentManager(
        obs_dim=obs_dim,
        action_dim=action_dim,
        num_agents=num_agents,
        buffer_size=buffer_size,
        batch_size=batch_size,
        train_freq=train_freq,
        target_update_freq=target_update_freq,
        lr=lr,
        gamma=gamma,
        epsilon_start=epsilon_start,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay
    )

    rewards_history = []

    for ep in range(1, num_episodes + 1):
        seed_val = np.random.randint(0, 1_000_000)
        env.seed(seed_val)
        raw_obs = env.reset()
        obs = [np.array(raw_obs[k], dtype=np.float32).flatten() for k in intersection_ids]
        total_reward = 0

        for t in range(max_steps_per_episode):
            actions = agent_mgr.select_actions(obs)
            next_raw_obs, rewards, done, _ = env.step(actions)
            next_obs = [np.array(next_raw_obs[k], dtype=np.float32).flatten() for k in intersection_ids]
            reward_dict   = {key: val for key, val in rewards}
            rewards_list  = [reward_dict[k] for k in intersection_ids]
            assert len(rewards_list) == num_agents
            total_reward += sum(rewards_list)

            agent_mgr.store_transition(obs, actions, next_obs, rewards_list, done)
            agent_mgr.step()

            obs = next_obs
            if done:
                break

        agent_mgr.end_episode()
        rewards_history.append(total_reward)
        print(f"Episode {ep:4d} | Steps {t:3d} | Reward {total_reward:.1f} | Epsilon {agent_mgr.epsilon:.3f}")

        if ep % checkpoint_interval == 0:
            ckpt_path = os.path.join(checkpoint_dir, f"qnet_double_dqn_ep{ep}.pth")
            torch.save(agent_mgr.q_net.state_dict(), ckpt_path)
            print(f"Checkpoint SAVED")

    final_path = os.path.join(checkpoint_dir, "qnet_double_dqn_final.pth")
    torch.save(agent_mgr.q_net.state_dict(), final_path)
    print(f"Model saved to {final_path}")

    plt.plot(rewards_history)
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Multi-Agent DQN Training")
    plt.show()

    env.close()

# %%
train_multi_dqn("Intersections_4/sample_config.json")
# Out:
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:146: UserWarning: WARN: The obs returned by the `step()` method was expecting a numpy array, actual type: <class 'list'>
#   logger.warn(f"{pre} was expecting a numpy array, actual type: {type(obs)}")
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:252: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'list'>
#   logger.warn(
# Episode    1 | Steps 998 | Reward -5370894.0 | Epsilon 0.997
# Episode    2 | Steps 998 | Reward -5689188.0 | Epsilon 0.994
# Episode    3 | Steps 998 | Reward -5307324.0 | Epsilon 0.992
# Episode    4 | Steps 998 | Reward -5352567.0 | Epsilon 0.989
# Episode    5 | Steps 998 | Reward -5117184.0 | Epsilon 0.986
# Episode    6 | Steps 998 | Reward -4762629.0 | Epsilon 0.984
# Episode    7 | Steps 998 | Reward -5182659.0 | Epsilon 0.981
# Episode    8 | Steps 998 | Reward -4388202.0 | Epsilon 0.978
# Episode    9 | Steps 998 | Reward -4949265.0 | Epsilon 0.975
# Episode   10 | Steps 998 | Reward -4800810.0 | Epsilon 0.973
# Episode   11 | Steps 998 | Reward -4324512.0 | Epsilon 0.970
# Episode   12 | Steps 998 | Reward -4499895.0 | Epsilon 0.967
# Episode   13 | Steps 998 | Reward -3838419.0 | Epsilon 0.965
# Episode   14 | Steps 998 | Reward -4413531.0 | Epsilon 0.962
# Episode   15 | Steps 998 | Reward -4324314.0 | Epsilon 0.959
# Episode   16 | Steps 998 | Reward -3696837.0 | Epsilon 0.957
# Episode   17 | Steps 998 | Reward -4211664.0 | Epsilon 0.954
# Episode   18 | Steps 998 | Reward -4086099.0 | Epsilon 0.951
# Episode   19 | Steps 998 | Reward -4336824.0 | Epsilon 0.949
# Episode   20 | Steps 998 | Reward -4005885.0 | Epsilon 0.946
# Episode   21 | Steps 998 | Reward -3779157.0 | Epsilon 0.943
# Episode   22 | Steps 998 | Reward -3787437.0 | Epsilon 0.941
# Episode   23 | Steps 998 | Reward -4375929.0 | Epsilon 0.938
# Episode   24 | Steps 998 | Reward -4363830.0 | Epsilon 0.936
# Episode   25 | Steps 998 | Reward -3734265.0 | Epsilon 0.933
# Episode   26 | Steps 998 | Reward -3221904.0 | Epsilon 0.930
# Episode   27 | Steps 998 | Reward -3745014.0 | Epsilon 0.928
# Episode   28 | Steps 998 | Reward -3672528.0 | Epsilon 0.925
# Episode   29 | Steps 998 | Reward -3610332.0 | Epsilon 0.923
# Episode   30 | Steps 998 | Reward -3609063.0 | Epsilon 0.920
# Episode   31 | Steps 998 | Reward -3586929.0 | Epsilon 0.918
# Episode   32 | Steps 998 | Reward -3668985.0 | Epsilon 0.915
# Episode   33 | Steps 998 | Reward -3319590.0 | Epsilon 0.913
# Episode   34 | Steps 998 | Reward -3562002.0 | Epsilon 0.910
# Episode   35 | Steps 998 | Reward -3549699.0 | Epsilon 0.908
# Episode   36 | Steps 998 | Reward -3408270.0 | Epsilon 0.905
# Episode   37 | Steps 998 | Reward -3357735.0 | Epsilon 0.903
# Episode   38 | Steps 998 | Reward -3312087.0 | Epsilon 0.900
# Episode   39 | Steps 998 | Reward -3387813.0 | Epsilon 0.898
# Episode   40 | Steps 998 | Reward -3069387.0 | Epsilon 0.895
# Episode   41 | Steps 998 | Reward -3102477.0 | Epsilon 0.893
# Episode   42 | Steps 998 | Reward -3229692.0 | Epsilon 0.890
# Episode   43 | Steps 998 | Reward -3098229.0 | Epsilon 0.888
# Episode   44 | Steps 998 | Reward -2785257.0 | Epsilon 0.885
# Episode   45 | Steps 998 | Reward -3009375.0 | Epsilon 0.883
# Episode   46 | Steps 998 | Reward -3199809.0 | Epsilon 0.880
# Episode   47 | Steps 998 | Reward -3228435.0 | Epsilon 0.878
# Episode   48 | Steps 998 | Reward -2616231.0 | Epsilon 0.875
# Episode   49 | Steps 998 | Reward -2848002.0 | Epsilon 0.873
# Episode   50 | Steps 998 | Reward -2754426.0 | Epsilon 0.871
# Episode   51 | Steps 998 | Reward -2898465.0 | Epsilon 0.868
# Episode   52 | Steps 998 | Reward -2729295.0 | Epsilon 0.866
# Episode   53 | Steps 998 | Reward -3092154.0 | Epsilon 0.863
# Episode   54 | Steps 998 | Reward -2821422.0 | Epsilon 0.861
# Episode   55 | Steps 998 | Reward -2723724.0 | Epsilon 0.859
# Episode   56 | Steps 998 | Reward -2606814.0 | Epsilon 0.856
# Episode   57 | Steps 998 | Reward -2677329.0 | Epsilon 0.854
# Episode   58 | Steps 998 | Reward -2748432.0 | Epsilon 0.851
# Episode   59 | Steps 998 | Reward -2766135.0 | Epsilon 0.849
# Episode   60 | Steps 998 | Reward -2703330.0 | Epsilon 0.847
# Episode   61 | Steps 998 | Reward -2588874.0 | Epsilon 0.844
# Episode   62 | Steps 998 | Reward -2623464.0 | Epsilon 0.842
# Episode   63 | Steps 998 | Reward -2588205.0 | Epsilon 0.840
# Episode   64 | Steps 998 | Reward -2739255.0 | Epsilon 0.837
# Episode   65 | Steps 998 | Reward -2649099.0 | Epsilon 0.835
# Episode   66 | Steps 998 | Reward -2816502.0 | Epsilon 0.833
# Episode   67 | Steps 998 | Reward -2487999.0 | Epsilon 0.830
# Episode   68 | Steps 998 | Reward -2410554.0 | Epsilon 0.828
# Episode   69 | Steps 998 | Reward -2575806.0 | Epsilon 0.826
# Episode   70 | Steps 998 | Reward -2237124.0 | Epsilon 0.824
# Episode   71 | Steps 998 | Reward -2414088.0 | Epsilon 0.821
# Episode   72 | Steps 998 | Reward -2427243.0 | Epsilon 0.819
# Episode   73 | Steps 998 | Reward -2157342.0 | Epsilon 0.817
# Episode   74 | Steps 998 | Reward -2214840.0 | Epsilon 0.815
# Episode   75 | Steps 998 | Reward -2393367.0 | Epsilon 0.812
# Episode   76 | Steps 998 | Reward -2528157.0 | Epsilon 0.810
# Episode   77 | Steps 998 | Reward -2331429.0 | Epsilon 0.808
# Episode   78 | Steps 998 | Reward -2161530.0 | Epsilon 0.806
# Episode   79 | Steps 998 | Reward -2378493.0 | Epsilon 0.803
# Episode   80 | Steps 998 | Reward -2116272.0 | Epsilon 0.801
# Episode   81 | Steps 998 | Reward -2146278.0 | Epsilon 0.799
# Episode   82 | Steps 998 | Reward -2218677.0 | Epsilon 0.797
# Episode   83 | Steps 998 | Reward -2468148.0 | Epsilon 0.794
# Episode   84 | Steps 998 | Reward -2239221.0 | Epsilon 0.792
# Episode   85 | Steps 998 | Reward -2228718.0 | Epsilon 0.790
# Episode   86 | Steps 998 | Reward -1989390.0 | Epsilon 0.788
# Episode   87 | Steps 998 | Reward -1973067.0 | Epsilon 0.786
# Episode   88 | Steps 998 | Reward -2250096.0 | Epsilon 0.783
# Episode   89 | Steps 998 | Reward -2309985.0 | Epsilon 0.781
# Episode   90 | Steps 998 | Reward -1817157.0 | Epsilon 0.779
# Episode   91 | Steps 998 | Reward -2047131.0 | Epsilon 0.777
# Episode   92 | Steps 998 | Reward -2154297.0 | Epsilon 0.775
# Episode   93 | Steps 998 | Reward -1753497.0 | Epsilon 0.773
# Episode   94 | Steps 998 | Reward -2223462.0 | Epsilon 0.771
# Episode   95 | Steps 998 | Reward -1873872.0 | Epsilon 0.768
# Episode   96 | Steps 998 | Reward -2251983.0 | Epsilon 0.766
# Episode   97 | Steps 998 | Reward -2131314.0 | Epsilon 0.764
# Episode   98 | Steps 998 | Reward -1941120.0 | Epsilon 0.762
# Episode   99 | Steps 998 | Reward -2186667.0 | Epsilon 0.760
# Episode  100 | Steps 998 | Reward -2321862.0 | Epsilon 0.758
# Episode  101 | Steps 998 | Reward -1980969.0 | Epsilon 0.756
# Episode  102 | Steps 998 | Reward -2179473.0 | Epsilon 0.754
# Episode  103 | Steps 998 | Reward -1794543.0 | Epsilon 0.752
# Episode  104 | Steps 998 | Reward -2010852.0 | Epsilon 0.749
# Episode  105 | Steps 998 | Reward -1617759.0 | Epsilon 0.747
# Episode  106 | Steps 998 | Reward -1771116.0 | Epsilon 0.745
# Episode  107 | Steps 998 | Reward -1813701.0 | Epsilon 0.743
# Episode  108 | Steps 998 | Reward -1899087.0 | Epsilon 0.741
# Episode  109 | Steps 998 | Reward -2138604.0 | Epsilon 0.739
# Episode  110 | Steps 998 | Reward -1853106.0 | Epsilon 0.737
# Episode  111 | Steps 998 | Reward -1970346.0 | Epsilon 0.735
# Episode  112 | Steps 998 | Reward -1630920.0 | Epsilon 0.733
# Episode  113 | Steps 998 | Reward -1785960.0 | Epsilon 0.731
# Episode  114 | Steps 998 | Reward -1911918.0 | Epsilon 0.729
# Episode  115 | Steps 998 | Reward -1939677.0 | Epsilon 0.727
# Episode  116 | Steps 998 | Reward -1567851.0 | Epsilon 0.725
# Episode  117 | Steps 998 | Reward -2004921.0 | Epsilon 0.723
# Episode  118 | Steps 998 | Reward -1756104.0 | Epsilon 0.721
# Episode  119 | Steps 998 | Reward -1964085.0 | Epsilon 0.719
# Episode  120 | Steps 998 | Reward -1497450.0 | Epsilon 0.717
# Episode  121 | Steps 998 | Reward -1705005.0 | Epsilon 0.715
# Episode  122 | Steps 998 | Reward -1974720.0 | Epsilon 0.713
# Episode  123 | Steps 998 | Reward -1676214.0 | Epsilon 0.711
# Episode  124 | Steps 998 | Reward -1520922.0 | Epsilon 0.709
# Episode  125 | Steps 998 | Reward -1744782.0 | Epsilon 0.707
# Episode  126 | Steps 998 | Reward -1589688.0 | Epsilon 0.705
# Episode  127 | Steps 998 | Reward -1731591.0 | Epsilon 0.703
# Episode  128 | Steps 998 | Reward -1788495.0 | Epsilon 0.701
# Episode  129 | Steps 998 | Reward -1634325.0 | Epsilon 0.699
# Episode  130 | Steps 998 | Reward -1714740.0 | Epsilon 0.697
# Episode  131 | Steps 998 | Reward -1766787.0 | Epsilon 0.695
# Episode  132 | Steps 998 | Reward -1565253.0 | Epsilon 0.694
# Episode  133 | Steps 998 | Reward -1811568.0 | Epsilon 0.692
# Episode  134 | Steps 998 | Reward -1718667.0 | Epsilon 0.690
# Episode  135 | Steps 998 | Reward -1650081.0 | Epsilon 0.688
# Episode  136 | Steps 998 | Reward -1803135.0 | Epsilon 0.686
# Episode  137 | Steps 998 | Reward -1813878.0 | Epsilon 0.684
# Episode  138 | Steps 998 | Reward -1508232.0 | Epsilon 0.682
# Episode  139 | Steps 998 | Reward -1424814.0 | Epsilon 0.680
# Episode  140 | Steps 998 | Reward -1420194.0 | Epsilon 0.678
# Episode  141 | Steps 998 | Reward -1520964.0 | Epsilon 0.676
# Episode  142 | Steps 998 | Reward -1476015.0 | Epsilon 0.675
# Episode  143 | Steps 998 | Reward -1517466.0 | Epsilon 0.673
# Episode  144 | Steps 998 | Reward -1725399.0 | Epsilon 0.671
# Episode  145 | Steps 998 | Reward -1354071.0 | Epsilon 0.669
# Episode  146 | Steps 998 | Reward -1692351.0 | Epsilon 0.667
# Episode  147 | Steps 998 | Reward -1513104.0 | Epsilon 0.665
# Episode  148 | Steps 998 | Reward -1532781.0 | Epsilon 0.663
# Episode  149 | Steps 998 | Reward -1508910.0 | Epsilon 0.662
# Episode  150 | Steps 998 | Reward -1804518.0 | Epsilon 0.660
# Episode  151 | Steps 998 | Reward -1645482.0 | Epsilon 0.658
# Episode  152 | Steps 998 | Reward -1973832.0 | Epsilon 0.656
# Episode  153 | Steps 998 | Reward -1390110.0 | Epsilon 0.654
# Episode  154 | Steps 998 | Reward -1510755.0 | Epsilon 0.652
# Episode  155 | Steps 998 | Reward -1559559.0 | Epsilon 0.651
# Episode  156 | Steps 998 | Reward -1450338.0 | Epsilon 0.649
# Episode  157 | Steps 998 | Reward -1479972.0 | Epsilon 0.647
# Episode  158 | Steps 998 | Reward -1367967.0 | Epsilon 0.645
# Episode  159 | Steps 998 | Reward -1578675.0 | Epsilon 0.643
# Episode  160 | Steps 998 | Reward -1537443.0 | Epsilon 0.642
# Episode  161 | Steps 998 | Reward -1464315.0 | Epsilon 0.640
# Episode  162 | Steps 998 | Reward -1421217.0 | Epsilon 0.638
# Episode  163 | Steps 998 | Reward -1475637.0 | Epsilon 0.636
# Episode  164 | Steps 998 | Reward -1447302.0 | Epsilon 0.635
# Episode  165 | Steps 998 | Reward -1422762.0 | Epsilon 0.633
# Episode  166 | Steps 998 | Reward -1272816.0 | Epsilon 0.631
# Episode  167 | Steps 998 | Reward -1378059.0 | Epsilon 0.629
# Episode  168 | Steps 998 | Reward -1402641.0 | Epsilon 0.628
# Episode  169 | Steps 998 | Reward -1801986.0 | Epsilon 0.626
# Episode  170 | Steps 998 | Reward -1313430.0 | Epsilon 0.624
# Episode  171 | Steps 998 | Reward -1681161.0 | Epsilon 0.622
# Episode  172 | Steps 998 | Reward -1489248.0 | Epsilon 0.621
# Episode  173 | Steps 998 | Reward -1363194.0 | Epsilon 0.619
# Episode  174 | Steps 998 | Reward -1418010.0 | Epsilon 0.617
# Episode  175 | Steps 998 | Reward -1585938.0 | Epsilon 0.616
# Episode  176 | Steps 998 | Reward -1330065.0 | Epsilon 0.614
# Episode  177 | Steps 998 | Reward -1297569.0 | Epsilon 0.612
# Episode  178 | Steps 998 | Reward -1490169.0 | Epsilon 0.610
# Episode  179 | Steps 998 | Reward -1598190.0 | Epsilon 0.609
# Episode  180 | Steps 998 | Reward -1427388.0 | Epsilon 0.607
# Episode  181 | Steps 998 | Reward -1319313.0 | Epsilon 0.605
# Episode  182 | Steps 998 | Reward -1482453.0 | Epsilon 0.604
# Episode  183 | Steps 998 | Reward -1274682.0 | Epsilon 0.602
# Episode  184 | Steps 998 | Reward -1200159.0 | Epsilon 0.600
# Episode  185 | Steps 998 | Reward -1154514.0 | Epsilon 0.599
# Episode  186 | Steps 998 | Reward -1531656.0 | Epsilon 0.597
# Episode  187 | Steps 998 | Reward -1382364.0 | Epsilon 0.595
# Episode  188 | Steps 998 | Reward -1265379.0 | Epsilon 0.594
# Episode  189 | Steps 998 | Reward -1248246.0 | Epsilon 0.592
# Episode  190 | Steps 998 | Reward -1188030.0 | Epsilon 0.590
# Episode  191 | Steps 998 | Reward -1125189.0 | Epsilon 0.589
# Episode  192 | Steps 998 | Reward -1245324.0 | Epsilon 0.587
# Episode  193 | Steps 998 | Reward -1322517.0 | Epsilon 0.586
# Episode  194 | Steps 998 | Reward -1149267.0 | Epsilon 0.584
# Episode  195 | Steps 998 | Reward -1207788.0 | Epsilon 0.582
# Episode  196 | Steps 998 | Reward -1282392.0 | Epsilon 0.581
# Episode  197 | Steps 998 | Reward -1438158.0 | Epsilon 0.579
# Episode  198 | Steps 998 | Reward -1248447.0 | Epsilon 0.578
# Episode  199 | Steps 998 | Reward -1316793.0 | Epsilon 0.576
# Episode  200 | Steps 998 | Reward -1301169.0 | Epsilon 0.574
# Episode  201 | Steps 998 | Reward -1239714.0 | Epsilon 0.573
# Episode  202 | Steps 998 | Reward -1224453.0 | Epsilon 0.571
# Episode  203 | Steps 998 | Reward -1297638.0 | Epsilon 0.570
# Episode  204 | Steps 998 | Reward -1165320.0 | Epsilon 0.568
# Episode  205 | Steps 998 | Reward -1226736.0 | Epsilon 0.566
# Episode  206 | Steps 998 | Reward -1264026.0 | Epsilon 0.565
# Episode  207 | Steps 998 | Reward -1063053.0 | Epsilon 0.563
# Episode  208 | Steps 998 | Reward -1265922.0 | Epsilon 0.562
# Episode  209 | Steps 998 | Reward -1217427.0 | Epsilon 0.560
# Episode  210 | Steps 998 | Reward -1327596.0 | Epsilon 0.559
# Episode  211 | Steps 998 | Reward -1155639.0 | Epsilon 0.557
# Episode  212 | Steps 998 | Reward -1300596.0 | Epsilon 0.556
# Episode  213 | Steps 998 | Reward -1339824.0 | Epsilon 0.554
# Episode  214 | Steps 998 | Reward -1154442.0 | Epsilon 0.552
# Episode  215 | Steps 998 | Reward -1032885.0 | Epsilon 0.551
# Episode  216 | Steps 998 | Reward -1369776.0 | Epsilon 0.549
# Episode  217 | Steps 998 | Reward -1206816.0 | Epsilon 0.548
# Episode  218 | Steps 998 | Reward -1359072.0 | Epsilon 0.546
# Episode  219 | Steps 998 | Reward -1085268.0 | Epsilon 0.545
# Episode  220 | Steps 998 | Reward -1235691.0 | Epsilon 0.543
# Episode  221 | Steps 998 | Reward -1062444.0 | Epsilon 0.542
# Episode  222 | Steps 998 | Reward -1110030.0 | Epsilon 0.540
# Episode  223 | Steps 998 | Reward -1146267.0 | Epsilon 0.539
# Episode  224 | Steps 998 | Reward -1043982.0 | Epsilon 0.537
# Episode  225 | Steps 998 | Reward -1090884.0 | Epsilon 0.536
# Episode  226 | Steps 998 | Reward -1170786.0 | Epsilon 0.534
# Episode  227 | Steps 998 | Reward -1194003.0 | Epsilon 0.533
# Episode  228 | Steps 998 | Reward -1174935.0 | Epsilon 0.531
# Episode  229 | Steps 998 | Reward -1050420.0 | Epsilon 0.530
# Episode  230 | Steps 998 | Reward -1018005.0 | Epsilon 0.529
# Episode  231 | Steps 998 | Reward -1274910.0 | Epsilon 0.527
# Episode  232 | Steps 998 | Reward -977607.0 | Epsilon 0.526
# Episode  233 | Steps 998 | Reward -1043673.0 | Epsilon 0.524
# Episode  234 | Steps 998 | Reward -1139754.0 | Epsilon 0.523
# Episode  235 | Steps 998 | Reward -955848.0 | Epsilon 0.521
# Episode  236 | Steps 998 | Reward -1041303.0 | Epsilon 0.520
# Episode  237 | Steps 998 | Reward -1107159.0 | Epsilon 0.518
# Episode  238 | Steps 998 | Reward -1218603.0 | Epsilon 0.517
# Episode  239 | Steps 998 | Reward -1063542.0 | Epsilon 0.515
# Episode  240 | Steps 998 | Reward -967086.0 | Epsilon 0.514
# Episode  241 | Steps 998 | Reward -1157475.0 | Epsilon 0.513
# Episode  242 | Steps 998 | Reward -1039758.0 | Epsilon 0.511
# Episode  243 | Steps 998 | Reward -1141281.0 | Epsilon 0.510
# Episode  244 | Steps 998 | Reward -1129017.0 | Epsilon 0.508
# Episode  245 | Steps 998 | Reward -1156620.0 | Epsilon 0.507
# Episode  246 | Steps 998 | Reward -1207701.0 | Epsilon 0.506
# Episode  247 | Steps 998 | Reward -957651.0 | Epsilon 0.504
# Episode  248 | Steps 998 | Reward -1042458.0 | Epsilon 0.503
# Episode  249 | Steps 998 | Reward -1024317.0 | Epsilon 0.501
# Episode  250 | Steps 998 | Reward -998535.0 | Epsilon 0.500
# Checkpoint SAVED
# Episode  251 | Steps 998 | Reward -1393473.0 | Epsilon 0.499
# Episode  252 | Steps 998 | Reward -1278687.0 | Epsilon 0.497
# Episode  253 | Steps 998 | Reward -1047135.0 | Epsilon 0.496
# Episode  254 | Steps 998 | Reward -1100034.0 | Epsilon 0.494
# Episode  255 | Steps 998 | Reward -1118907.0 | Epsilon 0.493
# Episode  256 | Steps 998 | Reward -1061103.0 | Epsilon 0.492
# Episode  257 | Steps 998 | Reward -886080.0 | Epsilon 0.490
# Episode  258 | Steps 998 | Reward -1016922.0 | Epsilon 0.489
# Episode  259 | Steps 998 | Reward -958842.0 | Epsilon 0.488
# Episode  260 | Steps 998 | Reward -1156374.0 | Epsilon 0.486
# Episode  261 | Steps 998 | Reward -879204.0 | Epsilon 0.485
# Episode  262 | Steps 998 | Reward -923643.0 | Epsilon 0.484
# Episode  263 | Steps 998 | Reward -933273.0 | Epsilon 0.482
# Episode  264 | Steps 998 | Reward -913284.0 | Epsilon 0.481
# Episode  265 | Steps 998 | Reward -970797.0 | Epsilon 0.480
# Episode  266 | Steps 998 | Reward -1141467.0 | Epsilon 0.478
# Episode  267 | Steps 998 | Reward -896055.0 | Epsilon 0.477
# Episode  268 | Steps 998 | Reward -1079226.0 | Epsilon 0.476
# Episode  269 | Steps 998 | Reward -849597.0 | Epsilon 0.474
# Episode  270 | Steps 998 | Reward -1016793.0 | Epsilon 0.473
# Episode  271 | Steps 998 | Reward -2356968.0 | Epsilon 0.472
# Episode  272 | Steps 998 | Reward -1137375.0 | Epsilon 0.470
# Episode  273 | Steps 998 | Reward -1056666.0 | Epsilon 0.469
# Episode  274 | Steps 998 | Reward -973704.0 | Epsilon 0.468
# Episode  275 | Steps 998 | Reward -900396.0 | Epsilon 0.467
# Episode  276 | Steps 998 | Reward -918852.0 | Epsilon 0.465
# Episode  277 | Steps 998 | Reward -1217394.0 | Epsilon 0.464
# Episode  278 | Steps 998 | Reward -1092528.0 | Epsilon 0.463
# Episode  279 | Steps 998 | Reward -1131072.0 | Epsilon 0.461
# Episode  280 | Steps 998 | Reward -1062699.0 | Epsilon 0.460
# Episode  281 | Steps 998 | Reward -1255623.0 | Epsilon 0.459
# Episode  282 | Steps 998 | Reward -865056.0 | Epsilon 0.458
# Episode  283 | Steps 998 | Reward -1011492.0 | Epsilon 0.456
# Episode  284 | Steps 998 | Reward -1202121.0 | Epsilon 0.455
# Episode  285 | Steps 998 | Reward -1026225.0 | Epsilon 0.454
# Episode  286 | Steps 998 | Reward -2628693.0 | Epsilon 0.453
# Episode  287 | Steps 998 | Reward -1138221.0 | Epsilon 0.451
# Episode  288 | Steps 998 | Reward -940104.0 | Epsilon 0.450
# Episode  289 | Steps 998 | Reward -873888.0 | Epsilon 0.449
# Episode  290 | Steps 998 | Reward -944616.0 | Epsilon 0.448
# Episode  291 | Steps 998 | Reward -829032.0 | Epsilon 0.446
# Episode  292 | Steps 998 | Reward -968970.0 | Epsilon 0.445
# Episode  293 | Steps 998 | Reward -1000950.0 | Epsilon 0.444
# Episode  294 | Steps 998 | Reward -872637.0 | Epsilon 0.443
# Episode  295 | Steps 998 | Reward -954339.0 | Epsilon 0.441
# Episode  296 | Steps 998 | Reward -943920.0 | Epsilon 0.440
# Episode  297 | Steps 998 | Reward -983478.0 | Epsilon 0.439
# Episode  298 | Steps 998 | Reward -1084371.0 | Epsilon 0.438
# Episode  299 | Steps 998 | Reward -989244.0 | Epsilon 0.436
# Episode  300 | Steps 998 | Reward -1410822.0 | Epsilon 0.435
# Episode  301 | Steps 998 | Reward -899502.0 | Epsilon 0.434
# Episode  302 | Steps 998 | Reward -842847.0 | Epsilon 0.433
# Episode  303 | Steps 998 | Reward -1146363.0 | Epsilon 0.432
# Episode  304 | Steps 998 | Reward -935889.0 | Epsilon 0.430
# Episode  305 | Steps 998 | Reward -1060131.0 | Epsilon 0.429
# Episode  306 | Steps 998 | Reward -933303.0 | Epsilon 0.428
# Episode  307 | Steps 998 | Reward -839799.0 | Epsilon 0.427
# Episode  308 | Steps 998 | Reward -1014810.0 | Epsilon 0.426
# Episode  309 | Steps 998 | Reward -826419.0 | Epsilon 0.425
# Episode  310 | Steps 998 | Reward -1030527.0 | Epsilon 0.423
# Episode  311 | Steps 998 | Reward -942027.0 | Epsilon 0.422
# Episode  312 | Steps 998 | Reward -871053.0 | Epsilon 0.421
# Episode  313 | Steps 998 | Reward -886179.0 | Epsilon 0.420
# Episode  314 | Steps 998 | Reward -815847.0 | Epsilon 0.419
# Episode  315 | Steps 998 | Reward -1577214.0 | Epsilon 0.418
# Episode  316 | Steps 998 | Reward -961782.0 | Epsilon 0.416
# Episode  317 | Steps 998 | Reward -788322.0 | Epsilon 0.415
# Episode  318 | Steps 998 | Reward -896289.0 | Epsilon 0.414
# Episode  319 | Steps 998 | Reward -1107927.0 | Epsilon 0.413
# Episode  320 | Steps 998 | Reward -796161.0 | Epsilon 0.412
# Episode  321 | Steps 998 | Reward -1206393.0 | Epsilon 0.411
# Episode  322 | Steps 998 | Reward -918078.0 | Epsilon 0.410
# Episode  323 | Steps 998 | Reward -1246221.0 | Epsilon 0.408
# Episode  324 | Steps 998 | Reward -1119132.0 | Epsilon 0.407
# Episode  325 | Steps 998 | Reward -839772.0 | Epsilon 0.406
# Episode  326 | Steps 998 | Reward -956076.0 | Epsilon 0.405
# Episode  327 | Steps 998 | Reward -1005891.0 | Epsilon 0.404
# Episode  328 | Steps 998 | Reward -1191339.0 | Epsilon 0.403
# Episode  329 | Steps 998 | Reward -904359.0 | Epsilon 0.402
# Episode  330 | Steps 998 | Reward -911118.0 | Epsilon 0.401
# Episode  331 | Steps 998 | Reward -914616.0 | Epsilon 0.399
# Episode  332 | Steps 998 | Reward -1010790.0 | Epsilon 0.398
# Episode  333 | Steps 998 | Reward -901296.0 | Epsilon 0.397
# Episode  334 | Steps 998 | Reward -896649.0 | Epsilon 0.396
# Episode  335 | Steps 998 | Reward -816468.0 | Epsilon 0.395
# Episode  336 | Steps 998 | Reward -954243.0 | Epsilon 0.394
# Episode  337 | Steps 998 | Reward -875238.0 | Epsilon 0.393
# Episode  338 | Steps 998 | Reward -894054.0 | Epsilon 0.392
# Episode  339 | Steps 998 | Reward -914115.0 | Epsilon 0.391
# Episode  340 | Steps 998 | Reward -1022880.0 | Epsilon 0.390
# Episode  341 | Steps 998 | Reward -811983.0 | Epsilon 0.389
# Episode  342 | Steps 998 | Reward -808005.0 | Epsilon 0.387
# Episode  343 | Steps 998 | Reward -965241.0 | Epsilon 0.386
# Episode  344 | Steps 998 | Reward -880692.0 | Epsilon 0.385
# Episode  345 | Steps 998 | Reward -820428.0 | Epsilon 0.384
# Episode  346 | Steps 998 | Reward -762792.0 | Epsilon 0.383
# Episode  347 | Steps 998 | Reward -814815.0 | Epsilon 0.382
# Episode  348 | Steps 998 | Reward -830367.0 | Epsilon 0.381
# Episode  349 | Steps 998 | Reward -1104165.0 | Epsilon 0.380
# Episode  350 | Steps 998 | Reward -1130145.0 | Epsilon 0.379
# Episode  351 | Steps 998 | Reward -965343.0 | Epsilon 0.378
# Episode  352 | Steps 998 | Reward -772176.0 | Epsilon 0.377
# Episode  353 | Steps 998 | Reward -799821.0 | Epsilon 0.376
# Episode  354 | Steps 998 | Reward -782574.0 | Epsilon 0.375
# Episode  355 | Steps 998 | Reward -774162.0 | Epsilon 0.374
# Episode  356 | Steps 998 | Reward -2964945.0 | Epsilon 0.373
# Episode  357 | Steps 998 | Reward -856518.0 | Epsilon 0.372
# Episode  358 | Steps 998 | Reward -764109.0 | Epsilon 0.371
# Episode  359 | Steps 998 | Reward -835416.0 | Epsilon 0.370
# Episode  360 | Steps 998 | Reward -876084.0 | Epsilon 0.369
# Episode  361 | Steps 998 | Reward -1024719.0 | Epsilon 0.368
# Episode  362 | Steps 998 | Reward -891687.0 | Epsilon 0.367
# Episode  363 | Steps 998 | Reward -922950.0 | Epsilon 0.366
# Episode  364 | Steps 998 | Reward -890631.0 | Epsilon 0.365
# Episode  365 | Steps 998 | Reward -1077768.0 | Epsilon 0.363
# Episode  366 | Steps 998 | Reward -894537.0 | Epsilon 0.362
# Episode  367 | Steps 998 | Reward -784332.0 | Epsilon 0.361
# Episode  368 | Steps 998 | Reward -869277.0 | Epsilon 0.360
# Episode  369 | Steps 998 | Reward -831462.0 | Epsilon 0.359
# Episode  370 | Steps 998 | Reward -844746.0 | Epsilon 0.358
# Episode  371 | Steps 998 | Reward -774909.0 | Epsilon 0.357
# Episode  372 | Steps 998 | Reward -757827.0 | Epsilon 0.357
# Episode  373 | Steps 998 | Reward -924534.0 | Epsilon 0.356
# Episode  374 | Steps 998 | Reward -809067.0 | Epsilon 0.355
# Episode  375 | Steps 998 | Reward -1006077.0 | Epsilon 0.354
# Episode  376 | Steps 998 | Reward -929886.0 | Epsilon 0.353
# Episode  377 | Steps 998 | Reward -847224.0 | Epsilon 0.352
# Episode  378 | Steps 998 | Reward -711252.0 | Epsilon 0.351
# Episode  379 | Steps 998 | Reward -805107.0 | Epsilon 0.350
# Episode  380 | Steps 998 | Reward -932244.0 | Epsilon 0.349
# Episode  381 | Steps 998 | Reward -890100.0 | Epsilon 0.348
# Episode  382 | Steps 998 | Reward -863451.0 | Epsilon 0.347
# Episode  383 | Steps 998 | Reward -720549.0 | Epsilon 0.346
# Episode  384 | Steps 998 | Reward -873300.0 | Epsilon 0.345
# Episode  385 | Steps 998 | Reward -794340.0 | Epsilon 0.344
# Episode  386 | Steps 998 | Reward -854985.0 | Epsilon 0.343
# Episode  387 | Steps 998 | Reward -1190028.0 | Epsilon 0.342
# Episode  388 | Steps 998 | Reward -805620.0 | Epsilon 0.341
# Episode  389 | Steps 998 | Reward -885897.0 | Epsilon 0.340
# Episode  390 | Steps 998 | Reward -780525.0 | Epsilon 0.339
# Episode  391 | Steps 998 | Reward -693558.0 | Epsilon 0.338
# Episode  392 | Steps 998 | Reward -723063.0 | Epsilon 0.337
# Episode  393 | Steps 998 | Reward -994974.0 | Epsilon 0.336
# Episode  394 | Steps 998 | Reward -936789.0 | Epsilon 0.335
# Episode  395 | Steps 998 | Reward -771243.0 | Epsilon 0.334
# Episode  396 | Steps 998 | Reward -861963.0 | Epsilon 0.334
# Episode  397 | Steps 998 | Reward -823050.0 | Epsilon 0.333
# Episode  398 | Steps 998 | Reward -979083.0 | Epsilon 0.332
# Episode  399 | Steps 998 | Reward -671688.0 | Epsilon 0.331
# Episode  400 | Steps 998 | Reward -1036449.0 | Epsilon 0.330
# Episode  401 | Steps 998 | Reward -847638.0 | Epsilon 0.329
# Episode  402 | Steps 998 | Reward -965058.0 | Epsilon 0.328
# Episode  403 | Steps 998 | Reward -931830.0 | Epsilon 0.327
# Episode  404 | Steps 998 | Reward -771690.0 | Epsilon 0.326
# Episode  405 | Steps 998 | Reward -874215.0 | Epsilon 0.325
# Episode  406 | Steps 998 | Reward -775074.0 | Epsilon 0.324
# Episode  407 | Steps 998 | Reward -821397.0 | Epsilon 0.324
# Episode  408 | Steps 998 | Reward -756591.0 | Epsilon 0.323
# Episode  409 | Steps 998 | Reward -774147.0 | Epsilon 0.322
# Episode  410 | Steps 998 | Reward -807399.0 | Epsilon 0.321
# Episode  411 | Steps 998 | Reward -840723.0 | Epsilon 0.320
# Episode  412 | Steps 998 | Reward -942285.0 | Epsilon 0.319
# Episode  413 | Steps 998 | Reward -771144.0 | Epsilon 0.318
# Episode  414 | Steps 998 | Reward -805203.0 | Epsilon 0.317
# Episode  415 | Steps 998 | Reward -625701.0 | Epsilon 0.316
# Episode  416 | Steps 998 | Reward -731019.0 | Epsilon 0.316
# Episode  417 | Steps 998 | Reward -736131.0 | Epsilon 0.315
# Episode  418 | Steps 998 | Reward -862965.0 | Epsilon 0.314
# Episode  419 | Steps 998 | Reward -832707.0 | Epsilon 0.313
# Episode  420 | Steps 998 | Reward -739554.0 | Epsilon 0.312
# Episode  421 | Steps 998 | Reward -793269.0 | Epsilon 0.311
# Episode  422 | Steps 998 | Reward -611667.0 | Epsilon 0.310
# Episode  423 | Steps 998 | Reward -762624.0 | Epsilon 0.309
# Episode  424 | Steps 998 | Reward -867291.0 | Epsilon 0.309
# Episode  425 | Steps 998 | Reward -812946.0 | Epsilon 0.308
# Episode  426 | Steps 998 | Reward -893595.0 | Epsilon 0.307
# Episode  427 | Steps 998 | Reward -862704.0 | Epsilon 0.306
# Episode  428 | Steps 998 | Reward -690258.0 | Epsilon 0.305
# Episode  429 | Steps 998 | Reward -697245.0 | Epsilon 0.304
# Episode  430 | Steps 998 | Reward -787059.0 | Epsilon 0.304
# Episode  431 | Steps 998 | Reward -875598.0 | Epsilon 0.303
# Episode  432 | Steps 998 | Reward -670056.0 | Epsilon 0.302
# Episode  433 | Steps 998 | Reward -619365.0 | Epsilon 0.301
# Episode  434 | Steps 998 | Reward -956544.0 | Epsilon 0.300
# Episode  435 | Steps 998 | Reward -868677.0 | Epsilon 0.299
# Episode  436 | Steps 998 | Reward -790266.0 | Epsilon 0.299
# Episode  437 | Steps 998 | Reward -708987.0 | Epsilon 0.298
# Episode  438 | Steps 998 | Reward -729312.0 | Epsilon 0.297
# Episode  439 | Steps 998 | Reward -823374.0 | Epsilon 0.296
# Episode  440 | Steps 998 | Reward -819432.0 | Epsilon 0.295
# Episode  441 | Steps 998 | Reward -906093.0 | Epsilon 0.294
# Episode  442 | Steps 998 | Reward -854631.0 | Epsilon 0.294
# Episode  443 | Steps 998 | Reward -982359.0 | Epsilon 0.293
# Episode  444 | Steps 998 | Reward -748149.0 | Epsilon 0.292
# Episode  445 | Steps 998 | Reward -729243.0 | Epsilon 0.291
# Episode  446 | Steps 998 | Reward -832620.0 | Epsilon 0.290
# Episode  447 | Steps 998 | Reward -768711.0 | Epsilon 0.290
# Episode  448 | Steps 998 | Reward -756012.0 | Epsilon 0.289
# Episode  449 | Steps 998 | Reward -731466.0 | Epsilon 0.288
# Episode  450 | Steps 998 | Reward -756072.0 | Epsilon 0.287
# Episode  451 | Steps 998 | Reward -844332.0 | Epsilon 0.286
# Episode  452 | Steps 998 | Reward -676128.0 | Epsilon 0.286
# Episode  453 | Steps 998 | Reward -760533.0 | Epsilon 0.285
# Episode  454 | Steps 998 | Reward -786972.0 | Epsilon 0.284
# Episode  455 | Steps 998 | Reward -783150.0 | Epsilon 0.283
# Episode  456 | Steps 998 | Reward -732444.0 | Epsilon 0.282
# Episode  457 | Steps 998 | Reward -754974.0 | Epsilon 0.282
# Episode  458 | Steps 998 | Reward -878055.0 | Epsilon 0.281
# Episode  459 | Steps 998 | Reward -684924.0 | Epsilon 0.280
# Episode  460 | Steps 998 | Reward -805332.0 | Epsilon 0.279
# Episode  461 | Steps 998 | Reward -741702.0 | Epsilon 0.279
# Episode  462 | Steps 998 | Reward -698043.0 | Epsilon 0.278
# Episode  463 | Steps 998 | Reward -701310.0 | Epsilon 0.277
# Episode  464 | Steps 998 | Reward -789696.0 | Epsilon 0.276
# Episode  465 | Steps 998 | Reward -767964.0 | Epsilon 0.275
# Episode  466 | Steps 998 | Reward -796536.0 | Epsilon 0.275
# Episode  467 | Steps 998 | Reward -731811.0 | Epsilon 0.274
# Episode  468 | Steps 998 | Reward -739422.0 | Epsilon 0.273
# Episode  469 | Steps 998 | Reward -798936.0 | Epsilon 0.272
# Episode  470 | Steps 998 | Reward -847113.0 | Epsilon 0.272
# Episode  471 | Steps 998 | Reward -851301.0 | Epsilon 0.271
# Episode  472 | Steps 998 | Reward -671817.0 | Epsilon 0.270
# Episode  473 | Steps 998 | Reward -737367.0 | Epsilon 0.269
# Episode  474 | Steps 998 | Reward -678069.0 | Epsilon 0.269
# Episode  475 | Steps 998 | Reward -778305.0 | Epsilon 0.268
# Episode  476 | Steps 998 | Reward -896199.0 | Epsilon 0.267
# Episode  477 | Steps 998 | Reward -660348.0 | Epsilon 0.266
# Episode  478 | Steps 998 | Reward -653979.0 | Epsilon 0.266
# Episode  479 | Steps 998 | Reward -744195.0 | Epsilon 0.265
# Episode  480 | Steps 998 | Reward -716922.0 | Epsilon 0.264
# Episode  481 | Steps 998 | Reward -625248.0 | Epsilon 0.264
# Episode  482 | Steps 998 | Reward -1010316.0 | Epsilon 0.263
# Episode  483 | Steps 998 | Reward -584796.0 | Epsilon 0.262
# Episode  484 | Steps 998 | Reward -754653.0 | Epsilon 0.261
# Episode  485 | Steps 998 | Reward -606165.0 | Epsilon 0.261
# Episode  486 | Steps 998 | Reward -791763.0 | Epsilon 0.260
# Episode  487 | Steps 998 | Reward -622734.0 | Epsilon 0.259
# Episode  488 | Steps 998 | Reward -666960.0 | Epsilon 0.258
# Episode  489 | Steps 998 | Reward -848877.0 | Epsilon 0.258
# Episode  490 | Steps 998 | Reward -682353.0 | Epsilon 0.257
# Episode  491 | Steps 998 | Reward -684588.0 | Epsilon 0.256
# Episode  492 | Steps 998 | Reward -768324.0 | Epsilon 0.256
# Episode  493 | Steps 998 | Reward -542196.0 | Epsilon 0.255
# Episode  494 | Steps 998 | Reward -638634.0 | Epsilon 0.254
# Episode  495 | Steps 998 | Reward -727521.0 | Epsilon 0.253
# Episode  496 | Steps 998 | Reward -671130.0 | Epsilon 0.253
# Episode  497 | Steps 998 | Reward -798204.0 | Epsilon 0.252
# Episode  498 | Steps 998 | Reward -708072.0 | Epsilon 0.251
# Episode  499 | Steps 998 | Reward -643587.0 | Epsilon 0.251
# Episode  500 | Steps 998 | Reward -741465.0 | Epsilon 0.250
# Checkpoint SAVED
# Model saved to checkpoints/qnet_double_dqn_final.pth

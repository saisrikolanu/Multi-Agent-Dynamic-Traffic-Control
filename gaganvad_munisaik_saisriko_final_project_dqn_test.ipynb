# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import gym
import os
import cityflow
import gym_cityflow
import random

# %%
class DQN_network(torch.nn.Module):
    def __init__(self, input_dim, action_dim, hidden_dims=[128, 256, 128]):
        super().__init__()
        self.fc1 = torch.nn.Linear(input_dim, hidden_dims[0])
        self.norm1 = torch.nn.LayerNorm(hidden_dims[0])
        self.fc2 = torch.nn.Linear(hidden_dims[0], hidden_dims[1])
        self.norm2 = torch.nn.LayerNorm(hidden_dims[1])
        self.fc3 = torch.nn.Linear(hidden_dims[1], hidden_dims[2])
        self.norm3 = torch.nn.LayerNorm(hidden_dims[2])
        self.out = torch.nn.Linear(hidden_dims[2], action_dim)

    def forward(self, x):
        x = torch.relu(self.norm1(self.fc1(x)))
        x = torch.relu(self.norm2(self.fc2(x)))
        x = torch.relu(self.norm3(self.fc3(x)))
        return self.out(x)

# %%
CONFIG_PATH = "Intersections_4/sample_config.json"
CHECKPOINT = "checkpoints/qnet_dqn_final.pth"
NUM_AGENTS = 16
OBS_DIM    = 72
ACTION_DIM = 9
STEPS      = 1000

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
q_net = DQN_network(OBS_DIM, ACTION_DIM).to(device)
checkpoint = torch.load(CHECKPOINT, map_location=device)
q_net.load_state_dict(checkpoint)
q_net.eval()
# Out:
# DQN_network(
#   (fc1): Linear(in_features=72, out_features=128, bias=True)
#   (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (norm3): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (out): Linear(in_features=128, out_features=9, bias=True)
# )

# %%
env = gym.make(
    id="cityflow-v0",
    configPath=CONFIG_PATH,
    episodeSteps=STEPS
)
raw_obs = env.reset()
intersection_ids = sorted(raw_obs.keys())
# Out:
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(

# %%
obs = [
    np.array(raw_obs[i], dtype=np.float32).flatten()
    for i in intersection_ids
]

# %%
total_reward     = 0.0
step_rewards     = []
queue_lengths    = []

prev_vehicles   = set(env.eng.get_vehicles(include_waiting=True))
arrived_vehicles = set()

lane_wait = env.eng.get_lane_waiting_vehicle_count()
queue_lengths.append(sum(lane_wait.values()))

for t in range(1, STEPS+1):
    actions = []
    for o in obs:
        tensor_o = torch.tensor(o, dtype=torch.float32, device=device).unsqueeze(0)
        with torch.no_grad():
            q_vals = q_net(tensor_o)
        actions.append(int(q_vals.argmax(dim=1).item()))

    next_raw_obs, rewards, done, info = env.step(actions)
    total_r = sum(r for _, r in rewards)
    total_reward += total_r
    step_rewards.append(total_r)

    cur_vehicles = set(env.eng.get_vehicles(include_waiting=True))
    new_arrivals = prev_vehicles - cur_vehicles
    arrived_vehicles |= new_arrivals
    prev_vehicles = cur_vehicles

    lw = env.eng.get_lane_waiting_vehicle_count()
    queue_lengths.append(sum(lw.values()))
    
    obs = [
        np.array(next_raw_obs[i], dtype=np.float32).flatten()
        for i in intersection_ids
    ]

    print(f"Step {t:4d}  reward {total_r:8.1f}  queue {queue_lengths[-1]:4d}")

    if done:
        print(f"Environment signaled done at step {t+1}")
        break

num_arrived     = len(arrived_vehicles)
total_wait_time = sum(queue_lengths)  
avg_wait_per_veh= total_wait_time/num_arrived if num_arrived>0 else float("nan")

avg_travel_time = env.eng.get_average_travel_time()  
active_vehicles = env.eng.get_vehicle_count()  
      
print("\n=== Evaluation Summary ===")
print(f"Total steps executed       : {t}")
print(f"Total reward accumulated   : {total_reward:.1f}")
print(f"Vehicles arrived           : {num_arrived}")
print(f"Active vehicles remaining  : {active_vehicles}")
print(f"Avg waiting time/vehicle   : {avg_wait_per_veh:.2f} s")
print(f"Avg travel time (all)      : {avg_travel_time:.2f} s")
# Out:
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:146: UserWarning: WARN: The obs returned by the `step()` method was expecting a numpy array, actual type: <class 'list'>
#   logger.warn(f"{pre} was expecting a numpy array, actual type: {type(obs)}")
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:252: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'list'>
#   logger.warn(
# Step    1  reward      0.0  queue    0
# Step    2  reward      0.0  queue    0
# Step    3  reward      0.0  queue    0
# Step    4  reward      0.0  queue    0
# Step    5  reward      0.0  queue    0
# Step    6  reward      0.0  queue    0
# Step    7  reward      0.0  queue    0
# Step    8  reward      0.0  queue    0
# Step    9  reward      0.0  queue    0
# Step   10  reward      0.0  queue    0
# Step   11  reward      0.0  queue    0
# Step   12  reward      0.0  queue    0
# Step   13  reward      0.0  queue    0
# Step   14  reward      0.0  queue    0
# Step   15  reward      0.0  queue    0
# Step   16  reward      0.0  queue    0
# Step   17  reward      0.0  queue    0
# Step   18  reward      0.0  queue    0
# Step   19  reward      0.0  queue    0
# Step   20  reward      0.0  queue    0
# Step   21  reward      0.0  queue    0
# Step   22  reward      0.0  queue    0
# Step   23  reward      0.0  queue    0
# Step   24  reward      0.0  queue    0
# Step   25  reward      0.0  queue    0
# Step   26  reward      0.0  queue    0
# Step   27  reward      0.0  queue    0
# Step   28  reward      0.0  queue    0
# Step   29  reward      0.0  queue    0
# Step   30  reward      0.0  queue    0
# Step   31  reward    -30.0  queue    5
# Step   32  reward    -15.0  queue    1
# Step   33  reward    -24.0  queue    1
# Step   34  reward    -39.0  queue    2
# Step   35  reward    -42.0  queue    1
# Step   36  reward    -57.0  queue    2
# Step   37  reward    -66.0  queue    2
# Step   38  reward    -87.0  queue    4
# Step   39  reward   -120.0  queue    5
# Step   40  reward   -162.0  queue    4
# Step   41  reward   -222.0  queue    7
# Step   42  reward   -273.0  queue    8
# Step   43  reward   -273.0  queue    5
# Step   44  reward   -312.0  queue    7
# Step   45  reward   -243.0  queue    6
# Step   46  reward   -228.0  queue    5
# Step   47  reward   -177.0  queue    4
# Step   48  reward   -183.0  queue    5
# Step   49  reward   -195.0  queue    3
# Step   50  reward   -219.0  queue    3
# Step   51  reward   -273.0  queue    5
# Step   52  reward   -333.0  queue    7
# Step   53  reward    -99.0  queue    5
# Step   54  reward    -93.0  queue    5
# Step   55  reward    -87.0  queue    4
# Step   56  reward    -75.0  queue    2
# Step   57  reward   -129.0  queue    7
# Step   58  reward   -147.0  queue    8
# Step   59  reward   -168.0  queue    7
# Step   60  reward   -156.0  queue    5
# Step   61  reward   -198.0  queue    6
# Step   62  reward   -219.0  queue    5
# Step   63  reward   -282.0  queue    9
# Step   64  reward   -252.0  queue    7
# Step   65  reward   -294.0  queue    9
# Step   66  reward   -255.0  queue    8
# Step   67  reward   -252.0  queue    5
# Step   68  reward   -255.0  queue    4
# Step   69  reward   -288.0  queue    6
# Step   70  reward   -258.0  queue    3
# Step   71  reward   -243.0  queue    8
# Step   72  reward   -267.0  queue    6
# Step   73  reward   -105.0  queue    9
# Step   74  reward    -93.0  queue    8
# Step   75  reward    -84.0  queue    8
# Step   76  reward    -66.0  queue    5
# Step   77  reward    -66.0  queue    5
# Step   78  reward   -114.0  queue    6
# Step   79  reward   -141.0  queue    9
# Step   80  reward   -216.0  queue   11
# Step   81  reward   -216.0  queue   12
# Step   82  reward   -141.0  queue    7
# Step   83  reward   -120.0  queue    5
# Step   84  reward   -165.0  queue    7
# Step   85  reward   -174.0  queue    9
# Step   86  reward   -219.0  queue   11
# Step   87  reward   -138.0  queue    8
# Step   88  reward   -114.0  queue    4
# Step   89  reward   -168.0  queue    7
# Step   90  reward   -141.0  queue    7
# Step   91  reward    -60.0  queue    7
# Step   92  reward    -54.0  queue    4
# Step   93  reward    -96.0  queue    5
# Step   94  reward   -144.0  queue    8
# Step   95  reward   -222.0  queue   12
# Step   96  reward   -288.0  queue   12
# Step   97  reward   -300.0  queue   11
# Step   98  reward   -351.0  queue   12
# Step   99  reward   -396.0  queue   12
# Step  100  reward   -447.0  queue   13
# Step  101  reward   -297.0  queue    9
# Step  102  reward   -297.0  queue    7
# Step  103  reward   -282.0  queue    9
# Step  104  reward   -291.0  queue    7
# Step  105  reward   -315.0  queue    9
# Step  106  reward   -222.0  queue    5
# Step  107  reward   -276.0  queue    7
# Step  108  reward   -306.0  queue    7
# Step  109  reward   -300.0  queue   10
# Step  110  reward   -279.0  queue    9
# Step  111  reward   -306.0  queue    8
# Step  112  reward   -309.0  queue    8
# Step  113  reward   -348.0  queue   10
# Step  114  reward    -72.0  queue    8
# Step  115  reward    -63.0  queue    5
# Step  116  reward    -90.0  queue    6
# Step  117  reward    -81.0  queue    3
# Step  118  reward    -96.0  queue    7
# Step  119  reward   -132.0  queue   12
# Step  120  reward   -177.0  queue   11
# Step  121  reward   -291.0  queue   19
# Step  122  reward   -324.0  queue   16
# Step  123  reward   -306.0  queue   12
# Step  124  reward   -222.0  queue   10
# Step  125  reward   -243.0  queue   11
# Step  126  reward   -255.0  queue   13
# Step  127  reward   -279.0  queue   13
# Step  128  reward   -336.0  queue   12
# Step  129  reward   -450.0  queue   20
# Step  130  reward   -396.0  queue   17
# Step  131  reward   -417.0  queue   14
# Step  132  reward   -366.0  queue   15
# Step  133  reward   -375.0  queue   14
# Step  134  reward   -393.0  queue   16
# Step  135  reward   -378.0  queue   21
# Step  136  reward   -459.0  queue   20
# Step  137  reward   -321.0  queue   16
# Step  138  reward   -315.0  queue   16
# Step  139  reward   -405.0  queue   18
# Step  140  reward   -390.0  queue   16
# Step  141  reward   -441.0  queue   15
# Step  142  reward   -558.0  queue   21
# Step  143  reward   -630.0  queue   22
# Step  144  reward   -588.0  queue   17
# Step  145  reward   -579.0  queue   16
# Step  146  reward   -579.0  queue   17
# Step  147  reward   -555.0  queue   13
# Step  148  reward   -534.0  queue   14
# Step  149  reward   -531.0  queue   15
# Step  150  reward   -552.0  queue   17
# Step  151  reward   -594.0  queue   21
# Step  152  reward   -507.0  queue   17
# Step  153  reward   -600.0  queue   15
# Step  154  reward   -621.0  queue   20
# Step  155  reward   -567.0  queue   18
# Step  156  reward   -696.0  queue   21
# Step  157  reward   -660.0  queue   22
# Step  158  reward   -654.0  queue   18
# Step  159  reward   -645.0  queue   18
# Step  160  reward   -687.0  queue   15
# Step  161  reward   -699.0  queue   19
# Step  162  reward   -789.0  queue   18
# Step  163  reward   -780.0  queue   16
# Step  164  reward   -780.0  queue   16
# Step  165  reward   -846.0  queue   19
# Step  166  reward   -930.0  queue   21
# Step  167  reward  -1020.0  queue   21
# Step  168  reward  -1101.0  queue   24
# Step  169  reward  -1131.0  queue   23
# Step  170  reward  -1002.0  queue   22
# Step  171  reward   -762.0  queue   18
# Step  172  reward   -603.0  queue   20
# Step  173  reward   -453.0  queue   22
# Step  174  reward   -582.0  queue   23
# Step  175  reward   -645.0  queue   28
# Step  176  reward   -678.0  queue   29
# Step  177  reward   -741.0  queue   26
# Step  178  reward   -813.0  queue   28
# Step  179  reward   -843.0  queue   23
# Step  180  reward   -864.0  queue   22
# Step  181  reward   -993.0  queue   22
# Step  182  reward  -1083.0  queue   24
# Step  183  reward  -1092.0  queue   26
# Step  184  reward  -1101.0  queue   31
# Step  185  reward   -801.0  queue   23
# Step  186  reward   -690.0  queue   19
# Step  187  reward   -660.0  queue   22
# Step  188  reward   -618.0  queue   23
# Step  189  reward   -780.0  queue   26
# Step  190  reward   -762.0  queue   29
# Step  191  reward   -651.0  queue   30
# Step  192  reward   -573.0  queue   27
# Step  193  reward   -465.0  queue   24
# Step  194  reward   -423.0  queue   21
# Step  195  reward   -423.0  queue   21
# Step  196  reward   -414.0  queue   21
# Step  197  reward   -453.0  queue   26
# Step  198  reward   -549.0  queue   32
# Step  199  reward   -642.0  queue   28
# Step  200  reward   -654.0  queue   27
# Step  201  reward   -708.0  queue   27
# Step  202  reward   -720.0  queue   27
# Step  203  reward   -603.0  queue   22
# Step  204  reward   -552.0  queue   18
# Step  205  reward   -543.0  queue   19
# Step  206  reward   -504.0  queue   22
# Step  207  reward   -276.0  queue   19
# Step  208  reward   -309.0  queue   23
# Step  209  reward   -213.0  queue   18
# Step  210  reward   -174.0  queue   10
# Step  211  reward   -186.0  queue   13
# Step  212  reward   -270.0  queue   18
# Step  213  reward   -363.0  queue   26
# Step  214  reward   -384.0  queue   27
# Step  215  reward   -438.0  queue   28
# Step  216  reward   -435.0  queue   26
# Step  217  reward   -435.0  queue   23
# Step  218  reward   -399.0  queue   20
# Step  219  reward   -465.0  queue   29
# Step  220  reward   -516.0  queue   30
# Step  221  reward   -600.0  queue   31
# Step  222  reward   -678.0  queue   33
# Step  223  reward   -690.0  queue   34
# Step  224  reward   -687.0  queue   28
# Step  225  reward   -687.0  queue   29
# Step  226  reward   -495.0  queue   23
# Step  227  reward   -366.0  queue   20
# Step  228  reward   -303.0  queue   18
# Step  229  reward   -276.0  queue   18
# Step  230  reward   -276.0  queue   22
# Step  231  reward   -351.0  queue   20
# Step  232  reward   -324.0  queue   20
# Step  233  reward   -318.0  queue   16
# Step  234  reward   -510.0  queue   30
# Step  235  reward   -495.0  queue   28
# Step  236  reward   -513.0  queue   26
# Step  237  reward   -609.0  queue   27
# Step  238  reward   -651.0  queue   27
# Step  239  reward   -645.0  queue   25
# Step  240  reward   -570.0  queue   25
# Step  241  reward   -567.0  queue   27
# Step  242  reward   -435.0  queue   23
# Step  243  reward   -414.0  queue   19
# Step  244  reward   -456.0  queue   22
# Step  245  reward   -492.0  queue   23
# Step  246  reward   -564.0  queue   29
# Step  247  reward   -627.0  queue   29
# Step  248  reward   -660.0  queue   29
# Step  249  reward   -528.0  queue   20
# Step  250  reward   -486.0  queue   23
# Step  251  reward   -519.0  queue   31
# Step  252  reward   -495.0  queue   33
# Step  253  reward   -603.0  queue   35
# Step  254  reward   -615.0  queue   29
# Step  255  reward   -567.0  queue   26
# Step  256  reward   -495.0  queue   24
# Step  257  reward   -636.0  queue   28
# Step  258  reward   -786.0  queue   38
# Step  259  reward   -804.0  queue   38
# Step  260  reward   -750.0  queue   35
# Step  261  reward   -723.0  queue   33
# Step  262  reward   -774.0  queue   39
# Step  263  reward   -801.0  queue   34
# Step  264  reward   -819.0  queue   33
# Step  265  reward   -921.0  queue   35
# Step  266  reward   -834.0  queue   29
# Step  267  reward   -837.0  queue   27
# Step  268  reward   -768.0  queue   27
# Step  269  reward   -798.0  queue   32
# Step  270  reward   -753.0  queue   30
# Step  271  reward   -756.0  queue   28
# Step  272  reward   -792.0  queue   28
# Step  273  reward   -861.0  queue   28
# Step  274  reward   -786.0  queue   30
# Step  275  reward   -723.0  queue   28
# Step  276  reward   -705.0  queue   31
# Step  277  reward   -645.0  queue   30
# Step  278  reward   -588.0  queue   25
# Step  279  reward   -468.0  queue   26
# Step  280  reward   -540.0  queue   27
# Step  281  reward   -435.0  queue   27
# Step  282  reward   -456.0  queue   28
# Step  283  reward   -555.0  queue   27
# Step  284  reward   -690.0  queue   34
# Step  285  reward   -738.0  queue   35
# Step  286  reward   -870.0  queue   34
# Step  287  reward  -1035.0  queue   39
# Step  288  reward  -1221.0  queue   39
# Step  289  reward  -1227.0  queue   37
# Step  290  reward  -1374.0  queue   39
# Step  291  reward  -1473.0  queue   39
# Step  292  reward  -1368.0  queue   42
# Step  293  reward  -1068.0  queue   32
# Step  294  reward   -951.0  queue   35
# Step  295  reward   -930.0  queue   34
# Step  296  reward   -822.0  queue   34
# Step  297  reward   -591.0  queue   33
# Step  298  reward   -630.0  queue   32
# Step  299  reward   -609.0  queue   33
# Step  300  reward   -681.0  queue   39
# Step  301  reward   -795.0  queue   40
# Step  302  reward   -720.0  queue   35
# Step  303  reward   -693.0  queue   33
# Step  304  reward   -747.0  queue   35
# Step  305  reward   -765.0  queue   39
# Step  306  reward   -795.0  queue   43
# Step  307  reward   -858.0  queue   37
# Step  308  reward   -777.0  queue   35
# Step  309  reward   -756.0  queue   29
# Step  310  reward   -699.0  queue   27
# Step  311  reward   -696.0  queue   29
# Step  312  reward   -603.0  queue   29
# Step  313  reward   -597.0  queue   33
# Step  314  reward   -588.0  queue   32
# Step  315  reward   -606.0  queue   32
# Step  316  reward   -699.0  queue   34
# Step  317  reward   -816.0  queue   37
# Step  318  reward   -813.0  queue   39
# Step  319  reward   -762.0  queue   35
# Step  320  reward   -729.0  queue   32
# Step  321  reward   -720.0  queue   33
# Step  322  reward   -624.0  queue   32
# Step  323  reward   -603.0  queue   37
# Step  324  reward   -714.0  queue   35
# Step  325  reward   -696.0  queue   35
# Step  326  reward   -633.0  queue   27
# Step  327  reward   -615.0  queue   31
# Step  328  reward   -645.0  queue   34
# Step  329  reward   -570.0  queue   30
# Step  330  reward   -480.0  queue   30
# Step  331  reward   -495.0  queue   30
# Step  332  reward   -510.0  queue   32
# Step  333  reward   -516.0  queue   31
# Step  334  reward   -498.0  queue   33
# Step  335  reward   -399.0  queue   27
# Step  336  reward   -435.0  queue   28
# Step  337  reward   -384.0  queue   26
# Step  338  reward   -366.0  queue   28
# Step  339  reward   -390.0  queue   32
# Step  340  reward   -441.0  queue   32
# Step  341  reward   -390.0  queue   32
# Step  342  reward   -312.0  queue   25
# Step  343  reward   -294.0  queue   22
# Step  344  reward   -426.0  queue   28
# Step  345  reward   -474.0  queue   30
# Step  346  reward   -576.0  queue   34
# Step  347  reward   -675.0  queue   35
# Step  348  reward   -684.0  queue   35
# Step  349  reward   -660.0  queue   29
# Step  350  reward   -801.0  queue   36
# Step  351  reward   -951.0  queue   37
# Step  352  reward   -891.0  queue   34
# Step  353  reward   -957.0  queue   37
# Step  354  reward   -879.0  queue   37
# Step  355  reward   -912.0  queue   36
# Step  356  reward  -1020.0  queue   38
# Step  357  reward   -843.0  queue   33
# Step  358  reward   -693.0  queue   34
# Step  359  reward   -651.0  queue   29
# Step  360  reward   -747.0  queue   27
# Step  361  reward   -903.0  queue   40
# Step  362  reward  -1032.0  queue   40
# Step  363  reward  -1065.0  queue   45
# Step  364  reward  -1137.0  queue   46
# Step  365  reward  -1101.0  queue   44
# Step  366  reward  -1110.0  queue   39
# Step  367  reward  -1098.0  queue   39
# Step  368  reward   -948.0  queue   37
# Step  369  reward  -1026.0  queue   43
# Step  370  reward  -1326.0  queue   53
# Step  371  reward  -1404.0  queue   50
# Step  372  reward  -1401.0  queue   50
# Step  373  reward  -1416.0  queue   51
# Step  374  reward  -1398.0  queue   48
# Step  375  reward  -1404.0  queue   48
# Step  376  reward  -1653.0  queue   50
# Step  377  reward  -1665.0  queue   48
# Step  378  reward  -1590.0  queue   48
# Step  379  reward  -1608.0  queue   43
# Step  380  reward  -1527.0  queue   41
# Step  381  reward  -1452.0  queue   39
# Step  382  reward  -1362.0  queue   37
# Step  383  reward  -1254.0  queue   39
# Step  384  reward  -1224.0  queue   40
# Step  385  reward  -1209.0  queue   37
# Step  386  reward  -1005.0  queue   36
# Step  387  reward  -1014.0  queue   47
# Step  388  reward  -1113.0  queue   46
# Step  389  reward  -1161.0  queue   50
# Step  390  reward  -1212.0  queue   53
# Step  391  reward  -1218.0  queue   53
# Step  392  reward  -1218.0  queue   50
# Step  393  reward  -1281.0  queue   54
# Step  394  reward  -1113.0  queue   50
# Step  395  reward  -1020.0  queue   45
# Step  396  reward   -954.0  queue   50
# Step  397  reward  -1023.0  queue   50
# Step  398  reward   -924.0  queue   45
# Step  399  reward   -813.0  queue   39
# Step  400  reward   -921.0  queue   45
# Step  401  reward  -1179.0  queue   58
# Step  402  reward  -1299.0  queue   60
# Step  403  reward  -1233.0  queue   53
# Step  404  reward  -1089.0  queue   44
# Step  405  reward  -1134.0  queue   40
# Step  406  reward  -1053.0  queue   40
# Step  407  reward   -963.0  queue   48
# Step  408  reward   -780.0  queue   37
# Step  409  reward   -642.0  queue   31
# Step  410  reward   -672.0  queue   36
# Step  411  reward   -771.0  queue   43
# Step  412  reward   -807.0  queue   49
# Step  413  reward   -945.0  queue   53
# Step  414  reward  -1035.0  queue   46
# Step  415  reward  -1029.0  queue   46
# Step  416  reward   -993.0  queue   49
# Step  417  reward  -1005.0  queue   46
# Step  418  reward  -1074.0  queue   39
# Step  419  reward  -1050.0  queue   39
# Step  420  reward  -1074.0  queue   41
# Step  421  reward  -1137.0  queue   47
# Step  422  reward  -1197.0  queue   44
# Step  423  reward  -1167.0  queue   40
# Step  424  reward  -1011.0  queue   35
# Step  425  reward   -969.0  queue   43
# Step  426  reward   -939.0  queue   39
# Step  427  reward  -1047.0  queue   39
# Step  428  reward   -906.0  queue   41
# Step  429  reward  -1035.0  queue   47
# Step  430  reward   -993.0  queue   37
# Step  431  reward   -945.0  queue   34
# Step  432  reward   -957.0  queue   37
# Step  433  reward   -963.0  queue   36
# Step  434  reward  -1080.0  queue   44
# Step  435  reward  -1227.0  queue   52
# Step  436  reward  -1299.0  queue   55
# Step  437  reward  -1251.0  queue   47
# Step  438  reward  -1101.0  queue   37
# Step  439  reward  -1071.0  queue   37
# Step  440  reward  -1032.0  queue   33
# Step  441  reward  -1146.0  queue   36
# Step  442  reward  -1116.0  queue   40
# Step  443  reward  -1140.0  queue   42
# Step  444  reward  -1200.0  queue   42
# Step  445  reward  -1368.0  queue   38
# Step  446  reward  -1536.0  queue   43
# Step  447  reward  -1485.0  queue   49
# Step  448  reward  -1152.0  queue   42
# Step  449  reward   -894.0  queue   43
# Step  450  reward   -978.0  queue   41
# Step  451  reward   -909.0  queue   42
# Step  452  reward   -972.0  queue   42
# Step  453  reward  -1074.0  queue   43
# Step  454  reward  -1137.0  queue   43
# Step  455  reward  -1134.0  queue   40
# Step  456  reward  -1188.0  queue   42
# Step  457  reward  -1137.0  queue   44
# Step  458  reward  -1080.0  queue   39
# Step  459  reward  -1050.0  queue   42
# Step  460  reward  -1020.0  queue   37
# Step  461  reward   -999.0  queue   39
# Step  462  reward  -1071.0  queue   42
# Step  463  reward  -1254.0  queue   50
# Step  464  reward  -1239.0  queue   44
# Step  465  reward  -1257.0  queue   39
# Step  466  reward  -1164.0  queue   38
# Step  467  reward  -1074.0  queue   38
# Step  468  reward   -936.0  queue   38
# Step  469  reward   -735.0  queue   36
# Step  470  reward   -624.0  queue   29
# Step  471  reward   -636.0  queue   31
# Step  472  reward   -594.0  queue   31
# Step  473  reward   -561.0  queue   34
# Step  474  reward   -579.0  queue   33
# Step  475  reward   -567.0  queue   29
# Step  476  reward   -594.0  queue   29
# Step  477  reward   -765.0  queue   34
# Step  478  reward   -951.0  queue   43
# Step  479  reward  -1005.0  queue   42
# Step  480  reward   -912.0  queue   37
# Step  481  reward   -885.0  queue   34
# Step  482  reward   -867.0  queue   39
# Step  483  reward   -819.0  queue   44
# Step  484  reward   -807.0  queue   42
# Step  485  reward   -909.0  queue   42
# Step  486  reward  -1056.0  queue   45
# Step  487  reward  -1182.0  queue   50
# Step  488  reward  -1200.0  queue   44
# Step  489  reward  -1092.0  queue   34
# Step  490  reward  -1152.0  queue   33
# Step  491  reward  -1242.0  queue   40
# Step  492  reward  -1275.0  queue   42
# Step  493  reward  -1221.0  queue   36
# Step  494  reward  -1047.0  queue   34
# Step  495  reward   -930.0  queue   34
# Step  496  reward   -849.0  queue   36
# Step  497  reward   -975.0  queue   39
# Step  498  reward  -1107.0  queue   41
# Step  499  reward  -1131.0  queue   43
# Step  500  reward   -999.0  queue   33
# Step  501  reward   -831.0  queue   28
# Step  502  reward   -792.0  queue   29
# Step  503  reward   -804.0  queue   30
# Step  504  reward   -951.0  queue   35
# Step  505  reward  -1005.0  queue   35
# Step  506  reward   -876.0  queue   41
# Step  507  reward  -1050.0  queue   41
# Step  508  reward  -1077.0  queue   41
# Step  509  reward  -1131.0  queue   37
# Step  510  reward  -1146.0  queue   42
# Step  511  reward  -1200.0  queue   44
# Step  512  reward  -1341.0  queue   46
# Step  513  reward  -1302.0  queue   38
# Step  514  reward  -1083.0  queue   39
# Step  515  reward  -1032.0  queue   40
# Step  516  reward  -1158.0  queue   41
# Step  517  reward  -1158.0  queue   38
# Step  518  reward  -1221.0  queue   41
# Step  519  reward  -1359.0  queue   41
# Step  520  reward  -1206.0  queue   40
# Step  521  reward   -957.0  queue   36
# Step  522  reward   -813.0  queue   33
# Step  523  reward   -807.0  queue   38
# Step  524  reward   -726.0  queue   35
# Step  525  reward   -648.0  queue   36
# Step  526  reward   -702.0  queue   28
# Step  527  reward   -810.0  queue   32
# Step  528  reward   -858.0  queue   40
# Step  529  reward   -882.0  queue   40
# Step  530  reward  -1008.0  queue   45
# Step  531  reward  -1149.0  queue   47
# Step  532  reward  -1176.0  queue   46
# Step  533  reward  -1206.0  queue   48
# Step  534  reward  -1089.0  queue   38
# Step  535  reward   -993.0  queue   37
# Step  536  reward  -1011.0  queue   40
# Step  537  reward  -1023.0  queue   40
# Step  538  reward  -1041.0  queue   37
# Step  539  reward  -1008.0  queue   40
# Step  540  reward  -1056.0  queue   42
# Step  541  reward  -1038.0  queue   40
# Step  542  reward   -789.0  queue   30
# Step  543  reward   -684.0  queue   31
# Step  544  reward   -639.0  queue   30
# Step  545  reward   -522.0  queue   31
# Step  546  reward   -540.0  queue   35
# Step  547  reward   -558.0  queue   32
# Step  548  reward   -486.0  queue   28
# Step  549  reward   -510.0  queue   30
# Step  550  reward   -576.0  queue   30
# Step  551  reward   -699.0  queue   37
# Step  552  reward   -873.0  queue   43
# Step  553  reward  -1149.0  queue   49
# Step  554  reward  -1233.0  queue   48
# Step  555  reward  -1389.0  queue   55
# Step  556  reward  -1575.0  queue   54
# Step  557  reward  -1491.0  queue   46
# Step  558  reward  -1407.0  queue   42
# Step  559  reward  -1458.0  queue   44
# Step  560  reward  -1323.0  queue   40
# Step  561  reward  -1359.0  queue   45
# Step  562  reward  -1296.0  queue   43
# Step  563  reward  -1143.0  queue   38
# Step  564  reward   -936.0  queue   34
# Step  565  reward   -948.0  queue   33
# Step  566  reward   -945.0  queue   35
# Step  567  reward   -918.0  queue   34
# Step  568  reward   -972.0  queue   38
# Step  569  reward   -987.0  queue   40
# Step  570  reward  -1014.0  queue   39
# Step  571  reward  -1104.0  queue   47
# Step  572  reward  -1038.0  queue   43
# Step  573  reward  -1035.0  queue   38
# Step  574  reward   -912.0  queue   40
# Step  575  reward  -1020.0  queue   40
# Step  576  reward   -966.0  queue   42
# Step  577  reward  -1065.0  queue   43
# Step  578  reward  -1053.0  queue   39
# Step  579  reward   -876.0  queue   36
# Step  580  reward   -750.0  queue   31
# Step  581  reward   -579.0  queue   32
# Step  582  reward   -606.0  queue   35
# Step  583  reward   -615.0  queue   33
# Step  584  reward   -579.0  queue   29
# Step  585  reward   -630.0  queue   30
# Step  586  reward   -672.0  queue   35
# Step  587  reward   -864.0  queue   39
# Step  588  reward  -1062.0  queue   48
# Step  589  reward  -1230.0  queue   52
# Step  590  reward  -1194.0  queue   48
# Step  591  reward  -1233.0  queue   46
# Step  592  reward  -1134.0  queue   39
# Step  593  reward  -1092.0  queue   36
# Step  594  reward  -1035.0  queue   37
# Step  595  reward  -1044.0  queue   41
# Step  596  reward  -1044.0  queue   40
# Step  597  reward   -930.0  queue   42
# Step  598  reward   -816.0  queue   36
# Step  599  reward   -867.0  queue   43
# Step  600  reward   -909.0  queue   42
# Step  601  reward  -1086.0  queue   46
# Step  602  reward  -1260.0  queue   48
# Step  603  reward  -1302.0  queue   45
# Step  604  reward  -1353.0  queue   46
# Step  605  reward  -1368.0  queue   44
# Step  606  reward  -1485.0  queue   47
# Step  607  reward  -1566.0  queue   51
# Step  608  reward  -1533.0  queue   52
# Step  609  reward  -1542.0  queue   49
# Step  610  reward  -1569.0  queue   46
# Step  611  reward  -1644.0  queue   49
# Step  612  reward  -1701.0  queue   58
# Step  613  reward  -1863.0  queue   58
# Step  614  reward  -2040.0  queue   54
# Step  615  reward  -2151.0  queue   60
# Step  616  reward  -2199.0  queue   58
# Step  617  reward  -2151.0  queue   50
# Step  618  reward  -1884.0  queue   47
# Step  619  reward  -1737.0  queue   48
# Step  620  reward  -1476.0  queue   39
# Step  621  reward  -1368.0  queue   35
# Step  622  reward  -1335.0  queue   39
# Step  623  reward  -1242.0  queue   45
# Step  624  reward  -1248.0  queue   47
# Step  625  reward  -1452.0  queue   51
# Step  626  reward  -1539.0  queue   50
# Step  627  reward  -1503.0  queue   48
# Step  628  reward  -1584.0  queue   52
# Step  629  reward  -1680.0  queue   46
# Step  630  reward  -1581.0  queue   41
# Step  631  reward  -1620.0  queue   40
# Step  632  reward  -1779.0  queue   49
# Step  633  reward  -1785.0  queue   51
# Step  634  reward  -1809.0  queue   53
# Step  635  reward  -1521.0  queue   50
# Step  636  reward  -1359.0  queue   46
# Step  637  reward  -1305.0  queue   50
# Step  638  reward  -1317.0  queue   51
# Step  639  reward  -1083.0  queue   46
# Step  640  reward   -984.0  queue   45
# Step  641  reward   -948.0  queue   39
# Step  642  reward   -957.0  queue   41
# Step  643  reward   -963.0  queue   46
# Step  644  reward   -888.0  queue   49
# Step  645  reward   -873.0  queue   44
# Step  646  reward   -735.0  queue   33
# Step  647  reward   -711.0  queue   34
# Step  648  reward   -678.0  queue   32
# Step  649  reward   -660.0  queue   34
# Step  650  reward   -762.0  queue   38
# Step  651  reward   -891.0  queue   43
# Step  652  reward  -1005.0  queue   42
# Step  653  reward  -1152.0  queue   48
# Step  654  reward  -1194.0  queue   48
# Step  655  reward  -1194.0  queue   47
# Step  656  reward  -1185.0  queue   55
# Step  657  reward  -1056.0  queue   48
# Step  658  reward  -1086.0  queue   47
# Step  659  reward  -1158.0  queue   43
# Step  660  reward  -1152.0  queue   45
# Step  661  reward  -1131.0  queue   45
# Step  662  reward   -954.0  queue   39
# Step  663  reward   -786.0  queue   43
# Step  664  reward   -744.0  queue   38
# Step  665  reward   -801.0  queue   39
# Step  666  reward   -807.0  queue   40
# Step  667  reward   -762.0  queue   38
# Step  668  reward   -765.0  queue   37
# Step  669  reward   -813.0  queue   43
# Step  670  reward   -822.0  queue   43
# Step  671  reward   -732.0  queue   44
# Step  672  reward   -747.0  queue   44
# Step  673  reward   -882.0  queue   43
# Step  674  reward   -723.0  queue   36
# Step  675  reward   -684.0  queue   40
# Step  676  reward   -642.0  queue   44
# Step  677  reward   -603.0  queue   44
# Step  678  reward   -549.0  queue   37
# Step  679  reward   -567.0  queue   31
# Step  680  reward   -552.0  queue   34
# Step  681  reward   -576.0  queue   41
# Step  682  reward   -504.0  queue   38
# Step  683  reward   -510.0  queue   35
# Step  684  reward   -621.0  queue   36
# Step  685  reward   -765.0  queue   48
# Step  686  reward   -987.0  queue   55
# Step  687  reward  -1047.0  queue   51
# Step  688  reward  -1146.0  queue   46
# Step  689  reward  -1326.0  queue   54
# Step  690  reward  -1380.0  queue   55
# Step  691  reward  -1365.0  queue   49
# Step  692  reward  -1368.0  queue   53
# Step  693  reward  -1461.0  queue   57
# Step  694  reward  -1731.0  queue   62
# Step  695  reward  -1848.0  queue   61
# Step  696  reward  -2031.0  queue   59
# Step  697  reward  -1794.0  queue   56
# Step  698  reward  -1560.0  queue   47
# Step  699  reward  -1269.0  queue   43
# Step  700  reward  -1095.0  queue   39
# Step  701  reward   -951.0  queue   42
# Step  702  reward   -939.0  queue   44
# Step  703  reward  -1011.0  queue   44
# Step  704  reward  -1023.0  queue   41
# Step  705  reward  -1173.0  queue   45
# Step  706  reward  -1305.0  queue   47
# Step  707  reward  -1389.0  queue   50
# Step  708  reward  -1488.0  queue   57
# Step  709  reward  -1599.0  queue   57
# Step  710  reward  -1632.0  queue   54
# Step  711  reward  -1416.0  queue   46
# Step  712  reward  -1221.0  queue   46
# Step  713  reward  -1137.0  queue   36
# Step  714  reward  -1083.0  queue   32
# Step  715  reward   -825.0  queue   24
# Step  716  reward   -870.0  queue   27
# Step  717  reward   -876.0  queue   30
# Step  718  reward   -825.0  queue   36
# Step  719  reward   -669.0  queue   36
# Step  720  reward   -579.0  queue   31
# Step  721  reward   -672.0  queue   33
# Step  722  reward   -885.0  queue   39
# Step  723  reward   -996.0  queue   36
# Step  724  reward  -1080.0  queue   37
# Step  725  reward  -1335.0  queue   43
# Step  726  reward  -1473.0  queue   52
# Step  727  reward  -1425.0  queue   48
# Step  728  reward  -1467.0  queue   45
# Step  729  reward  -1752.0  queue   52
# Step  730  reward  -1557.0  queue   51
# Step  731  reward  -1278.0  queue   47
# Step  732  reward  -1146.0  queue   43
# Step  733  reward  -1068.0  queue   39
# Step  734  reward   -834.0  queue   43
# Step  735  reward   -612.0  queue   37
# Step  736  reward   -534.0  queue   35
# Step  737  reward   -573.0  queue   39
# Step  738  reward   -675.0  queue   38
# Step  739  reward   -708.0  queue   38
# Step  740  reward   -681.0  queue   39
# Step  741  reward   -687.0  queue   38
# Step  742  reward   -807.0  queue   42
# Step  743  reward   -705.0  queue   46
# Step  744  reward   -765.0  queue   41
# Step  745  reward   -912.0  queue   42
# Step  746  reward   -789.0  queue   43
# Step  747  reward   -780.0  queue   42
# Step  748  reward   -873.0  queue   42
# Step  749  reward   -915.0  queue   47
# Step  750  reward   -993.0  queue   49
# Step  751  reward  -1164.0  queue   52
# Step  752  reward  -1092.0  queue   53
# Step  753  reward  -1095.0  queue   48
# Step  754  reward   -918.0  queue   42
# Step  755  reward   -789.0  queue   42
# Step  756  reward   -759.0  queue   42
# Step  757  reward   -825.0  queue   47
# Step  758  reward   -816.0  queue   49
# Step  759  reward   -735.0  queue   42
# Step  760  reward   -831.0  queue   45
# Step  761  reward   -918.0  queue   47
# Step  762  reward   -957.0  queue   39
# Step  763  reward   -774.0  queue   42
# Step  764  reward   -603.0  queue   34
# Step  765  reward   -747.0  queue   35
# Step  766  reward   -717.0  queue   40
# Step  767  reward   -738.0  queue   44
# Step  768  reward   -822.0  queue   44
# Step  769  reward   -966.0  queue   47
# Step  770  reward  -1077.0  queue   55
# Step  771  reward  -1164.0  queue   52
# Step  772  reward  -1290.0  queue   53
# Step  773  reward  -1419.0  queue   57
# Step  774  reward  -1395.0  queue   52
# Step  775  reward  -1398.0  queue   51
# Step  776  reward  -1299.0  queue   49
# Step  777  reward  -1428.0  queue   47
# Step  778  reward  -1482.0  queue   53
# Step  779  reward  -1344.0  queue   43
# Step  780  reward  -1278.0  queue   43
# Step  781  reward  -1404.0  queue   41
# Step  782  reward  -1509.0  queue   49
# Step  783  reward  -1698.0  queue   53
# Step  784  reward  -1983.0  queue   58
# Step  785  reward  -2229.0  queue   58
# Step  786  reward  -2427.0  queue   58
# Step  787  reward  -2409.0  queue   47
# Step  788  reward  -2610.0  queue   54
# Step  789  reward  -2718.0  queue   51
# Step  790  reward  -2856.0  queue   48
# Step  791  reward  -2856.0  queue   47
# Step  792  reward  -2931.0  queue   49
# Step  793  reward  -3045.0  queue   47
# Step  794  reward  -2976.0  queue   45
# Step  795  reward  -2964.0  queue   49
# Step  796  reward  -2748.0  queue   49
# Step  797  reward  -2511.0  queue   49
# Step  798  reward  -2391.0  queue   53
# Step  799  reward  -2499.0  queue   54
# Step  800  reward  -2070.0  queue   52
# Step  801  reward  -1776.0  queue   46
# Step  802  reward  -1578.0  queue   47
# Step  803  reward  -1602.0  queue   47
# Step  804  reward  -1710.0  queue   49
# Step  805  reward  -1548.0  queue   53
# Step  806  reward  -1407.0  queue   53
# Step  807  reward  -1668.0  queue   61
# Step  808  reward  -1650.0  queue   59
# Step  809  reward  -1665.0  queue   61
# Step  810  reward  -1812.0  queue   64
# Step  811  reward  -1662.0  queue   59
# Step  812  reward  -1701.0  queue   65
# Step  813  reward  -1611.0  queue   59
# Step  814  reward  -1326.0  queue   48
# Step  815  reward  -1344.0  queue   50
# Step  816  reward  -1263.0  queue   50
# Step  817  reward  -1209.0  queue   48
# Step  818  reward  -1428.0  queue   55
# Step  819  reward  -1695.0  queue   57
# Step  820  reward  -1863.0  queue   59
# Step  821  reward  -2160.0  queue   64
# Step  822  reward  -2205.0  queue   60
# Step  823  reward  -2262.0  queue   65
# Step  824  reward  -2208.0  queue   58
# Step  825  reward  -2130.0  queue   55
# Step  826  reward  -2076.0  queue   54
# Step  827  reward  -1932.0  queue   54
# Step  828  reward  -2061.0  queue   56
# Step  829  reward  -1974.0  queue   63
# Step  830  reward  -1788.0  queue   60
# Step  831  reward  -1428.0  queue   55
# Step  832  reward  -1101.0  queue   42
# Step  833  reward   -969.0  queue   39
# Step  834  reward  -1092.0  queue   46
# Step  835  reward  -1200.0  queue   54
# Step  836  reward  -1299.0  queue   58
# Step  837  reward  -1254.0  queue   59
# Step  838  reward  -1263.0  queue   60
# Step  839  reward  -1422.0  queue   67
# Step  840  reward  -1374.0  queue   65
# Step  841  reward  -1464.0  queue   63
# Step  842  reward  -1713.0  queue   67
# Step  843  reward  -1764.0  queue   67
# Step  844  reward  -1764.0  queue   70
# Step  845  reward  -1740.0  queue   62
# Step  846  reward  -1572.0  queue   57
# Step  847  reward  -1485.0  queue   58
# Step  848  reward  -1332.0  queue   48
# Step  849  reward  -1395.0  queue   44
# Step  850  reward  -1368.0  queue   45
# Step  851  reward  -1341.0  queue   47
# Step  852  reward  -1437.0  queue   53
# Step  853  reward  -1521.0  queue   56
# Step  854  reward  -1683.0  queue   64
# Step  855  reward  -1740.0  queue   61
# Step  856  reward  -1749.0  queue   56
# Step  857  reward  -1758.0  queue   59
# Step  858  reward  -1776.0  queue   59
# Step  859  reward  -1860.0  queue   66
# Step  860  reward  -2133.0  queue   68
# Step  861  reward  -2283.0  queue   68
# Step  862  reward  -2103.0  queue   61
# Step  863  reward  -2109.0  queue   59
# Step  864  reward  -2298.0  queue   63
# Step  865  reward  -2337.0  queue   64
# Step  866  reward  -2283.0  queue   69
# Step  867  reward  -2292.0  queue   65
# Step  868  reward  -2301.0  queue   71
# Step  869  reward  -2118.0  queue   68
# Step  870  reward  -1821.0  queue   63
# Step  871  reward  -1983.0  queue   67
# Step  872  reward  -1917.0  queue   69
# Step  873  reward  -1896.0  queue   66
# Step  874  reward  -1932.0  queue   67
# Step  875  reward  -1833.0  queue   62
# Step  876  reward  -1707.0  queue   62
# Step  877  reward  -1320.0  queue   49
# Step  878  reward  -1257.0  queue   53
# Step  879  reward  -1224.0  queue   53
# Step  880  reward  -1236.0  queue   57
# Step  881  reward  -1284.0  queue   55
# Step  882  reward  -1299.0  queue   51
# Step  883  reward  -1461.0  queue   65
# Step  884  reward  -1491.0  queue   64
# Step  885  reward  -1443.0  queue   57
# Step  886  reward  -1380.0  queue   56
# Step  887  reward  -1293.0  queue   50
# Step  888  reward   -930.0  queue   43
# Step  889  reward  -1053.0  queue   56
# Step  890  reward  -1104.0  queue   62
# Step  891  reward  -1188.0  queue   59
# Step  892  reward  -1359.0  queue   67
# Step  893  reward  -1404.0  queue   63
# Step  894  reward  -1410.0  queue   62
# Step  895  reward  -1629.0  queue   69
# Step  896  reward  -1659.0  queue   70
# Step  897  reward  -1641.0  queue   66
# Step  898  reward  -1770.0  queue   64
# Step  899  reward  -1935.0  queue   68
# Step  900  reward  -2058.0  queue   66
# Step  901  reward  -2046.0  queue   75
# Step  902  reward  -2067.0  queue   78
# Step  903  reward  -1869.0  queue   71
# Step  904  reward  -1761.0  queue   67
# Step  905  reward  -1731.0  queue   67
# Step  906  reward  -1671.0  queue   69
# Step  907  reward  -1695.0  queue   66
# Step  908  reward  -1686.0  queue   70
# Step  909  reward  -1782.0  queue   73
# Step  910  reward  -1791.0  queue   70
# Step  911  reward  -1752.0  queue   66
# Step  912  reward  -1611.0  queue   58
# Step  913  reward  -1770.0  queue   67
# Step  914  reward  -1950.0  queue   71
# Step  915  reward  -1983.0  queue   71
# Step  916  reward  -2115.0  queue   70
# Step  917  reward  -2433.0  queue   74
# Step  918  reward  -2586.0  queue   73
# Step  919  reward  -2688.0  queue   69
# Step  920  reward  -2733.0  queue   71
# Step  921  reward  -2781.0  queue   71
# Step  922  reward  -2853.0  queue   78
# Step  923  reward  -3045.0  queue   80
# Step  924  reward  -3042.0  queue   80
# Step  925  reward  -2799.0  queue   74
# Step  926  reward  -2784.0  queue   72
# Step  927  reward  -2616.0  queue   66
# Step  928  reward  -2307.0  queue   62
# Step  929  reward  -2118.0  queue   59
# Step  930  reward  -1893.0  queue   63
# Step  931  reward  -1863.0  queue   67
# Step  932  reward  -1683.0  queue   64
# Step  933  reward  -1746.0  queue   65
# Step  934  reward  -1686.0  queue   61
# Step  935  reward  -1743.0  queue   66
# Step  936  reward  -1722.0  queue   66
# Step  937  reward  -1548.0  queue   64
# Step  938  reward  -1494.0  queue   65
# Step  939  reward  -1659.0  queue   66
# Step  940  reward  -1809.0  queue   69
# Step  941  reward  -1863.0  queue   70
# Step  942  reward  -1779.0  queue   64
# Step  943  reward  -1716.0  queue   65
# Step  944  reward  -1719.0  queue   65
# Step  945  reward  -1521.0  queue   65
# Step  946  reward  -1599.0  queue   62
# Step  947  reward  -1449.0  queue   58
# Step  948  reward  -1314.0  queue   52
# Step  949  reward  -1338.0  queue   50
# Step  950  reward  -1401.0  queue   47
# Step  951  reward  -1479.0  queue   50
# Step  952  reward  -1482.0  queue   59
# Step  953  reward  -1509.0  queue   59
# Step  954  reward  -1335.0  queue   57
# Step  955  reward  -1194.0  queue   61
# Step  956  reward  -1353.0  queue   66
# Step  957  reward  -1566.0  queue   73
# Step  958  reward  -1542.0  queue   69
# Step  959  reward  -1533.0  queue   62
# Step  960  reward  -1539.0  queue   60
# Step  961  reward  -1482.0  queue   61
# Step  962  reward  -1350.0  queue   59
# Step  963  reward  -1317.0  queue   58
# Step  964  reward  -1296.0  queue   55
# Step  965  reward  -1170.0  queue   47
# Step  966  reward  -1125.0  queue   48
# Step  967  reward  -1206.0  queue   56
# Step  968  reward  -1305.0  queue   53
# Step  969  reward  -1431.0  queue   52
# Step  970  reward  -1449.0  queue   49
# Step  971  reward  -1416.0  queue   55
# Step  972  reward  -1482.0  queue   64
# Step  973  reward  -1590.0  queue   61
# Step  974  reward  -1632.0  queue   66
# Step  975  reward  -1566.0  queue   54
# Step  976  reward  -1656.0  queue   57
# Step  977  reward  -1605.0  queue   65
# Step  978  reward  -1755.0  queue   68
# Step  979  reward  -1725.0  queue   68
# Step  980  reward  -1536.0  queue   57
# Step  981  reward  -1548.0  queue   66
# Step  982  reward  -1482.0  queue   63
# Step  983  reward  -1374.0  queue   56
# Step  984  reward  -1359.0  queue   60
# Step  985  reward  -1476.0  queue   62
# Step  986  reward  -1551.0  queue   63
# Step  987  reward  -1590.0  queue   65
# Step  988  reward  -1578.0  queue   59
# Step  989  reward  -1314.0  queue   55
# Step  990  reward  -1296.0  queue   58
# Step  991  reward  -1311.0  queue   56
# Step  992  reward  -1329.0  queue   58
# Step  993  reward  -1353.0  queue   61
# Step  994  reward  -1242.0  queue   49
# Step  995  reward  -1410.0  queue   49
# Step  996  reward  -1350.0  queue   51
# Step  997  reward  -1332.0  queue   50
# Step  998  reward  -1245.0  queue   54
# Step  999  reward  -1263.0  queue   51
# Environment signaled done at step 1000
#
# === Evaluation Summary ===
# Total steps executed       : 999
# Total reward accumulated   : -1000179.0
# Vehicles arrived           : 2535
# Active vehicles remaining  : 580
# Avg waiting time/vehicle   : 14.93 s
# Avg travel time (all)      : 156.56 s

# %%
import gym
import cityflow
import gym_cityflow
import numpy as np

# 1) make your env
env = gym.make(
    id='cityflow-v0',
    configPath='Intersections_4/sample_config.json',
    episodeSteps=1000
)

# 2) reset
raw_obs = env.reset()

# 3) initialize trackers
total_reward     = 0.0
step_rewards     = []
waiting_per_step = []

# track arrivals via set-difference
prev_vehicles    = set(env.eng.get_vehicles(include_waiting=True))
arrived_vehicles = set()

# record initial queue length
waiting_dict     = env.eng.get_lane_waiting_vehicle_count()
waiting_per_step.append(sum(waiting_dict.values()))

# 4) run random actions
for t in range(1000):
    action = env.action_space.sample()
    _, reward, done, _ = env.step(action)

    # sum and record this step's reward
    step_r = sum(r for _, r in reward)
    step_rewards.append(step_r)
    total_reward += step_r
    print(f"Step {t+1:4d} | Reward {step_r:8.1f}")

    # detect arrivals
    cur_vehicles = set(env.eng.get_vehicles(include_waiting=True))
    new_arrs     = prev_vehicles - cur_vehicles
    arrived_vehicles |= new_arrs
    prev_vehicles = cur_vehicles

    # record queue length
    waiting_dict     = env.eng.get_lane_waiting_vehicle_count()
    waiting_per_step.append(sum(waiting_dict.values()))

    if done:
        break

# 5) compute random-policy metrics
num_arrived      = len(arrived_vehicles)
total_wait_time  = sum(waiting_per_step)                 # vehicle-seconds
avg_wait_per_car = total_wait_time / num_arrived if num_arrived>0 else float('nan')
avg_travel_time  = env.eng.get_average_travel_time()     # overall average travel time
active_vehicles  = env.eng.get_vehicle_count()           # vehicles still in sim

# 6) print summary
print("\n=== Random Policy Metrics ===")
print(f"Total steps executed      : {t+1}")
print(f"Total reward accumulated  : {total_reward:.1f}")
print(f"Vehicles completed routes : {num_arrived}")
print(f"Still active vehicles     : {active_vehicles}")
print(f"Avg waiting time per car  : {avg_wait_per_car:.2f} s")
print(f"Avg travel time           : {avg_travel_time:.2f} s")

# 7) cleanup
env.close()
# Out:
# Step    1 | Reward      0.0
# Step    2 | Reward      0.0
# Step    3 | Reward      0.0
# Step    4 | Reward      0.0
# Step    5 | Reward      0.0
# Step    6 | Reward      0.0
# Step    7 | Reward      0.0
# Step    8 | Reward      0.0
# Step    9 | Reward      0.0
# Step   10 | Reward      0.0
# Step   11 | Reward      0.0
# Step   12 | Reward      0.0
# Step   13 | Reward      0.0
# Step   14 | Reward      0.0
# Step   15 | Reward      0.0
# Step   16 | Reward      0.0
# Step   17 | Reward      0.0
# Step   18 | Reward      0.0
# Step   19 | Reward      0.0
# Step   20 | Reward      0.0
# Step   21 | Reward      0.0
# Step   22 | Reward      0.0
# Step   23 | Reward      0.0
# Step   24 | Reward      0.0
# Step   25 | Reward      0.0
# Step   26 | Reward      0.0
# Step   27 | Reward      0.0
# Step   28 | Reward      0.0
# Step   29 | Reward      0.0
# Step   30 | Reward    -12.0
# Step   31 | Reward    -60.0
# Step   32 | Reward   -123.0
# Step   33 | Reward   -168.0
# Step   34 | Reward   -195.0
# Step   35 | Reward   -198.0
# Step   36 | Reward   -234.0
# Step   37 | Reward   -225.0
# Step   38 | Reward   -279.0
# Step   39 | Reward   -288.0
# Step   40 | Reward   -195.0
# Step   41 | Reward   -228.0
# Step   42 | Reward   -324.0
# Step   43 | Reward   -336.0
# Step   44 | Reward   -354.0
# Step   45 | Reward   -375.0
# Step   46 | Reward   -345.0
# Step   47 | Reward   -273.0
# Step   48 | Reward   -297.0
# Step   49 | Reward   -267.0
# Step   50 | Reward   -267.0
# Step   51 | Reward   -354.0
# Step   52 | Reward   -417.0
# Step   53 | Reward   -480.0
# Step   54 | Reward   -483.0
# Step   55 | Reward   -540.0
# Step   56 | Reward   -591.0
# Step   57 | Reward   -657.0
# Step   58 | Reward   -714.0
# Step   59 | Reward   -798.0
# Step   60 | Reward   -855.0
# Step   61 | Reward   -957.0
# Step   62 | Reward  -1050.0
# Step   63 | Reward  -1125.0
# Step   64 | Reward  -1284.0
# Step   65 | Reward  -1461.0
# Step   66 | Reward  -1623.0
# Step   67 | Reward  -1710.0
# Step   68 | Reward  -1740.0
# Step   69 | Reward  -1815.0
# Step   70 | Reward  -1785.0
# Step   71 | Reward  -1797.0
# Step   72 | Reward  -1899.0
# Step   73 | Reward  -1794.0
# Step   74 | Reward  -1833.0
# Step   75 | Reward  -1731.0
# Step   76 | Reward  -1524.0
# Step   77 | Reward  -1596.0
# Step   78 | Reward  -1506.0
# Step   79 | Reward  -1224.0
# Step   80 | Reward  -1293.0
# Step   81 | Reward  -1086.0
# Step   82 | Reward   -945.0
# Step   83 | Reward   -882.0
# Step   84 | Reward   -849.0
# Step   85 | Reward   -903.0
# Step   86 | Reward   -774.0
# Step   87 | Reward   -618.0
# Step   88 | Reward   -498.0
# Step   89 | Reward   -534.0
# Step   90 | Reward   -465.0
# Step   91 | Reward   -549.0
# Step   92 | Reward   -636.0
# Step   93 | Reward   -654.0
# Step   94 | Reward   -720.0
# Step   95 | Reward   -783.0
# Step   96 | Reward   -936.0
# Step   97 | Reward  -1077.0
# Step   98 | Reward  -1086.0
# Step   99 | Reward  -1050.0
# Step  100 | Reward   -996.0
# Step  101 | Reward  -1173.0
# Step  102 | Reward  -1044.0
# Step  103 | Reward  -1026.0
# Step  104 | Reward   -987.0
# Step  105 | Reward  -1143.0
# Step  106 | Reward  -1212.0
# Step  107 | Reward  -1152.0
# Step  108 | Reward  -1194.0
# Step  109 | Reward  -1326.0
# Step  110 | Reward  -1449.0
# Step  111 | Reward  -1506.0
# Step  112 | Reward  -1497.0
# Step  113 | Reward  -1296.0
# Step  114 | Reward  -1119.0
# Step  115 | Reward  -1218.0
# Step  116 | Reward  -1278.0
# Step  117 | Reward  -1503.0
# Step  118 | Reward  -1602.0
# Step  119 | Reward  -1449.0
# Step  120 | Reward  -1398.0
# Step  121 | Reward  -1383.0
# Step  122 | Reward  -1278.0
# Step  123 | Reward  -1338.0
# Step  124 | Reward  -1245.0
# Step  125 | Reward  -1074.0
# Step  126 | Reward  -1011.0
# Step  127 | Reward  -1017.0
# Step  128 | Reward  -1200.0
# Step  129 | Reward  -1299.0
# Step  130 | Reward  -1434.0
# Step  131 | Reward  -1725.0
# Step  132 | Reward  -1911.0
# Step  133 | Reward  -1989.0
# Step  134 | Reward  -2070.0
# Step  135 | Reward  -2034.0
# Step  136 | Reward  -2049.0
# Step  137 | Reward  -2154.0
# Step  138 | Reward  -2103.0
# Step  139 | Reward  -2307.0
# Step  140 | Reward  -2091.0
# Step  141 | Reward  -1782.0
# Step  142 | Reward  -1629.0
# Step  143 | Reward  -1548.0
# Step  144 | Reward  -1638.0
# Step  145 | Reward  -1536.0
# Step  146 | Reward  -1398.0
# Step  147 | Reward  -1170.0
# Step  148 | Reward  -1278.0
# Step  149 | Reward  -1236.0
# Step  150 | Reward  -1266.0
# Step  151 | Reward  -1272.0
# Step  152 | Reward  -1302.0
# Step  153 | Reward  -1398.0
# Step  154 | Reward  -1506.0
# Step  155 | Reward  -1710.0
# Step  156 | Reward  -1563.0
# Step  157 | Reward  -1494.0
# Step  158 | Reward  -1596.0
# Step  159 | Reward  -1491.0
# Step  160 | Reward  -1617.0
# Step  161 | Reward  -1590.0
# Step  162 | Reward  -1371.0
# Step  163 | Reward  -1224.0
# Step  164 | Reward  -1203.0
# Step  165 | Reward  -1344.0
# Step  166 | Reward  -1440.0
# Step  167 | Reward  -1653.0
# Step  168 | Reward  -1848.0
# Step  169 | Reward  -2046.0
# Step  170 | Reward  -2292.0
# Step  171 | Reward  -2391.0
# Step  172 | Reward  -2337.0
# Step  173 | Reward  -2610.0
# Step  174 | Reward  -2817.0
# Step  175 | Reward  -3012.0
# Step  176 | Reward  -3165.0
# Step  177 | Reward  -3132.0
# Step  178 | Reward  -3168.0
# Step  179 | Reward  -3066.0
# Step  180 | Reward  -3108.0
# Step  181 | Reward  -2862.0
# Step  182 | Reward  -2880.0
# Step  183 | Reward  -2706.0
# Step  184 | Reward  -2511.0
# Step  185 | Reward  -2259.0
# Step  186 | Reward  -2226.0
# Step  187 | Reward  -2232.0
# Step  188 | Reward  -2046.0
# Step  189 | Reward  -2040.0
# Step  190 | Reward  -2028.0
# Step  191 | Reward  -2034.0
# Step  192 | Reward  -2268.0
# Step  193 | Reward  -2484.0
# Step  194 | Reward  -2475.0
# Step  195 | Reward  -2511.0
# Step  196 | Reward  -2484.0
# Step  197 | Reward  -2472.0
# Step  198 | Reward  -2634.0
# Step  199 | Reward  -2688.0
# Step  200 | Reward  -2670.0
# Step  201 | Reward  -2619.0
# Step  202 | Reward  -2652.0
# Step  203 | Reward  -2970.0
# Step  204 | Reward  -3078.0
# Step  205 | Reward  -2907.0
# Step  206 | Reward  -2832.0
# Step  207 | Reward  -2634.0
# Step  208 | Reward  -2775.0
# Step  209 | Reward  -2595.0
# Step  210 | Reward  -2457.0
# Step  211 | Reward  -2370.0
# Step  212 | Reward  -2118.0
# Step  213 | Reward  -2007.0
# Step  214 | Reward  -1953.0
# Step  215 | Reward  -1962.0
# Step  216 | Reward  -2205.0
# Step  217 | Reward  -2376.0
# Step  218 | Reward  -2295.0
# Step  219 | Reward  -2424.0
# Step  220 | Reward  -2301.0
# Step  221 | Reward  -2208.0
# Step  222 | Reward  -2157.0
# Step  223 | Reward  -2067.0
# Step  224 | Reward  -1926.0
# Step  225 | Reward  -2163.0
# Step  226 | Reward  -2298.0
# Step  227 | Reward  -2385.0
# Step  228 | Reward  -2529.0
# Step  229 | Reward  -2616.0
# Step  230 | Reward  -2739.0
# Step  231 | Reward  -2790.0
# Step  232 | Reward  -2724.0
# Step  233 | Reward  -2826.0
# Step  234 | Reward  -2958.0
# Step  235 | Reward  -2913.0
# Step  236 | Reward  -2817.0
# Step  237 | Reward  -2607.0
# Step  238 | Reward  -2238.0
# Step  239 | Reward  -2112.0
# Step  240 | Reward  -2460.0
# Step  241 | Reward  -2451.0
# Step  242 | Reward  -2451.0
# Step  243 | Reward  -2475.0
# Step  244 | Reward  -2439.0
# Step  245 | Reward  -2466.0
# Step  246 | Reward  -2568.0
# Step  247 | Reward  -2568.0
# Step  248 | Reward  -2568.0
# Step  249 | Reward  -2631.0
# Step  250 | Reward  -2655.0
# Step  251 | Reward  -2826.0
# Step  252 | Reward  -3126.0
# Step  253 | Reward  -3597.0
# Step  254 | Reward  -3960.0
# Step  255 | Reward  -4107.0
# Step  256 | Reward  -4323.0
# Step  257 | Reward  -4437.0
# Step  258 | Reward  -4404.0
# Step  259 | Reward  -4362.0
# Step  260 | Reward  -4077.0
# Step  261 | Reward  -3918.0
# Step  262 | Reward  -3750.0
# Step  263 | Reward  -3849.0
# Step  264 | Reward  -4242.0
# Step  265 | Reward  -3792.0
# Step  266 | Reward  -3501.0
# Step  267 | Reward  -3288.0
# Step  268 | Reward  -3246.0
# Step  269 | Reward  -2943.0
# Step  270 | Reward  -2874.0
# Step  271 | Reward  -2868.0
# Step  272 | Reward  -2868.0
# Step  273 | Reward  -2886.0
# Step  274 | Reward  -2655.0
# Step  275 | Reward  -2472.0
# Step  276 | Reward  -2427.0
# Step  277 | Reward  -2427.0
# Step  278 | Reward  -2751.0
# Step  279 | Reward  -2976.0
# Step  280 | Reward  -3339.0
# Step  281 | Reward  -3552.0
# Step  282 | Reward  -3786.0
# Step  283 | Reward  -3753.0
# Step  284 | Reward  -3867.0
# Step  285 | Reward  -3738.0
# Step  286 | Reward  -3555.0
# Step  287 | Reward  -3612.0
# Step  288 | Reward  -3411.0
# Step  289 | Reward  -3309.0
# Step  290 | Reward  -3165.0
# Step  291 | Reward  -3369.0
# Step  292 | Reward  -3753.0
# Step  293 | Reward  -4044.0
# Step  294 | Reward  -4284.0
# Step  295 | Reward  -4281.0
# Step  296 | Reward  -4146.0
# Step  297 | Reward  -3990.0
# Step  298 | Reward  -3879.0
# Step  299 | Reward  -3861.0
# Step  300 | Reward  -3942.0
# Step  301 | Reward  -3894.0
# Step  302 | Reward  -4047.0
# Step  303 | Reward  -3987.0
# Step  304 | Reward  -4173.0
# Step  305 | Reward  -4182.0
# Step  306 | Reward  -4323.0
# Step  307 | Reward  -4083.0
# Step  308 | Reward  -3963.0
# Step  309 | Reward  -4017.0
# Step  310 | Reward  -4023.0
# Step  311 | Reward  -4059.0
# Step  312 | Reward  -4122.0
# Step  313 | Reward  -4182.0
# Step  314 | Reward  -4515.0
# Step  315 | Reward  -4521.0
# Step  316 | Reward  -4164.0
# Step  317 | Reward  -4053.0
# Step  318 | Reward  -4125.0
# Step  319 | Reward  -4323.0
# Step  320 | Reward  -4425.0
# Step  321 | Reward  -4299.0
# Step  322 | Reward  -4254.0
# Step  323 | Reward  -4182.0
# Step  324 | Reward  -4296.0
# Step  325 | Reward  -4350.0
# Step  326 | Reward  -4422.0
# Step  327 | Reward  -4551.0
# Step  328 | Reward  -4560.0
# Step  329 | Reward  -4542.0
# Step  330 | Reward  -4632.0
# Step  331 | Reward  -4839.0
# Step  332 | Reward  -5025.0
# Step  333 | Reward  -5316.0
# Step  334 | Reward  -5313.0
# Step  335 | Reward  -5424.0
# Step  336 | Reward  -5706.0
# Step  337 | Reward  -5244.0
# Step  338 | Reward  -4812.0
# Step  339 | Reward  -4638.0
# Step  340 | Reward  -4443.0
# Step  341 | Reward  -4371.0
# Step  342 | Reward  -4377.0
# Step  343 | Reward  -4626.0
# Step  344 | Reward  -4683.0
# Step  345 | Reward  -4875.0
# Step  346 | Reward  -5061.0
# Step  347 | Reward  -5064.0
# Step  348 | Reward  -4992.0
# Step  349 | Reward  -5073.0
# Step  350 | Reward  -4965.0
# Step  351 | Reward  -4680.0
# Step  352 | Reward  -4179.0
# Step  353 | Reward  -4380.0
# Step  354 | Reward  -4308.0
# Step  355 | Reward  -4014.0
# Step  356 | Reward  -4089.0
# Step  357 | Reward  -3903.0
# Step  358 | Reward  -3555.0
# Step  359 | Reward  -3378.0
# Step  360 | Reward  -3525.0
# Step  361 | Reward  -3780.0
# Step  362 | Reward  -3786.0
# Step  363 | Reward  -3930.0
# Step  364 | Reward  -4002.0
# Step  365 | Reward  -3894.0
# Step  366 | Reward  -3765.0
# Step  367 | Reward  -3867.0
# Step  368 | Reward  -3966.0
# Step  369 | Reward  -4071.0
# Step  370 | Reward  -3999.0
# Step  371 | Reward  -3759.0
# Step  372 | Reward  -3732.0
# Step  373 | Reward  -3378.0
# Step  374 | Reward  -3339.0
# Step  375 | Reward  -3171.0
# Step  376 | Reward  -2976.0
# Step  377 | Reward  -3246.0
# Step  378 | Reward  -3288.0
# Step  379 | Reward  -3612.0
# Step  380 | Reward  -3573.0
# Step  381 | Reward  -3693.0
# Step  382 | Reward  -3789.0
# Step  383 | Reward  -3906.0
# Step  384 | Reward  -4209.0
# Step  385 | Reward  -4677.0
# Step  386 | Reward  -4860.0
# Step  387 | Reward  -5007.0
# Step  388 | Reward  -5010.0
# Step  389 | Reward  -5169.0
# Step  390 | Reward  -5391.0
# Step  391 | Reward  -5493.0
# Step  392 | Reward  -5496.0
# Step  393 | Reward  -5817.0
# Step  394 | Reward  -6012.0
# Step  395 | Reward  -6366.0
# Step  396 | Reward  -6807.0
# Step  397 | Reward  -7275.0
# Step  398 | Reward  -7122.0
# Step  399 | Reward  -6849.0
# Step  400 | Reward  -6606.0
# Step  401 | Reward  -6387.0
# Step  402 | Reward  -6510.0
# Step  403 | Reward  -5994.0
# Step  404 | Reward  -5517.0
# Step  405 | Reward  -5253.0
# Step  406 | Reward  -5208.0
# Step  407 | Reward  -5235.0
# Step  408 | Reward  -5253.0
# Step  409 | Reward  -5133.0
# Step  410 | Reward  -5289.0
# Step  411 | Reward  -5337.0
# Step  412 | Reward  -5190.0
# Step  413 | Reward  -4761.0
# Step  414 | Reward  -4521.0
# Step  415 | Reward  -4275.0
# Step  416 | Reward  -4380.0
# Step  417 | Reward  -4203.0
# Step  418 | Reward  -4158.0
# Step  419 | Reward  -3759.0
# Step  420 | Reward  -3573.0
# Step  421 | Reward  -3222.0
# Step  422 | Reward  -3102.0
# Step  423 | Reward  -3165.0
# Step  424 | Reward  -3060.0
# Step  425 | Reward  -3135.0
# Step  426 | Reward  -3264.0
# Step  427 | Reward  -3342.0
# Step  428 | Reward  -3321.0
# Step  429 | Reward  -3444.0
# Step  430 | Reward  -3372.0
# Step  431 | Reward  -3357.0
# Step  432 | Reward  -3420.0
# Step  433 | Reward  -3552.0
# Step  434 | Reward  -3708.0
# Step  435 | Reward  -3534.0
# Step  436 | Reward  -3609.0
# Step  437 | Reward  -3654.0
# Step  438 | Reward  -3633.0
# Step  439 | Reward  -3531.0
# Step  440 | Reward  -3528.0
# Step  441 | Reward  -3447.0
# Step  442 | Reward  -3609.0
# Step  443 | Reward  -3558.0
# Step  444 | Reward  -3672.0
# Step  445 | Reward  -3465.0
# Step  446 | Reward  -3417.0
# Step  447 | Reward  -3291.0
# Step  448 | Reward  -3261.0
# Step  449 | Reward  -3189.0
# Step  450 | Reward  -3261.0
# Step  451 | Reward  -3432.0
# Step  452 | Reward  -3450.0
# Step  453 | Reward  -3684.0
# Step  454 | Reward  -3591.0
# Step  455 | Reward  -3360.0
# Step  456 | Reward  -3291.0
# Step  457 | Reward  -3081.0
# Step  458 | Reward  -3123.0
# Step  459 | Reward  -3408.0
# Step  460 | Reward  -3555.0
# Step  461 | Reward  -3645.0
# Step  462 | Reward  -3705.0
# Step  463 | Reward  -3795.0
# Step  464 | Reward  -3933.0
# Step  465 | Reward  -3972.0
# Step  466 | Reward  -3702.0
# Step  467 | Reward  -3615.0
# Step  468 | Reward  -3912.0
# Step  469 | Reward  -3669.0
# Step  470 | Reward  -3594.0
# Step  471 | Reward  -3540.0
# Step  472 | Reward  -3510.0
# Step  473 | Reward  -3558.0
# Step  474 | Reward  -3555.0
# Step  475 | Reward  -3723.0
# Step  476 | Reward  -3837.0
# Step  477 | Reward  -3885.0
# Step  478 | Reward  -3879.0
# Step  479 | Reward  -3762.0
# Step  480 | Reward  -3759.0
# Step  481 | Reward  -3540.0
# Step  482 | Reward  -3351.0
# Step  483 | Reward  -3372.0
# Step  484 | Reward  -3318.0
# Step  485 | Reward  -3414.0
# Step  486 | Reward  -3561.0
# Step  487 | Reward  -3720.0
# Step  488 | Reward  -3870.0
# Step  489 | Reward  -4017.0
# Step  490 | Reward  -3882.0
# Step  491 | Reward  -3693.0
# Step  492 | Reward  -3414.0
# Step  493 | Reward  -3189.0
# Step  494 | Reward  -3435.0
# Step  495 | Reward  -3603.0
# Step  496 | Reward  -3852.0
# Step  497 | Reward  -4065.0
# Step  498 | Reward  -4227.0
# Step  499 | Reward  -4470.0
# Step  500 | Reward  -4860.0
# Step  501 | Reward  -5175.0
# Step  502 | Reward  -5334.0
# Step  503 | Reward  -5508.0
# Step  504 | Reward  -5772.0
# Step  505 | Reward  -6054.0
# Step  506 | Reward  -6177.0
# Step  507 | Reward  -6414.0
# Step  508 | Reward  -6630.0
# Step  509 | Reward  -6882.0
# Step  510 | Reward  -6753.0
# Step  511 | Reward  -6309.0
# Step  512 | Reward  -6282.0
# Step  513 | Reward  -6396.0
# Step  514 | Reward  -6276.0
# Step  515 | Reward  -6192.0
# Step  516 | Reward  -6093.0
# Step  517 | Reward  -6180.0
# Step  518 | Reward  -6153.0
# Step  519 | Reward  -6033.0
# Step  520 | Reward  -5787.0
# Step  521 | Reward  -5856.0
# Step  522 | Reward  -5313.0
# Step  523 | Reward  -5169.0
# Step  524 | Reward  -5010.0
# Step  525 | Reward  -5172.0
# Step  526 | Reward  -5061.0
# Step  527 | Reward  -5268.0
# Step  528 | Reward  -5727.0
# Step  529 | Reward  -5571.0
# Step  530 | Reward  -5505.0
# Step  531 | Reward  -5745.0
# Step  532 | Reward  -5868.0
# Step  533 | Reward  -5976.0
# Step  534 | Reward  -6177.0
# Step  535 | Reward  -6264.0
# Step  536 | Reward  -6444.0
# Step  537 | Reward  -6963.0
# Step  538 | Reward  -6726.0
# Step  539 | Reward  -6792.0
# Step  540 | Reward  -6858.0
# Step  541 | Reward  -6969.0
# Step  542 | Reward  -6963.0
# Step  543 | Reward  -7056.0
# Step  544 | Reward  -7221.0
# Step  545 | Reward  -7269.0
# Step  546 | Reward  -7671.0
# Step  547 | Reward  -8151.0
# Step  548 | Reward  -8787.0
# Step  549 | Reward  -9195.0
# Step  550 | Reward  -9549.0
# Step  551 | Reward  -9897.0
# Step  552 | Reward  -9882.0
# Step  553 | Reward  -9837.0
# Step  554 | Reward  -9699.0
# Step  555 | Reward  -9621.0
# Step  556 | Reward  -9327.0
# Step  557 | Reward  -9099.0
# Step  558 | Reward  -8631.0
# Step  559 | Reward  -8214.0
# Step  560 | Reward  -8253.0
# Step  561 | Reward  -8154.0
# Step  562 | Reward  -7695.0
# Step  563 | Reward  -7464.0
# Step  564 | Reward  -7503.0
# Step  565 | Reward  -7551.0
# Step  566 | Reward  -7758.0
# Step  567 | Reward  -7899.0
# Step  568 | Reward  -8118.0
# Step  569 | Reward  -8397.0
# Step  570 | Reward  -8676.0
# Step  571 | Reward  -8301.0
# Step  572 | Reward  -7896.0
# Step  573 | Reward  -7728.0
# Step  574 | Reward  -7494.0
# Step  575 | Reward  -7632.0
# Step  576 | Reward  -7794.0
# Step  577 | Reward  -7611.0
# Step  578 | Reward  -7527.0
# Step  579 | Reward  -7728.0
# Step  580 | Reward  -7998.0
# Step  581 | Reward  -7989.0
# Step  582 | Reward  -7869.0
# Step  583 | Reward  -7983.0
# Step  584 | Reward  -8232.0
# Step  585 | Reward  -8064.0
# Step  586 | Reward  -7716.0
# Step  587 | Reward  -7278.0
# Step  588 | Reward  -6747.0
# Step  589 | Reward  -6639.0
# Step  590 | Reward  -6489.0
# Step  591 | Reward  -5979.0
# Step  592 | Reward  -5640.0
# Step  593 | Reward  -5832.0
# Step  594 | Reward  -5379.0
# Step  595 | Reward  -5274.0
# Step  596 | Reward  -5280.0
# Step  597 | Reward  -5517.0
# Step  598 | Reward  -5346.0
# Step  599 | Reward  -5118.0
# Step  600 | Reward  -4629.0
# Step  601 | Reward  -4227.0
# Step  602 | Reward  -4305.0
# Step  603 | Reward  -4350.0
# Step  604 | Reward  -4413.0
# Step  605 | Reward  -4827.0
# Step  606 | Reward  -5223.0
# Step  607 | Reward  -5358.0
# Step  608 | Reward  -5544.0
# Step  609 | Reward  -5787.0
# Step  610 | Reward  -5934.0
# Step  611 | Reward  -5970.0
# Step  612 | Reward  -6189.0
# Step  613 | Reward  -6360.0
# Step  614 | Reward  -6453.0
# Step  615 | Reward  -6579.0
# Step  616 | Reward  -6411.0
# Step  617 | Reward  -6315.0
# Step  618 | Reward  -6486.0
# Step  619 | Reward  -6690.0
# Step  620 | Reward  -6927.0
# Step  621 | Reward  -7134.0
# Step  622 | Reward  -7293.0
# Step  623 | Reward  -7587.0
# Step  624 | Reward  -7251.0
# Step  625 | Reward  -6849.0
# Step  626 | Reward  -6696.0
# Step  627 | Reward  -6621.0
# Step  628 | Reward  -6549.0
# Step  629 | Reward  -6726.0
# Step  630 | Reward  -6831.0
# Step  631 | Reward  -6888.0
# Step  632 | Reward  -7341.0
# Step  633 | Reward  -7731.0
# Step  634 | Reward  -7944.0
# Step  635 | Reward  -8085.0
# Step  636 | Reward  -8460.0
# Step  637 | Reward  -8700.0
# Step  638 | Reward  -8784.0
# Step  639 | Reward  -8967.0
# Step  640 | Reward  -9018.0
# Step  641 | Reward  -9027.0
# Step  642 | Reward  -8967.0
# Step  643 | Reward  -8964.0
# Step  644 | Reward  -9213.0
# Step  645 | Reward  -9582.0
# Step  646 | Reward -10056.0
# Step  647 | Reward -10578.0
# Step  648 | Reward -10575.0
# Step  649 | Reward -10467.0
# Step  650 | Reward -10479.0
# Step  651 | Reward -10596.0
# Step  652 | Reward -10992.0
# Step  653 | Reward -11427.0
# Step  654 | Reward -11676.0
# Step  655 | Reward -12069.0
# Step  656 | Reward -12420.0
# Step  657 | Reward -12393.0
# Step  658 | Reward -12594.0
# Step  659 | Reward -12867.0
# Step  660 | Reward -12726.0
# Step  661 | Reward -12798.0
# Step  662 | Reward -13026.0
# Step  663 | Reward -12447.0
# Step  664 | Reward -11856.0
# Step  665 | Reward -11529.0
# Step  666 | Reward -11580.0
# Step  667 | Reward -11529.0
# Step  668 | Reward -11454.0
# Step  669 | Reward -11625.0
# Step  670 | Reward -11418.0
# Step  671 | Reward -11496.0
# Step  672 | Reward -11541.0
# Step  673 | Reward -11418.0
# Step  674 | Reward -11313.0
# Step  675 | Reward -11514.0
# Step  676 | Reward -11370.0
# Step  677 | Reward -11127.0
# Step  678 | Reward -11352.0
# Step  679 | Reward -11541.0
# Step  680 | Reward -11349.0
# Step  681 | Reward -11160.0
# Step  682 | Reward -10992.0
# Step  683 | Reward -10836.0
# Step  684 | Reward -10545.0
# Step  685 | Reward -10353.0
# Step  686 | Reward -10128.0
# Step  687 | Reward -10023.0
# Step  688 | Reward -10185.0
# Step  689 | Reward  -9957.0
# Step  690 | Reward  -9438.0
# Step  691 | Reward  -9240.0
# Step  692 | Reward  -9045.0
# Step  693 | Reward  -8835.0
# Step  694 | Reward  -8709.0
# Step  695 | Reward  -8415.0
# Step  696 | Reward  -8469.0
# Step  697 | Reward  -8886.0
# Step  698 | Reward  -9090.0
# Step  699 | Reward  -9162.0
# Step  700 | Reward  -9072.0
# Step  701 | Reward  -8577.0
# Step  702 | Reward  -8061.0
# Step  703 | Reward  -7953.0
# Step  704 | Reward  -7971.0
# Step  705 | Reward  -8091.0
# Step  706 | Reward  -8205.0
# Step  707 | Reward  -8292.0
# Step  708 | Reward  -8088.0
# Step  709 | Reward  -8031.0
# Step  710 | Reward  -7836.0
# Step  711 | Reward  -7470.0
# Step  712 | Reward  -7323.0
# Step  713 | Reward  -7050.0
# Step  714 | Reward  -6711.0
# Step  715 | Reward  -6573.0
# Step  716 | Reward  -6564.0
# Step  717 | Reward  -6417.0
# Step  718 | Reward  -6402.0
# Step  719 | Reward  -6192.0
# Step  720 | Reward  -6051.0
# Step  721 | Reward  -6087.0
# Step  722 | Reward  -6216.0
# Step  723 | Reward  -6015.0
# Step  724 | Reward  -5712.0
# Step  725 | Reward  -5151.0
# Step  726 | Reward  -5274.0
# Step  727 | Reward  -5319.0
# Step  728 | Reward  -5364.0
# Step  729 | Reward  -5514.0
# Step  730 | Reward  -5589.0
# Step  731 | Reward  -5316.0
# Step  732 | Reward  -5400.0
# Step  733 | Reward  -5490.0
# Step  734 | Reward  -5373.0
# Step  735 | Reward  -5439.0
# Step  736 | Reward  -5727.0
# Step  737 | Reward  -5967.0
# Step  738 | Reward  -5859.0
# Step  739 | Reward  -5769.0
# Step  740 | Reward  -5901.0
# Step  741 | Reward  -6030.0
# Step  742 | Reward  -5919.0
# Step  743 | Reward  -6018.0
# Step  744 | Reward  -6390.0
# Step  745 | Reward  -6720.0
# Step  746 | Reward  -6675.0
# Step  747 | Reward  -6414.0
# Step  748 | Reward  -6399.0
# Step  749 | Reward  -6525.0
# Step  750 | Reward  -7116.0
# Step  751 | Reward  -7605.0
# Step  752 | Reward  -7626.0
# Step  753 | Reward  -7704.0
# Step  754 | Reward  -7902.0
# Step  755 | Reward  -7743.0
# Step  756 | Reward  -7806.0
# Step  757 | Reward  -7299.0
# Step  758 | Reward  -7230.0
# Step  759 | Reward  -7200.0
# Step  760 | Reward  -6915.0
# Step  761 | Reward  -6948.0
# Step  762 | Reward  -7182.0
# Step  763 | Reward  -7329.0
# Step  764 | Reward  -7329.0
# Step  765 | Reward  -7545.0
# Step  766 | Reward  -7779.0
# Step  767 | Reward  -8355.0
# Step  768 | Reward  -8544.0
# Step  769 | Reward  -8946.0
# Step  770 | Reward  -8949.0
# Step  771 | Reward  -9213.0
# Step  772 | Reward  -9423.0
# Step  773 | Reward  -9837.0
# Step  774 | Reward -10035.0
# Step  775 | Reward -10416.0
# Step  776 | Reward -10872.0
# Step  777 | Reward -11298.0
# Step  778 | Reward -11418.0
# Step  779 | Reward -11304.0
# Step  780 | Reward -10857.0
# Step  781 | Reward -10560.0
# Step  782 | Reward -10077.0
# Step  783 | Reward -10083.0
# Step  784 | Reward -10263.0
# Step  785 | Reward -10500.0
# Step  786 | Reward -10947.0
# Step  787 | Reward -11415.0
# Step  788 | Reward -11655.0
# Step  789 | Reward -11502.0
# Step  790 | Reward -11223.0
# Step  791 | Reward -10833.0
# Step  792 | Reward -10746.0
# Step  793 | Reward -10629.0
# Step  794 | Reward -10398.0
# Step  795 | Reward -10476.0
# Step  796 | Reward -10401.0
# Step  797 | Reward -10146.0
# Step  798 | Reward -10197.0
# Step  799 | Reward  -9894.0
# Step  800 | Reward  -9675.0
# Step  801 | Reward  -9501.0
# Step  802 | Reward  -9024.0
# Step  803 | Reward  -8928.0
# Step  804 | Reward  -8889.0
# Step  805 | Reward  -9057.0
# Step  806 | Reward  -9054.0
# Step  807 | Reward  -9051.0
# Step  808 | Reward  -9222.0
# Step  809 | Reward  -9525.0
# Step  810 | Reward  -9258.0
# Step  811 | Reward  -8706.0
# Step  812 | Reward  -8346.0
# Step  813 | Reward  -8259.0
# Step  814 | Reward  -8205.0
# Step  815 | Reward  -7674.0
# Step  816 | Reward  -7554.0
# Step  817 | Reward  -7695.0
# Step  818 | Reward  -7986.0
# Step  819 | Reward  -7725.0
# Step  820 | Reward  -7503.0
# Step  821 | Reward  -7479.0
# Step  822 | Reward  -7524.0
# Step  823 | Reward  -7605.0
# Step  824 | Reward  -7401.0
# Step  825 | Reward  -7371.0
# Step  826 | Reward  -7650.0
# Step  827 | Reward  -7824.0
# Step  828 | Reward  -7989.0
# Step  829 | Reward  -8271.0
# Step  830 | Reward  -7959.0
# Step  831 | Reward  -7836.0
# Step  832 | Reward  -7926.0
# Step  833 | Reward  -7899.0
# Step  834 | Reward  -7917.0
# Step  835 | Reward  -7866.0
# Step  836 | Reward  -8139.0
# Step  837 | Reward  -8457.0
# Step  838 | Reward  -8613.0
# Step  839 | Reward  -8292.0
# Step  840 | Reward  -7974.0
# Step  841 | Reward  -7719.0
# Step  842 | Reward  -7662.0
# Step  843 | Reward  -7806.0
# Step  844 | Reward  -7662.0
# Step  845 | Reward  -7731.0
# Step  846 | Reward  -7755.0
# Step  847 | Reward  -7782.0
# Step  848 | Reward  -7884.0
# Step  849 | Reward  -7857.0
# Step  850 | Reward  -7962.0
# Step  851 | Reward  -7899.0
# Step  852 | Reward  -7836.0
# Step  853 | Reward  -7758.0
# Step  854 | Reward  -7551.0
# Step  855 | Reward  -7281.0
# Step  856 | Reward  -6906.0
# Step  857 | Reward  -6780.0
# Step  858 | Reward  -6864.0
# Step  859 | Reward  -6930.0
# Step  860 | Reward  -6786.0
# Step  861 | Reward  -6462.0
# Step  862 | Reward  -6453.0
# Step  863 | Reward  -6231.0
# Step  864 | Reward  -6627.0
# Step  865 | Reward  -6816.0
# Step  866 | Reward  -7098.0
# Step  867 | Reward  -7368.0
# Step  868 | Reward  -7698.0
# Step  869 | Reward  -7539.0
# Step  870 | Reward  -7401.0
# Step  871 | Reward  -7557.0
# Step  872 | Reward  -7812.0
# Step  873 | Reward  -7719.0
# Step  874 | Reward  -8001.0
# Step  875 | Reward  -8250.0
# Step  876 | Reward  -8754.0
# Step  877 | Reward  -8967.0
# Step  878 | Reward  -9447.0
# Step  879 | Reward  -9591.0
# Step  880 | Reward  -9486.0
# Step  881 | Reward  -9369.0
# Step  882 | Reward  -9543.0
# Step  883 | Reward  -9462.0
# Step  884 | Reward  -9114.0
# Step  885 | Reward  -8676.0
# Step  886 | Reward  -8532.0
# Step  887 | Reward  -8517.0
# Step  888 | Reward  -8286.0
# Step  889 | Reward  -8532.0
# Step  890 | Reward  -9006.0
# Step  891 | Reward  -9306.0
# Step  892 | Reward  -9306.0
# Step  893 | Reward  -9294.0
# Step  894 | Reward  -9258.0
# Step  895 | Reward  -9093.0
# Step  896 | Reward  -9444.0
# Step  897 | Reward  -9909.0
# Step  898 | Reward -10311.0
# Step  899 | Reward -10476.0
# Step  900 | Reward -10134.0
# Step  901 | Reward  -9828.0
# Step  902 | Reward  -9654.0
# Step  903 | Reward  -9156.0
# Step  904 | Reward  -8835.0
# Step  905 | Reward  -8877.0
# Step  906 | Reward  -8316.0
# Step  907 | Reward  -7896.0
# Step  908 | Reward  -7590.0
# Step  909 | Reward  -8052.0
# Step  910 | Reward  -7668.0
# Step  911 | Reward  -7350.0
# Step  912 | Reward  -6873.0
# Step  913 | Reward  -6579.0
# Step  914 | Reward  -6132.0
# Step  915 | Reward  -6330.0
# Step  916 | Reward  -6177.0
# Step  917 | Reward  -6201.0
# Step  918 | Reward  -6276.0
# Step  919 | Reward  -6207.0
# Step  920 | Reward  -5943.0
# Step  921 | Reward  -6174.0
# Step  922 | Reward  -6144.0
# Step  923 | Reward  -6504.0
# Step  924 | Reward  -6795.0
# Step  925 | Reward  -6942.0
# Step  926 | Reward  -7290.0
# Step  927 | Reward  -7833.0
# Step  928 | Reward  -8190.0
# Step  929 | Reward  -8487.0
# Step  930 | Reward  -8685.0
# Step  931 | Reward  -8808.0
# Step  932 | Reward  -8877.0
# Step  933 | Reward  -8877.0
# Step  934 | Reward  -8871.0
# Step  935 | Reward  -8574.0
# Step  936 | Reward  -8979.0
# Step  937 | Reward  -9228.0
# Step  938 | Reward  -9966.0
# Step  939 | Reward -10581.0
# Step  940 | Reward -10671.0
# Step  941 | Reward -10587.0
# Step  942 | Reward -10296.0
# Step  943 | Reward -10353.0
# Step  944 | Reward -10881.0
# Step  945 | Reward -10626.0
# Step  946 | Reward -10524.0
# Step  947 | Reward -10311.0
# Step  948 | Reward -10410.0
# Step  949 | Reward -10425.0
# Step  950 | Reward -10029.0
# Step  951 | Reward  -9912.0
# Step  952 | Reward  -9936.0
# Step  953 | Reward -10038.0
# Step  954 | Reward  -9936.0
# Step  955 | Reward  -9978.0
# Step  956 | Reward -10011.0
# Step  957 | Reward -10239.0
# Step  958 | Reward -10188.0
# Step  959 | Reward -10059.0
# Step  960 | Reward  -9993.0
# Step  961 | Reward -10098.0
# Step  962 | Reward  -9939.0
# Step  963 | Reward  -9813.0
# Step  964 | Reward  -9501.0
# Step  965 | Reward  -9045.0
# Step  966 | Reward  -8604.0
# Step  967 | Reward  -8520.0
# Step  968 | Reward  -8409.0
# Step  969 | Reward  -8529.0
# Step  970 | Reward  -8538.0
# Step  971 | Reward  -8289.0
# Step  972 | Reward  -8412.0
# Step  973 | Reward  -8682.0
# Step  974 | Reward  -8919.0
# Step  975 | Reward  -8514.0
# Step  976 | Reward  -8562.0
# Step  977 | Reward  -8838.0
# Step  978 | Reward  -8775.0
# Step  979 | Reward  -8754.0
# Step  980 | Reward  -8628.0
# Step  981 | Reward  -8631.0
# Step  982 | Reward  -8586.0
# Step  983 | Reward  -9144.0
# Step  984 | Reward  -9237.0
# Step  985 | Reward  -9372.0
# Step  986 | Reward  -9912.0
# Step  987 | Reward -10137.0
# Step  988 | Reward -10506.0
# Step  989 | Reward -10308.0
# Step  990 | Reward -10308.0
# Step  991 | Reward -10248.0
# Step  992 | Reward -10347.0
# Step  993 | Reward -10248.0
# Step  994 | Reward  -9933.0
# Step  995 | Reward  -9285.0
# Step  996 | Reward  -8859.0
# Step  997 | Reward  -8526.0
# Step  998 | Reward  -8496.0
# Step  999 | Reward  -8073.0
#
# === Random Policy Metrics ===
# Total steps executed      : 999
# Total reward accumulated  : -5475168.0
# Vehicles completed routes : 2316
# Still active vehicles     : 784
# Avg waiting time per car  : 55.12 s
# Avg travel time           : 187.42 s

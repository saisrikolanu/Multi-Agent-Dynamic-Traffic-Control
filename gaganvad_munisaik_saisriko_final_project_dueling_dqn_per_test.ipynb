# %%
import torch
import torch.nn as nn
import json
import gym
import gym_cityflow
import cityflow
import os
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
from torch_geometric.nn import GATConv
from torch_geometric.utils import add_self_loops

# %%
class DuelingGAT(torch.nn.Module):
    def __init__(
        self,
        in_dim: int,      
        hidden_dim: int,  
        action_dim: int,    
        heads: int = 4      
    ):
        super().__init__()
        self.gat1 = GATConv(in_dim, hidden_dim, heads=heads, concat=True)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False)

        self.val_fc = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim // 2, 1)
        )
        
        self.adv_fc = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim // 2, action_dim)
        )

    def forward(self, x: torch.Tensor, edge_index: torch.LongTensor): 
        h = F.elu(self.gat1(x, edge_index))
        h = F.elu(self.gat2(h, edge_index))
        V = self.val_fc(h)                        
        A = self.adv_fc(h)                        
        Q = V + (A - A.mean(dim=1, keepdim=True)) 

        return Q

# %%
CONFIG_PATH = "Intersections_4/sample_config.json"
CHECKPOINT = "checkpoints/qnet_gat__per_ep250.pth"
NUM_AGENTS = 16
OBS_DIM    = 72
ACTION_DIM = 9
STEPS      = 1000
HIDDEN_DIM   = 64
HEADS        = 4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DuelingGAT(OBS_DIM, HIDDEN_DIM, ACTION_DIM, heads=HEADS).to(device)
state_dict = torch.load(CHECKPOINT, map_location=device)
model.load_state_dict(state_dict)
model.eval()
# Out:
# DuelingGAT(
#   (gat1): GATConv(72, 64, heads=4)
#   (gat2): GATConv(256, 64, heads=1)
#   (val_fc): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=1, bias=True)
#   )
#   (adv_fc): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=9, bias=True)
#   )
# )

# %%
cfg     = json.load(open(CONFIG_PATH))
roadnet = json.load(open(cfg["dir"] + cfg["roadnetFile"]))
nodes   = [i["id"] for i in roadnet["intersections"] if not i.get("virtual",False)]
nodes   = sorted(nodes)
node2idx = {n:idx for idx,n in enumerate(nodes)}

edges = []
for road in roadnet["roads"]:
    u,v = road.get("startIntersection"), road.get("endIntersection")
    if u in node2idx and v in node2idx:
        ui,vi = node2idx[u], node2idx[v]
        edges += [[ui,vi],[vi,ui]]
edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
edge_index, _ = add_self_loops(edge_index, num_nodes=len(nodes))
edge_index = edge_index.to(device)

# %%
env = gym.make(
    id="cityflow-v0",
    configPath=CONFIG_PATH,
    episodeSteps=STEPS
)
raw_obs = env.reset()
intersection_ids = sorted(raw_obs.keys())
assert len(intersection_ids) == NUM_AGENTS
# Out:
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(

# %%
total_reward      = 0.0
step_rewards      = []
queue_lengths     = []
prev_vehicles     = set(env.eng.get_vehicles(include_waiting=True))
arrived_vehicles  = set()
lane_wait = env.eng.get_lane_waiting_vehicle_count()
queue_lengths.append(sum(lane_wait.values()))

# %%
obs = [ np.array(raw_obs[i],dtype=np.float32).flatten() for i in intersection_ids ]

for t in range(1, STEPS+1):
    x = torch.tensor(obs, dtype=torch.float32, device=device)    
    with torch.no_grad():
        qv = model(x, edge_index)                                 
    actions = qv.argmax(dim=1).cpu().tolist()                     

    next_raw_obs, rewards, done, _ = env.step(actions)
    step_r = sum(r for _,r in rewards)
    total_reward += step_r
    step_rewards.append(step_r)
    cur_vehicles = set(env.eng.get_vehicles(include_waiting=True))
    new_arrs     = prev_vehicles - cur_vehicles
    arrived_vehicles |= new_arrs
    prev_vehicles = cur_vehicles

    lw = env.eng.get_lane_waiting_vehicle_count()
    queue_lengths.append(sum(lw.values()))
    obs = [ np.array(next_raw_obs[i],dtype=np.float32).flatten()
            for i in intersection_ids ]

    print(f"Step {t:4d} | Reward {step_r:8.1f} | Queue {queue_lengths[-1]:4d}")
    if done:
        print(f"Env signaled done at step {t}")
        break

num_arrived      = len(arrived_vehicles)
total_wait_time  = sum(queue_lengths)                   
avg_wait_per_car = total_wait_time / num_arrived        if num_arrived>0 else float("nan")
avg_travel_time  = env.eng.get_average_travel_time()    
active_vehicles  = env.eng.get_vehicle_count()

print("\n===== Dueling GAT-DQN Evaluation =====")
print(f"Total steps executed       : {t}")
print(f"Total reward accumulated   : {total_reward:.1f}")
print(f"Vehicles completed routes  : {num_arrived}")
print(f"Active vehicles remaining  : {active_vehicles}")
print(f"Avg waiting time per car   : {avg_wait_per_car:.2f} s")
print(f"Avg travel time (all)      : {avg_travel_time:.2f} s")
# Out:
# /scratch/19534219/ipykernel_134213/3276665258.py:5: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   x = torch.tensor(obs, dtype=torch.float32, device=device)    # [N,obs_dim]
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:146: UserWarning: WARN: The obs returned by the `step()` method was expecting a numpy array, actual type: <class 'list'>
#   logger.warn(f"{pre} was expecting a numpy array, actual type: {type(obs)}")
# /user/gaganvad/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:252: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'list'>
#   logger.warn(
# Step    1 | Reward      0.0 | Queue    0
# Step    2 | Reward      0.0 | Queue    0
# Step    3 | Reward      0.0 | Queue    0
# Step    4 | Reward      0.0 | Queue    0
# Step    5 | Reward      0.0 | Queue    0
# Step    6 | Reward      0.0 | Queue    0
# Step    7 | Reward      0.0 | Queue    0
# Step    8 | Reward      0.0 | Queue    0
# Step    9 | Reward      0.0 | Queue    0
# Step   10 | Reward      0.0 | Queue    0
# Step   11 | Reward      0.0 | Queue    0
# Step   12 | Reward      0.0 | Queue    0
# Step   13 | Reward      0.0 | Queue    0
# Step   14 | Reward      0.0 | Queue    0
# Step   15 | Reward      0.0 | Queue    0
# Step   16 | Reward      0.0 | Queue    0
# Step   17 | Reward      0.0 | Queue    0
# Step   18 | Reward      0.0 | Queue    0
# Step   19 | Reward      0.0 | Queue    0
# Step   20 | Reward      0.0 | Queue    0
# Step   21 | Reward      0.0 | Queue    0
# Step   22 | Reward      0.0 | Queue    0
# Step   23 | Reward      0.0 | Queue    0
# Step   24 | Reward      0.0 | Queue    0
# Step   25 | Reward      0.0 | Queue    0
# Step   26 | Reward      0.0 | Queue    0
# Step   27 | Reward      0.0 | Queue    0
# Step   28 | Reward      0.0 | Queue    0
# Step   29 | Reward      0.0 | Queue    0
# Step   30 | Reward      0.0 | Queue    0
# Step   31 | Reward    -60.0 | Queue    8
# Step   32 | Reward    -38.4 | Queue    5
# Step   33 | Reward    -38.4 | Queue    5
# Step   34 | Reward    -58.2 | Queue    8
# Step   35 | Reward    -38.4 | Queue    5
# Step   36 | Reward    -33.6 | Queue    4
# Step   37 | Reward    -23.4 | Queue    3
# Step   38 | Reward    -53.4 | Queue    7
# Step   39 | Reward    -30.0 | Queue    4
# Step   40 | Reward    -15.0 | Queue    2
# Step   41 | Reward    -48.0 | Queue    7
# Step   42 | Reward    -78.0 | Queue   11
# Step   43 | Reward    -26.4 | Queue    4
# Step   44 | Reward    -33.0 | Queue    5
# Step   45 | Reward    -43.2 | Queue    6
# Step   46 | Reward    -64.8 | Queue    9
# Step   47 | Reward    -71.4 | Queue   10
# Step   48 | Reward    -84.6 | Queue   12
# Step   49 | Reward    -41.4 | Queue    6
# Step   50 | Reward    -48.0 | Queue    7
# Step   51 | Reward    -49.8 | Queue    7
# Step   52 | Reward    -56.4 | Queue    8
# Step   53 | Reward    -19.8 | Queue    3
# Step   54 | Reward    -26.4 | Queue    4
# Step   55 | Reward    -33.0 | Queue    5
# Step   56 | Reward    -34.8 | Queue    5
# Step   57 | Reward    -30.0 | Queue    4
# Step   58 | Reward    -53.4 | Queue    7
# Step   59 | Reward    -73.2 | Queue   10
# Step   60 | Reward    -73.2 | Queue   10
# Step   61 | Reward    -64.8 | Queue    9
# Step   62 | Reward    -39.6 | Queue    6
# Step   63 | Reward    -60.0 | Queue    8
# Step   64 | Reward    -53.4 | Queue    7
# Step   65 | Reward    -76.8 | Queue   10
# Step   66 | Reward    -84.0 | Queue   10
# Step   67 | Reward    -65.4 | Queue    8
# Step   68 | Reward    -65.4 | Queue    8
# Step   69 | Reward    -48.6 | Queue    6
# Step   70 | Reward    -63.6 | Queue    8
# Step   71 | Reward    -55.2 | Queue    7
# Step   72 | Reward    -68.4 | Queue    9
# Step   73 | Reward   -102.0 | Queue   13
# Step   74 | Reward    -58.8 | Queue    7
# Step   75 | Reward    -25.2 | Queue    3
# Step   76 | Reward    -42.0 | Queue    5
# Step   77 | Reward    -90.6 | Queue   11
# Step   78 | Reward    -65.4 | Queue    8
# Step   79 | Reward    -88.8 | Queue   11
# Step   80 | Reward    -99.0 | Queue   12
# Step   81 | Reward    -43.2 | Queue    6
# Step   82 | Reward    -34.8 | Queue    5
# Step   83 | Reward    -60.0 | Queue    8
# Step   84 | Reward   -110.4 | Queue   14
# Step   85 | Reward    -93.6 | Queue   12
# Step   86 | Reward    -48.0 | Queue    7
# Step   87 | Reward    -61.2 | Queue    9
# Step   88 | Reward    -52.8 | Queue    8
# Step   89 | Reward    -66.0 | Queue   10
# Step   90 | Reward    -71.4 | Queue   10
# Step   91 | Reward   -115.2 | Queue   15
# Step   92 | Reward    -60.0 | Queue    8
# Step   93 | Reward    -36.6 | Queue    5
# Step   94 | Reward    -70.2 | Queue    9
# Step   95 | Reward    -46.8 | Queue    6
# Step   96 | Reward    -48.6 | Queue    6
# Step   97 | Reward    -83.4 | Queue   11
# Step   98 | Reward   -117.0 | Queue   15
# Step   99 | Reward    -53.4 | Queue    7
# Step  100 | Reward    -72.0 | Queue    9
# Step  101 | Reward    -73.8 | Queue    9
# Step  102 | Reward    -90.6 | Queue   11
# Step  103 | Reward   -132.0 | Queue   17
# Step  104 | Reward    -91.8 | Queue   12
# Step  105 | Reward   -139.2 | Queue   17
# Step  106 | Reward    -88.8 | Queue   11
# Step  107 | Reward    -65.4 | Queue    8
# Step  108 | Reward   -109.2 | Queue   13
# Step  109 | Reward    -75.6 | Queue    9
# Step  110 | Reward    -90.6 | Queue   11
# Step  111 | Reward   -112.8 | Queue   13
# Step  112 | Reward    -94.2 | Queue   11
# Step  113 | Reward    -92.4 | Queue   11
# Step  114 | Reward    -85.2 | Queue   11
# Step  115 | Reward    -93.0 | Queue   13
# Step  116 | Reward    -83.4 | Queue   11
# Step  117 | Reward    -85.2 | Queue   11
# Step  118 | Reward    -70.2 | Queue    9
# Step  119 | Reward   -105.6 | Queue   13
# Step  120 | Reward   -140.4 | Queue   18
# Step  121 | Reward   -153.6 | Queue   20
# Step  122 | Reward   -205.2 | Queue   27
# Step  123 | Reward   -173.4 | Queue   23
# Step  124 | Reward   -150.6 | Queue   19
# Step  125 | Reward   -144.0 | Queue   18
# Step  126 | Reward   -115.2 | Queue   15
# Step  127 | Reward   -165.6 | Queue   21
# Step  128 | Reward   -147.0 | Queue   19
# Step  129 | Reward   -124.8 | Queue   17
# Step  130 | Reward   -108.0 | Queue   15
# Step  131 | Reward    -91.2 | Queue   13
# Step  132 | Reward   -151.8 | Queue   20
# Step  133 | Reward   -111.6 | Queue   15
# Step  134 | Reward   -163.8 | Queue   21
# Step  135 | Reward   -133.8 | Queue   17
# Step  136 | Reward   -111.6 | Queue   15
# Step  137 | Reward   -111.6 | Queue   15
# Step  138 | Reward   -100.2 | Queue   13
# Step  139 | Reward   -129.0 | Queue   16
# Step  140 | Reward   -132.0 | Queue   17
# Step  141 | Reward   -123.6 | Queue   16
# Step  142 | Reward    -91.2 | Queue   13
# Step  143 | Reward   -124.8 | Queue   17
# Step  144 | Reward   -127.2 | Queue   16
# Step  145 | Reward   -132.0 | Queue   17
# Step  146 | Reward   -150.0 | Queue   20
# Step  147 | Reward   -142.8 | Queue   20
# Step  148 | Reward   -129.6 | Queue   18
# Step  149 | Reward   -180.0 | Queue   24
# Step  150 | Reward   -144.6 | Queue   20
# Step  151 | Reward   -161.4 | Queue   22
# Step  152 | Reward   -150.0 | Queue   20
# Step  153 | Reward   -131.4 | Queue   18
# Step  154 | Reward   -178.8 | Queue   23
# Step  155 | Reward   -200.4 | Queue   26
# Step  156 | Reward   -195.0 | Queue   26
# Step  157 | Reward   -138.0 | Queue   19
# Step  158 | Reward   -121.2 | Queue   17
# Step  159 | Reward   -139.8 | Queue   19
# Step  160 | Reward   -198.6 | Queue   26
# Step  161 | Reward   -203.4 | Queue   27
# Step  162 | Reward   -211.8 | Queue   28
# Step  163 | Reward   -173.4 | Queue   23
# Step  164 | Reward   -178.8 | Queue   23
# Step  165 | Reward   -165.6 | Queue   21
# Step  166 | Reward   -179.4 | Queue   22
# Step  167 | Reward   -179.4 | Queue   22
# Step  168 | Reward   -183.6 | Queue   24
# Step  169 | Reward   -163.2 | Queue   22
# Step  170 | Reward   -176.4 | Queue   24
# Step  171 | Reward   -170.4 | Queue   22
# Step  172 | Reward   -235.8 | Queue   30
# Step  173 | Reward   -217.8 | Queue   27
# Step  174 | Reward   -175.8 | Queue   22
# Step  175 | Reward   -160.2 | Queue   21
# Step  176 | Reward   -143.4 | Queue   19
# Step  177 | Reward   -140.4 | Queue   18
# Step  178 | Reward   -138.6 | Queue   18
# Step  179 | Reward   -182.4 | Queue   23
# Step  180 | Reward   -168.6 | Queue   22
# Step  181 | Reward   -162.0 | Queue   21
# Step  182 | Reward   -160.8 | Queue   20
# Step  183 | Reward   -103.2 | Queue   14
# Step  184 | Reward   -126.6 | Queue   17
# Step  185 | Reward   -128.4 | Queue   17
# Step  186 | Reward   -267.6 | Queue   34
# Step  187 | Reward   -242.4 | Queue   31
# Step  188 | Reward   -199.2 | Queue   25
# Step  189 | Reward   -163.8 | Queue   21
# Step  190 | Reward   -209.4 | Queue   26
# Step  191 | Reward   -219.0 | Queue   28
# Step  192 | Reward   -259.2 | Queue   33
# Step  193 | Reward   -240.6 | Queue   31
# Step  194 | Reward   -188.4 | Queue   25
# Step  195 | Reward   -183.6 | Queue   24
# Step  196 | Reward   -189.0 | Queue   24
# Step  197 | Reward   -220.8 | Queue   28
# Step  198 | Reward   -194.4 | Queue   24
# Step  199 | Reward   -217.8 | Queue   27
# Step  200 | Reward   -144.0 | Queue   18
# Step  201 | Reward   -110.4 | Queue   14
# Step  202 | Reward   -125.4 | Queue   16
# Step  203 | Reward   -183.0 | Queue   22
# Step  204 | Reward   -202.8 | Queue   25
# Step  205 | Reward   -199.2 | Queue   25
# Step  206 | Reward   -199.2 | Queue   25
# Step  207 | Reward   -159.0 | Queue   20
# Step  208 | Reward   -228.0 | Queue   28
# Step  209 | Reward   -200.4 | Queue   26
# Step  210 | Reward   -219.0 | Queue   28
# Step  211 | Reward   -227.4 | Queue   29
# Step  212 | Reward   -237.0 | Queue   31
# Step  213 | Reward   -255.6 | Queue   33
# Step  214 | Reward   -217.2 | Queue   28
# Step  215 | Reward   -200.4 | Queue   26
# Step  216 | Reward   -234.0 | Queue   30
# Step  217 | Reward   -215.4 | Queue   28
# Step  218 | Reward   -224.4 | Queue   28
# Step  219 | Reward   -225.6 | Queue   29
# Step  220 | Reward   -264.0 | Queue   34
# Step  221 | Reward   -247.2 | Queue   32
# Step  222 | Reward   -267.6 | Queue   34
# Step  223 | Reward   -237.6 | Queue   30
# Step  224 | Reward   -202.8 | Queue   25
# Step  225 | Reward   -216.0 | Queue   27
# Step  226 | Reward   -220.8 | Queue   28
# Step  227 | Reward   -244.2 | Queue   31
# Step  228 | Reward   -254.4 | Queue   32
# Step  229 | Reward   -256.2 | Queue   32
# Step  230 | Reward   -282.6 | Queue   36
# Step  231 | Reward   -255.6 | Queue   33
# Step  232 | Reward   -262.2 | Queue   34
# Step  233 | Reward   -265.8 | Queue   34
# Step  234 | Reward   -280.8 | Queue   36
# Step  235 | Reward   -297.6 | Queue   38
# Step  236 | Reward   -303.6 | Queue   40
# Step  237 | Reward   -307.2 | Queue   40
# Step  238 | Reward   -241.8 | Queue   32
# Step  239 | Reward   -210.0 | Queue   28
# Step  240 | Reward   -225.0 | Queue   30
# Step  241 | Reward   -225.6 | Queue   29
# Step  242 | Reward   -234.6 | Queue   29
# Step  243 | Reward   -214.2 | Queue   27
# Step  244 | Reward   -247.8 | Queue   31
# Step  245 | Reward   -225.6 | Queue   29
# Step  246 | Reward   -259.2 | Queue   33
# Step  247 | Reward   -225.6 | Queue   29
# Step  248 | Reward   -223.8 | Queue   29
# Step  249 | Reward   -239.4 | Queue   30
# Step  250 | Reward   -240.6 | Queue   31
# Step  251 | Reward   -220.8 | Queue   28
# Step  252 | Reward   -162.0 | Queue   21
# Step  253 | Reward   -155.4 | Queue   20
# Step  254 | Reward   -162.6 | Queue   20
# Step  255 | Reward   -174.0 | Queue   22
# Step  256 | Reward   -292.8 | Queue   37
# Step  257 | Reward   -267.6 | Queue   34
# Step  258 | Reward   -286.2 | Queue   36
# Step  259 | Reward   -274.2 | Queue   35
# Step  260 | Reward   -262.8 | Queue   33
# Step  261 | Reward   -222.6 | Queue   28
# Step  262 | Reward   -249.0 | Queue   32
# Step  263 | Reward   -285.0 | Queue   35
# Step  264 | Reward   -282.0 | Queue   34
# Step  265 | Reward   -277.8 | Queue   35
# Step  266 | Reward   -306.6 | Queue   38
# Step  267 | Reward   -271.2 | Queue   34
# Step  268 | Reward   -232.2 | Queue   30
# Step  269 | Reward   -309.0 | Queue   40
# Step  270 | Reward   -305.4 | Queue   40
# Step  271 | Reward   -310.8 | Queue   40
# Step  272 | Reward   -316.2 | Queue   40
# Step  273 | Reward   -309.6 | Queue   39
# Step  274 | Reward   -321.0 | Queue   41
# Step  275 | Reward   -359.4 | Queue   46
# Step  276 | Reward   -420.6 | Queue   52
# Step  277 | Reward   -363.6 | Queue   45
# Step  278 | Reward   -315.0 | Queue   39
# Step  279 | Reward   -284.4 | Queue   36
# Step  280 | Reward   -260.4 | Queue   34
# Step  281 | Reward   -294.0 | Queue   38
# Step  282 | Reward   -285.6 | Queue   37
# Step  283 | Reward   -374.4 | Queue   48
# Step  284 | Reward   -406.8 | Queue   51
# Step  285 | Reward   -391.8 | Queue   49
# Step  286 | Reward   -348.6 | Queue   43
# Step  287 | Reward   -333.6 | Queue   41
# Step  288 | Reward   -303.0 | Queue   38
# Step  289 | Reward   -307.8 | Queue   39
# Step  290 | Reward   -240.6 | Queue   31
# Step  291 | Reward   -255.6 | Queue   33
# Step  292 | Reward   -281.4 | Queue   35
# Step  293 | Reward   -308.4 | Queue   38
# Step  294 | Reward   -309.6 | Queue   39
# Step  295 | Reward   -276.0 | Queue   35
# Step  296 | Reward   -276.0 | Queue   35
# Step  297 | Reward   -336.0 | Queue   43
# Step  298 | Reward   -337.2 | Queue   44
# Step  299 | Reward   -313.2 | Queue   42
# Step  300 | Reward   -340.8 | Queue   44
# Step  301 | Reward   -367.8 | Queue   47
# Step  302 | Reward   -289.2 | Queue   37
# Step  303 | Reward   -345.0 | Queue   43
# Step  304 | Reward   -365.4 | Queue   45
# Step  305 | Reward   -361.8 | Queue   45
# Step  306 | Reward   -354.6 | Queue   45
# Step  307 | Reward   -432.0 | Queue   54
# Step  308 | Reward   -420.0 | Queue   53
# Step  309 | Reward   -426.6 | Queue   54
# Step  310 | Reward   -416.4 | Queue   53
# Step  311 | Reward   -401.4 | Queue   51
# Step  312 | Reward   -376.2 | Queue   48
# Step  313 | Reward   -390.6 | Queue   51
# Step  314 | Reward   -378.6 | Queue   50
# Step  315 | Reward   -358.8 | Queue   47
# Step  316 | Reward   -385.8 | Queue   50
# Step  317 | Reward   -377.4 | Queue   49
# Step  318 | Reward   -327.0 | Queue   43
# Step  319 | Reward   -321.6 | Queue   43
# Step  320 | Reward   -333.6 | Queue   44
# Step  321 | Reward   -333.6 | Queue   44
# Step  322 | Reward   -344.4 | Queue   44
# Step  323 | Reward   -348.0 | Queue   44
# Step  324 | Reward   -294.0 | Queue   38
# Step  325 | Reward   -327.0 | Queue   43
# Step  326 | Reward   -305.4 | Queue   40
# Step  327 | Reward   -319.2 | Queue   41
# Step  328 | Reward   -316.2 | Queue   40
# Step  329 | Reward   -276.0 | Queue   35
# Step  330 | Reward   -355.2 | Queue   44
# Step  331 | Reward   -388.8 | Queue   48
# Step  332 | Reward   -395.4 | Queue   49
# Step  333 | Reward   -323.4 | Queue   40
# Step  334 | Reward   -333.6 | Queue   41
# Step  335 | Reward   -298.2 | Queue   37
# Step  336 | Reward   -218.4 | Queue   29
# Step  337 | Reward   -267.6 | Queue   34
# Step  338 | Reward   -212.4 | Queue   27
# Step  339 | Reward   -250.8 | Queue   32
# Step  340 | Reward   -256.2 | Queue   32
# Step  341 | Reward   -231.0 | Queue   29
# Step  342 | Reward   -208.8 | Queue   27
# Step  343 | Reward   -289.2 | Queue   37
# Step  344 | Reward   -346.2 | Queue   44
# Step  345 | Reward   -346.2 | Queue   44
# Step  346 | Reward   -302.4 | Queue   39
# Step  347 | Reward   -270.6 | Queue   35
# Step  348 | Reward   -211.8 | Queue   28
# Step  349 | Reward   -158.4 | Queue   21
# Step  350 | Reward   -238.2 | Queue   29
# Step  351 | Reward   -297.0 | Queue   36
# Step  352 | Reward   -236.4 | Queue   29
# Step  353 | Reward   -249.6 | Queue   31
# Step  354 | Reward   -309.6 | Queue   39
# Step  355 | Reward   -318.0 | Queue   40
# Step  356 | Reward   -319.2 | Queue   41
# Step  357 | Reward   -297.6 | Queue   38
# Step  358 | Reward   -292.8 | Queue   37
# Step  359 | Reward   -307.8 | Queue   39
# Step  360 | Reward   -426.0 | Queue   52
# Step  361 | Reward   -409.2 | Queue   50
# Step  362 | Reward   -332.4 | Queue   40
# Step  363 | Reward   -307.2 | Queue   37
# Step  364 | Reward   -286.8 | Queue   35
# Step  365 | Reward   -309.0 | Queue   37
# Step  366 | Reward   -356.4 | Queue   42
# Step  367 | Reward   -435.6 | Queue   51
# Step  368 | Reward   -471.6 | Queue   54
# Step  369 | Reward   -448.2 | Queue   51
# Step  370 | Reward   -412.8 | Queue   47
# Step  371 | Reward   -331.2 | Queue   39
# Step  372 | Reward   -201.6 | Queue   24
# Step  373 | Reward   -225.0 | Queue   27
# Step  374 | Reward   -212.4 | Queue   27
# Step  375 | Reward   -214.2 | Queue   27
# Step  376 | Reward   -279.6 | Queue   35
# Step  377 | Reward   -332.4 | Queue   40
# Step  378 | Reward   -304.2 | Queue   36
# Step  379 | Reward   -302.4 | Queue   36
# Step  380 | Reward   -352.8 | Queue   42
# Step  381 | Reward   -342.6 | Queue   41
# Step  382 | Reward   -374.4 | Queue   45
# Step  383 | Reward   -346.2 | Queue   41
# Step  384 | Reward   -302.4 | Queue   36
# Step  385 | Reward   -282.0 | Queue   34
# Step  386 | Reward   -253.2 | Queue   31
# Step  387 | Reward   -259.8 | Queue   32
# Step  388 | Reward   -280.2 | Queue   34
# Step  389 | Reward   -255.0 | Queue   31
# Step  390 | Reward   -255.0 | Queue   31
# Step  391 | Reward   -294.0 | Queue   35
# Step  392 | Reward   -292.2 | Queue   35
# Step  393 | Reward   -256.8 | Queue   31
# Step  394 | Reward   -234.0 | Queue   27
# Step  395 | Reward   -272.4 | Queue   32
# Step  396 | Reward   -306.0 | Queue   36
# Step  397 | Reward   -243.6 | Queue   29
# Step  398 | Reward   -214.8 | Queue   26
# Step  399 | Reward   -195.0 | Queue   23
# Step  400 | Reward   -198.6 | Queue   23
# Step  401 | Reward   -267.6 | Queue   31
# Step  402 | Reward   -195.0 | Queue   23
# Step  403 | Reward   -231.6 | Queue   28
# Step  404 | Reward   -208.2 | Queue   25
# Step  405 | Reward   -223.2 | Queue   27
# Step  406 | Reward   -213.0 | Queue   26
# Step  407 | Reward   -238.2 | Queue   29
# Step  408 | Reward   -241.2 | Queue   30
# Step  409 | Reward   -289.8 | Queue   36
# Step  410 | Reward   -405.6 | Queue   50
# Step  411 | Reward   -395.4 | Queue   49
# Step  412 | Reward   -305.4 | Queue   40
# Step  413 | Reward   -298.8 | Queue   39
# Step  414 | Reward   -283.8 | Queue   37
# Step  415 | Reward   -322.2 | Queue   42
# Step  416 | Reward   -364.8 | Queue   46
# Step  417 | Reward   -337.8 | Queue   43
# Step  418 | Reward   -338.4 | Queue   42
# Step  419 | Reward   -343.8 | Queue   42
# Step  420 | Reward   -312.0 | Queue   38
# Step  421 | Reward   -356.4 | Queue   45
# Step  422 | Reward   -359.4 | Queue   46
# Step  423 | Reward   -371.4 | Queue   47
# Step  424 | Reward   -304.2 | Queue   39
# Step  425 | Reward   -351.6 | Queue   44
# Step  426 | Reward   -333.0 | Queue   42
# Step  427 | Reward   -344.4 | Queue   44
# Step  428 | Reward   -357.6 | Queue   46
# Step  429 | Reward   -342.6 | Queue   44
# Step  430 | Reward   -307.8 | Queue   39
# Step  431 | Reward   -302.4 | Queue   39
# Step  432 | Reward   -324.0 | Queue   42
# Step  433 | Reward   -416.4 | Queue   53
# Step  434 | Reward   -391.2 | Queue   50
# Step  435 | Reward   -393.0 | Queue   50
# Step  436 | Reward   -436.8 | Queue   55
# Step  437 | Reward   -450.6 | Queue   56
# Step  438 | Reward   -427.8 | Queue   52
# Step  439 | Reward   -492.6 | Queue   61
# Step  440 | Reward   -471.0 | Queue   58
# Step  441 | Reward   -472.8 | Queue   58
# Step  442 | Reward   -421.2 | Queue   51
# Step  443 | Reward   -442.8 | Queue   54
# Step  444 | Reward   -392.4 | Queue   48
# Step  445 | Reward   -447.6 | Queue   55
# Step  446 | Reward   -399.0 | Queue   49
# Step  447 | Reward   -392.4 | Queue   48
# Step  448 | Reward   -382.8 | Queue   46
# Step  449 | Reward   -295.2 | Queue   36
# Step  450 | Reward   -277.8 | Queue   35
# Step  451 | Reward   -316.2 | Queue   40
# Step  452 | Reward   -312.0 | Queue   38
# Step  453 | Reward   -358.2 | Queue   42
# Step  454 | Reward   -352.8 | Queue   42
# Step  455 | Reward   -374.4 | Queue   45
# Step  456 | Reward   -362.4 | Queue   44
# Step  457 | Reward   -310.2 | Queue   38
# Step  458 | Reward   -241.8 | Queue   29
# Step  459 | Reward   -295.8 | Queue   35
# Step  460 | Reward   -238.8 | Queue   28
# Step  461 | Reward   -322.2 | Queue   39
# Step  462 | Reward   -357.0 | Queue   44
# Step  463 | Reward   -316.2 | Queue   40
# Step  464 | Reward   -301.8 | Queue   37
# Step  465 | Reward   -384.0 | Queue   47
# Step  466 | Reward   -353.4 | Queue   44
# Step  467 | Reward   -345.0 | Queue   43
# Step  468 | Reward   -336.6 | Queue   42
# Step  469 | Reward   -342.0 | Queue   42
# Step  470 | Reward   -279.6 | Queue   35
# Step  471 | Reward   -328.2 | Queue   41
# Step  472 | Reward   -319.8 | Queue   40
# Step  473 | Reward   -372.0 | Queue   46
# Step  474 | Reward   -361.8 | Queue   45
# Step  475 | Reward   -361.8 | Queue   45
# Step  476 | Reward   -328.2 | Queue   41
# Step  477 | Reward   -315.0 | Queue   39
# Step  478 | Reward   -288.6 | Queue   35
# Step  479 | Reward   -328.8 | Queue   40
# Step  480 | Reward   -366.0 | Queue   44
# Step  481 | Reward   -382.8 | Queue   46
# Step  482 | Reward   -394.2 | Queue   48
# Step  483 | Reward   -426.0 | Queue   52
# Step  484 | Reward   -409.2 | Queue   50
# Step  485 | Reward   -381.6 | Queue   48
# Step  486 | Reward   -369.6 | Queue   47
# Step  487 | Reward   -370.8 | Queue   48
# Step  488 | Reward   -349.8 | Queue   44
# Step  489 | Reward   -319.8 | Queue   40
# Step  490 | Reward   -311.4 | Queue   39
# Step  491 | Reward   -306.0 | Queue   39
# Step  492 | Reward   -354.6 | Queue   45
# Step  493 | Reward   -286.2 | Queue   36
# Step  494 | Reward   -380.4 | Queue   47
# Step  495 | Reward   -340.8 | Queue   44
# Step  496 | Reward   -305.4 | Queue   40
# Step  497 | Reward   -355.8 | Queue   46
# Step  498 | Reward   -354.6 | Queue   45
# Step  499 | Reward   -351.6 | Queue   44
# Step  500 | Reward   -271.2 | Queue   34
# Step  501 | Reward   -250.8 | Queue   32
# Step  502 | Reward   -247.8 | Queue   31
# Step  503 | Reward   -281.4 | Queue   35
# Step  504 | Reward   -354.6 | Queue   45
# Step  505 | Reward   -398.4 | Queue   50
# Step  506 | Reward   -376.8 | Queue   47
# Step  507 | Reward   -352.8 | Queue   45
# Step  508 | Reward   -289.2 | Queue   37
# Step  509 | Reward   -282.6 | Queue   36
# Step  510 | Reward   -326.4 | Queue   41
# Step  511 | Reward   -331.8 | Queue   41
# Step  512 | Reward   -285.0 | Queue   35
# Step  513 | Reward   -226.2 | Queue   28
# Step  514 | Reward   -249.0 | Queue   32
# Step  515 | Reward   -309.0 | Queue   40
# Step  516 | Reward   -276.0 | Queue   35
# Step  517 | Reward   -207.0 | Queue   27
# Step  518 | Reward   -223.8 | Queue   29
# Step  519 | Reward   -306.0 | Queue   39
# Step  520 | Reward   -345.0 | Queue   43
# Step  521 | Reward   -288.0 | Queue   36
# Step  522 | Reward   -328.8 | Queue   40
# Step  523 | Reward   -411.0 | Queue   50
# Step  524 | Reward   -429.6 | Queue   52
# Step  525 | Reward   -394.2 | Queue   48
# Step  526 | Reward   -406.2 | Queue   49
# Step  527 | Reward   -361.2 | Queue   43
# Step  528 | Reward   -346.2 | Queue   41
# Step  529 | Reward   -335.4 | Queue   41
# Step  530 | Reward   -335.4 | Queue   41
# Step  531 | Reward   -289.2 | Queue   34
# Step  532 | Reward   -297.0 | Queue   36
# Step  533 | Reward   -286.8 | Queue   35
# Step  534 | Reward   -344.4 | Queue   44
# Step  535 | Reward   -334.2 | Queue   43
# Step  536 | Reward   -312.6 | Queue   40
# Step  537 | Reward   -261.0 | Queue   33
# Step  538 | Reward   -277.2 | Queue   33
# Step  539 | Reward   -248.4 | Queue   30
# Step  540 | Reward   -246.6 | Queue   30
# Step  541 | Reward   -236.4 | Queue   29
# Step  542 | Reward   -250.2 | Queue   30
# Step  543 | Reward   -302.4 | Queue   36
# Step  544 | Reward   -330.6 | Queue   40
# Step  545 | Reward   -404.4 | Queue   49
# Step  546 | Reward   -343.8 | Queue   42
# Step  547 | Reward   -328.8 | Queue   40
# Step  548 | Reward   -325.2 | Queue   40
# Step  549 | Reward   -298.2 | Queue   37
# Step  550 | Reward   -268.8 | Queue   35
# Step  551 | Reward   -287.4 | Queue   37
# Step  552 | Reward   -318.0 | Queue   40
# Step  553 | Reward   -315.0 | Queue   39
# Step  554 | Reward   -280.2 | Queue   34
# Step  555 | Reward   -259.8 | Queue   32
# Step  556 | Reward   -266.4 | Queue   33
# Step  557 | Reward   -288.0 | Queue   36
# Step  558 | Reward   -270.0 | Queue   33
# Step  559 | Reward   -241.8 | Queue   29
# Step  560 | Reward   -211.8 | Queue   25
# Step  561 | Reward   -231.6 | Queue   28
# Step  562 | Reward   -359.4 | Queue   43
# Step  563 | Reward   -401.4 | Queue   48
# Step  564 | Reward   -386.4 | Queue   46
# Step  565 | Reward   -372.6 | Queue   45
# Step  566 | Reward   -362.4 | Queue   44
# Step  567 | Reward   -345.6 | Queue   42
# Step  568 | Reward   -364.2 | Queue   44
# Step  569 | Reward   -363.6 | Queue   45
# Step  570 | Reward   -365.4 | Queue   45
# Step  571 | Reward   -417.0 | Queue   52
# Step  572 | Reward   -479.4 | Queue   59
# Step  573 | Reward   -444.0 | Queue   55
# Step  574 | Reward   -449.4 | Queue   55
# Step  575 | Reward   -446.4 | Queue   54
# Step  576 | Reward   -433.8 | Queue   54
# Step  577 | Reward   -408.0 | Queue   52
# Step  578 | Reward   -406.2 | Queue   52
# Step  579 | Reward   -397.8 | Queue   51
# Step  580 | Reward   -378.0 | Queue   48
# Step  581 | Reward   -361.8 | Queue   45
# Step  582 | Reward   -340.2 | Queue   42
# Step  583 | Reward   -373.8 | Queue   46
# Step  584 | Reward   -419.4 | Queue   51
# Step  585 | Reward   -430.8 | Queue   53
# Step  586 | Reward   -465.6 | Queue   58
# Step  587 | Reward   -453.0 | Queue   55
# Step  588 | Reward   -430.8 | Queue   53
# Step  589 | Reward   -475.8 | Queue   59
# Step  590 | Reward   -387.0 | Queue   48
# Step  591 | Reward   -447.6 | Queue   55
# Step  592 | Reward   -378.6 | Queue   47
# Step  593 | Reward   -391.8 | Queue   49
# Step  594 | Reward   -355.2 | Queue   44
# Step  595 | Reward   -360.0 | Queue   45
# Step  596 | Reward   -384.0 | Queue   47
# Step  597 | Reward   -376.8 | Queue   47
# Step  598 | Reward   -372.0 | Queue   46
# Step  599 | Reward   -355.8 | Queue   43
# Step  600 | Reward   -375.0 | Queue   44
# Step  601 | Reward   -344.4 | Queue   41
# Step  602 | Reward   -303.6 | Queue   37
# Step  603 | Reward   -337.2 | Queue   41
# Step  604 | Reward   -312.6 | Queue   37
# Step  605 | Reward   -302.4 | Queue   36
# Step  606 | Reward   -266.4 | Queue   33
# Step  607 | Reward   -337.2 | Queue   41
# Step  608 | Reward   -350.4 | Queue   43
# Step  609 | Reward   -408.6 | Queue   51
# Step  610 | Reward   -415.2 | Queue   52
# Step  611 | Reward   -396.0 | Queue   48
# Step  612 | Reward   -345.6 | Queue   42
# Step  613 | Reward   -295.2 | Queue   36
# Step  614 | Reward   -324.0 | Queue   39
# Step  615 | Reward   -319.2 | Queue   38
# Step  616 | Reward   -283.2 | Queue   35
# Step  617 | Reward   -253.2 | Queue   31
# Step  618 | Reward   -231.0 | Queue   29
# Step  619 | Reward   -268.2 | Queue   33
# Step  620 | Reward   -249.6 | Queue   31
# Step  621 | Reward   -251.4 | Queue   31
# Step  622 | Reward   -274.8 | Queue   34
# Step  623 | Reward   -328.8 | Queue   40
# Step  624 | Reward   -332.4 | Queue   40
# Step  625 | Reward   -343.8 | Queue   42
# Step  626 | Reward   -301.8 | Queue   37
# Step  627 | Reward   -297.0 | Queue   36
# Step  628 | Reward   -309.0 | Queue   37
# Step  629 | Reward   -302.4 | Queue   36
# Step  630 | Reward   -398.4 | Queue   47
# Step  631 | Reward   -393.6 | Queue   46
# Step  632 | Reward   -327.0 | Queue   37
# Step  633 | Reward   -284.4 | Queue   33
# Step  634 | Reward   -289.2 | Queue   34
# Step  635 | Reward   -325.8 | Queue   39
# Step  636 | Reward   -314.4 | Queue   37
# Step  637 | Reward   -265.8 | Queue   31
# Step  638 | Reward   -294.0 | Queue   35
# Step  639 | Reward   -310.8 | Queue   37
# Step  640 | Reward   -322.2 | Queue   39
# Step  641 | Reward   -324.0 | Queue   39
# Step  642 | Reward   -325.8 | Queue   39
# Step  643 | Reward   -319.2 | Queue   38
# Step  644 | Reward   -313.8 | Queue   38
# Step  645 | Reward   -269.4 | Queue   34
# Step  646 | Reward   -280.2 | Queue   34
# Step  647 | Reward   -217.8 | Queue   27
# Step  648 | Reward   -240.0 | Queue   29
# Step  649 | Reward   -271.8 | Queue   33
# Step  650 | Reward   -250.2 | Queue   30
# Step  651 | Reward   -199.8 | Queue   24
# Step  652 | Reward   -205.8 | Queue   26
# Step  653 | Reward   -243.6 | Queue   29
# Step  654 | Reward   -262.2 | Queue   31
# Step  655 | Reward   -297.0 | Queue   36
# Step  656 | Reward   -301.8 | Queue   37
# Step  657 | Reward   -348.6 | Queue   43
# Step  658 | Reward   -291.6 | Queue   36
# Step  659 | Reward   -305.4 | Queue   37
# Step  660 | Reward   -349.2 | Queue   42
# Step  661 | Reward   -309.0 | Queue   37
# Step  662 | Reward   -320.4 | Queue   39
# Step  663 | Reward   -327.6 | Queue   39
# Step  664 | Reward   -339.6 | Queue   40
# Step  665 | Reward   -326.4 | Queue   38
# Step  666 | Reward   -252.0 | Queue   30
# Step  667 | Reward   -266.4 | Queue   33
# Step  668 | Reward   -278.4 | Queue   34
# Step  669 | Reward   -265.2 | Queue   32
# Step  670 | Reward   -329.4 | Queue   39
# Step  671 | Reward   -290.4 | Queue   35
# Step  672 | Reward   -256.2 | Queue   32
# Step  673 | Reward   -257.4 | Queue   33
# Step  674 | Reward   -278.4 | Queue   34
# Step  675 | Reward   -297.0 | Queue   36
# Step  676 | Reward   -327.0 | Queue   40
# Step  677 | Reward   -290.4 | Queue   35
# Step  678 | Reward   -354.6 | Queue   42
# Step  679 | Reward   -366.6 | Queue   43
# Step  680 | Reward   -376.2 | Queue   45
# Step  681 | Reward   -411.6 | Queue   49
# Step  682 | Reward   -416.4 | Queue   50
# Step  683 | Reward   -426.6 | Queue   51
# Step  684 | Reward   -434.4 | Queue   50
# Step  685 | Reward   -445.8 | Queue   52
# Step  686 | Reward   -403.8 | Queue   47
# Step  687 | Reward   -369.0 | Queue   42
# Step  688 | Reward   -347.4 | Queue   39
# Step  689 | Reward   -364.2 | Queue   41
# Step  690 | Reward   -365.4 | Queue   42
# Step  691 | Reward   -366.6 | Queue   43
# Step  692 | Reward   -367.8 | Queue   44
# Step  693 | Reward   -342.6 | Queue   41
# Step  694 | Reward   -332.4 | Queue   40
# Step  695 | Reward   -308.4 | Queue   38
# Step  696 | Reward   -303.6 | Queue   37
# Step  697 | Reward   -290.4 | Queue   35
# Step  698 | Reward   -313.8 | Queue   38
# Step  699 | Reward   -301.8 | Queue   37
# Step  700 | Reward   -364.8 | Queue   46
# Step  701 | Reward   -303.0 | Queue   38
# Step  702 | Reward   -301.8 | Queue   37
# Step  703 | Reward   -315.0 | Queue   39
# Step  704 | Reward   -262.8 | Queue   33
# Step  705 | Reward   -221.4 | Queue   27
# Step  706 | Reward   -248.4 | Queue   30
# Step  707 | Reward   -262.2 | Queue   31
# Step  708 | Reward   -240.0 | Queue   29
# Step  709 | Reward   -251.4 | Queue   31
# Step  710 | Reward   -253.2 | Queue   31
# Step  711 | Reward   -253.2 | Queue   31
# Step  712 | Reward   -220.2 | Queue   26
# Step  713 | Reward   -233.4 | Queue   28
# Step  714 | Reward   -243.0 | Queue   30
# Step  715 | Reward   -354.6 | Queue   45
# Step  716 | Reward   -349.2 | Queue   45
# Step  717 | Reward   -310.8 | Queue   40
# Step  718 | Reward   -222.6 | Queue   28
# Step  719 | Reward   -209.4 | Queue   26
# Step  720 | Reward   -197.4 | Queue   25
# Step  721 | Reward   -259.8 | Queue   32
# Step  722 | Reward   -330.0 | Queue   41
# Step  723 | Reward   -298.2 | Queue   37
# Step  724 | Reward   -342.0 | Queue   42
# Step  725 | Reward   -281.4 | Queue   35
# Step  726 | Reward   -313.2 | Queue   39
# Step  727 | Reward   -356.4 | Queue   45
# Step  728 | Reward   -327.6 | Queue   39
# Step  729 | Reward   -403.2 | Queue   48
# Step  730 | Reward   -280.8 | Queue   33
# Step  731 | Reward   -289.8 | Queue   33
# Step  732 | Reward   -265.8 | Queue   31
# Step  733 | Reward   -238.8 | Queue   28
# Step  734 | Reward   -240.6 | Queue   28
# Step  735 | Reward   -233.4 | Queue   28
# Step  736 | Reward   -298.8 | Queue   36
# Step  737 | Reward   -357.0 | Queue   44
# Step  738 | Reward   -350.4 | Queue   43
# Step  739 | Reward   -325.2 | Queue   40
# Step  740 | Reward   -338.4 | Queue   42
# Step  741 | Reward   -258.0 | Queue   32
# Step  742 | Reward   -293.4 | Queue   36
# Step  743 | Reward   -246.6 | Queue   30
# Step  744 | Reward   -315.6 | Queue   38
# Step  745 | Reward   -388.2 | Queue   46
# Step  746 | Reward   -381.0 | Queue   46
# Step  747 | Reward   -357.6 | Queue   43
# Step  748 | Reward   -366.0 | Queue   44
# Step  749 | Reward   -308.4 | Queue   38
# Step  750 | Reward   -310.2 | Queue   38
# Step  751 | Reward   -322.2 | Queue   39
# Step  752 | Reward   -396.6 | Queue   47
# Step  753 | Reward   -390.0 | Queue   46
# Step  754 | Reward   -430.8 | Queue   50
# Step  755 | Reward   -456.0 | Queue   53
# Step  756 | Reward   -416.4 | Queue   50
# Step  757 | Reward   -394.2 | Queue   48
# Step  758 | Reward   -434.4 | Queue   53
# Step  759 | Reward   -462.6 | Queue   57
# Step  760 | Reward   -456.0 | Queue   56
# Step  761 | Reward   -452.4 | Queue   56
# Step  762 | Reward   -466.2 | Queue   57
# Step  763 | Reward   -446.4 | Queue   54
# Step  764 | Reward   -446.4 | Queue   54
# Step  765 | Reward   -435.0 | Queue   52
# Step  766 | Reward   -402.6 | Queue   49
# Step  767 | Reward   -406.2 | Queue   49
# Step  768 | Reward   -435.0 | Queue   52
# Step  769 | Reward   -435.6 | Queue   51
# Step  770 | Reward   -379.8 | Queue   45
# Step  771 | Reward   -349.2 | Queue   42
# Step  772 | Reward   -322.2 | Queue   39
# Step  773 | Reward   -322.8 | Queue   38
# Step  774 | Reward   -360.6 | Queue   41
# Step  775 | Reward   -389.4 | Queue   44
# Step  776 | Reward   -367.2 | Queue   42
# Step  777 | Reward   -380.4 | Queue   44
# Step  778 | Reward   -368.4 | Queue   43
# Step  779 | Reward   -369.6 | Queue   44
# Step  780 | Reward   -405.0 | Queue   48
# Step  781 | Reward   -371.4 | Queue   44
# Step  782 | Reward   -336.0 | Queue   40
# Step  783 | Reward   -361.8 | Queue   42
# Step  784 | Reward   -305.4 | Queue   37
# Step  785 | Reward   -321.0 | Queue   38
# Step  786 | Reward   -369.0 | Queue   45
# Step  787 | Reward   -383.4 | Queue   48
# Step  788 | Reward   -342.0 | Queue   42
# Step  789 | Reward   -337.2 | Queue   41
# Step  790 | Reward   -406.2 | Queue   49
# Step  791 | Reward   -441.6 | Queue   53
# Step  792 | Reward   -428.4 | Queue   51
# Step  793 | Reward   -376.2 | Queue   45
# Step  794 | Reward   -336.0 | Queue   40
# Step  795 | Reward   -376.2 | Queue   45
# Step  796 | Reward   -360.6 | Queue   44
# Step  797 | Reward   -393.0 | Queue   47
# Step  798 | Reward   -305.4 | Queue   37
# Step  799 | Reward   -282.0 | Queue   34
# Step  800 | Reward   -331.2 | Queue   39
# Step  801 | Reward   -419.4 | Queue   48
# Step  802 | Reward   -420.6 | Queue   49
# Step  803 | Reward   -449.4 | Queue   52
# Step  804 | Reward   -528.6 | Queue   61
# Step  805 | Reward   -486.0 | Queue   57
# Step  806 | Reward   -558.6 | Queue   65
# Step  807 | Reward   -597.6 | Queue   69
# Step  808 | Reward   -579.0 | Queue   67
# Step  809 | Reward   -553.2 | Queue   65
# Step  810 | Reward   -489.0 | Queue   58
# Step  811 | Reward   -492.0 | Queue   59
# Step  812 | Reward   -460.2 | Queue   55
# Step  813 | Reward   -477.0 | Queue   57
# Step  814 | Reward   -444.0 | Queue   52
# Step  815 | Reward   -462.0 | Queue   55
# Step  816 | Reward   -406.2 | Queue   49
# Step  817 | Reward   -385.8 | Queue   47
# Step  818 | Reward   -331.8 | Queue   41
# Step  819 | Reward   -365.4 | Queue   45
# Step  820 | Reward   -392.4 | Queue   48
# Step  821 | Reward   -471.6 | Queue   57
# Step  822 | Reward   -454.8 | Queue   55
# Step  823 | Reward   -462.6 | Queue   57
# Step  824 | Reward   -438.0 | Queue   53
# Step  825 | Reward   -503.4 | Queue   61
# Step  826 | Reward   -491.4 | Queue   60
# Step  827 | Reward   -421.2 | Queue   51
# Step  828 | Reward   -434.4 | Queue   53
# Step  829 | Reward   -405.6 | Queue   50
# Step  830 | Reward   -399.6 | Queue   48
# Step  831 | Reward   -382.8 | Queue   46
# Step  832 | Reward   -375.0 | Queue   44
# Step  833 | Reward   -386.4 | Queue   46
# Step  834 | Reward   -309.0 | Queue   37
# Step  835 | Reward   -290.4 | Queue   35
# Step  836 | Reward   -251.4 | Queue   31
# Step  837 | Reward   -247.8 | Queue   31
# Step  838 | Reward   -284.4 | Queue   36
# Step  839 | Reward   -330.6 | Queue   40
# Step  840 | Reward   -364.2 | Queue   44
# Step  841 | Reward   -348.0 | Queue   41
# Step  842 | Reward   -378.6 | Queue   44
# Step  843 | Reward   -405.0 | Queue   48
# Step  844 | Reward   -428.4 | Queue   51
# Step  845 | Reward   -441.6 | Queue   53
# Step  846 | Reward   -428.4 | Queue   51
# Step  847 | Reward   -450.0 | Queue   54
# Step  848 | Reward   -418.2 | Queue   50
# Step  849 | Reward   -384.6 | Queue   46
# Step  850 | Reward   -441.6 | Queue   53
# Step  851 | Reward   -450.0 | Queue   54
# Step  852 | Reward   -457.2 | Queue   54
# Step  853 | Reward   -428.4 | Queue   51
# Step  854 | Reward   -376.2 | Queue   45
# Step  855 | Reward   -420.6 | Queue   49
# Step  856 | Reward   -454.2 | Queue   53
# Step  857 | Reward   -468.0 | Queue   54
# Step  858 | Reward   -446.4 | Queue   51
# Step  859 | Reward   -495.6 | Queue   56
# Step  860 | Reward   -487.2 | Queue   55
# Step  861 | Reward   -489.0 | Queue   55
# Step  862 | Reward   -547.2 | Queue   63
# Step  863 | Reward   -557.4 | Queue   64
# Step  864 | Reward   -511.8 | Queue   59
# Step  865 | Reward   -546.0 | Queue   62
# Step  866 | Reward   -555.6 | Queue   64
# Step  867 | Reward   -531.6 | Queue   62
# Step  868 | Reward   -496.2 | Queue   58
# Step  869 | Reward   -460.2 | Queue   55
# Step  870 | Reward   -488.4 | Queue   59
# Step  871 | Reward   -527.4 | Queue   63
# Step  872 | Reward   -546.0 | Queue   65
# Step  873 | Reward   -424.8 | Queue   51
# Step  874 | Reward   -413.4 | Queue   49
# Step  875 | Reward   -441.6 | Queue   53
# Step  876 | Reward   -403.8 | Queue   50
# Step  877 | Reward   -435.6 | Queue   54
# Step  878 | Reward   -411.0 | Queue   50
# Step  879 | Reward   -460.2 | Queue   55
# Step  880 | Reward   -426.6 | Queue   51
# Step  881 | Reward   -483.6 | Queue   58
# Step  882 | Reward   -483.6 | Queue   58
# Step  883 | Reward   -505.2 | Queue   61
# Step  884 | Reward   -534.0 | Queue   64
# Step  885 | Reward   -578.4 | Queue   68
# Step  886 | Reward   -522.0 | Queue   60
# Step  887 | Reward   -468.0 | Queue   54
# Step  888 | Reward   -445.8 | Queue   52
# Step  889 | Reward   -447.0 | Queue   53
# Step  890 | Reward   -513.0 | Queue   60
# Step  891 | Reward   -565.2 | Queue   66
# Step  892 | Reward   -538.8 | Queue   62
# Step  893 | Reward   -493.2 | Queue   57
# Step  894 | Reward   -528.0 | Queue   62
# Step  895 | Reward   -427.2 | Queue   50
# Step  896 | Reward   -379.8 | Queue   45
# Step  897 | Reward   -420.0 | Queue   50
# Step  898 | Reward   -415.2 | Queue   49
# Step  899 | Reward   -481.2 | Queue   56
# Step  900 | Reward   -427.2 | Queue   50
# Step  901 | Reward   -465.6 | Queue   55
# Step  902 | Reward   -465.6 | Queue   55
# Step  903 | Reward   -446.4 | Queue   54
# Step  904 | Reward   -442.8 | Queue   54
# Step  905 | Reward   -439.8 | Queue   53
# Step  906 | Reward   -396.0 | Queue   48
# Step  907 | Reward   -399.6 | Queue   48
# Step  908 | Reward   -400.2 | Queue   47
# Step  909 | Reward   -491.4 | Queue   57
# Step  910 | Reward   -472.8 | Queue   55
# Step  911 | Reward   -445.2 | Queue   53
# Step  912 | Reward   -421.2 | Queue   51
# Step  913 | Reward   -374.4 | Queue   45
# Step  914 | Reward   -411.0 | Queue   50
# Step  915 | Reward   -431.4 | Queue   52
# Step  916 | Reward   -417.0 | Queue   49
# Step  917 | Reward   -349.8 | Queue   41
# Step  918 | Reward   -378.0 | Queue   45
# Step  919 | Reward   -351.0 | Queue   42
# Step  920 | Reward   -397.8 | Queue   48
# Step  921 | Reward   -407.4 | Queue   50
# Step  922 | Reward   -400.8 | Queue   49
# Step  923 | Reward   -366.6 | Queue   46
# Step  924 | Reward   -395.4 | Queue   49
# Step  925 | Reward   -403.8 | Queue   50
# Step  926 | Reward   -420.6 | Queue   52
# Step  927 | Reward   -403.8 | Queue   50
# Step  928 | Reward   -423.6 | Queue   53
# Step  929 | Reward   -436.2 | Queue   53
# Step  930 | Reward   -392.4 | Queue   48
# Step  931 | Reward   -453.0 | Queue   55
# Step  932 | Reward   -486.0 | Queue   60
# Step  933 | Reward   -466.2 | Queue   57
# Step  934 | Reward   -358.2 | Queue   45
# Step  935 | Reward   -379.8 | Queue   48
# Step  936 | Reward   -346.2 | Queue   44
# Step  937 | Reward   -307.2 | Queue   40
# Step  938 | Reward   -312.6 | Queue   40
# Step  939 | Reward   -289.2 | Queue   37
# Step  940 | Reward   -260.4 | Queue   34
# Step  941 | Reward   -292.8 | Queue   37
# Step  942 | Reward   -308.4 | Queue   38
# Step  943 | Reward   -309.0 | Queue   37
# Step  944 | Reward   -394.8 | Queue   47
# Step  945 | Reward   -469.8 | Queue   57
# Step  946 | Reward   -491.4 | Queue   60
# Step  947 | Reward   -501.0 | Queue   62
# Step  948 | Reward   -452.4 | Queue   56
# Step  949 | Reward   -459.0 | Queue   57
# Step  950 | Reward   -481.2 | Queue   59
# Step  951 | Reward   -403.8 | Queue   50
# Step  952 | Reward   -432.6 | Queue   53
# Step  953 | Reward   -450.6 | Queue   56
# Step  954 | Reward   -436.8 | Queue   55
# Step  955 | Reward   -386.4 | Queue   49
# Step  956 | Reward   -385.2 | Queue   48
# Step  957 | Reward   -400.2 | Queue   50
# Step  958 | Reward   -420.6 | Queue   52
# Step  959 | Reward   -377.4 | Queue   46
# Step  960 | Reward   -337.2 | Queue   41
# Step  961 | Reward   -360.0 | Queue   45
# Step  962 | Reward   -369.0 | Queue   45
# Step  963 | Reward   -449.4 | Queue   55
# Step  964 | Reward   -465.6 | Queue   58
# Step  965 | Reward   -361.2 | Queue   46
# Step  966 | Reward   -361.8 | Queue   45
# Step  967 | Reward   -321.6 | Queue   40
# Step  968 | Reward   -355.2 | Queue   44
# Step  969 | Reward   -405.6 | Queue   50
# Step  970 | Reward   -486.0 | Queue   60
# Step  971 | Reward   -472.2 | Queue   59
# Step  972 | Reward   -460.8 | Queue   57
# Step  973 | Reward   -453.0 | Queue   55
# Step  974 | Reward   -465.0 | Queue   56
# Step  975 | Reward   -443.4 | Queue   53
# Step  976 | Reward   -408.0 | Queue   49
# Step  977 | Reward   -352.2 | Queue   43
# Step  978 | Reward   -301.8 | Queue   37
# Step  979 | Reward   -319.2 | Queue   38
# Step  980 | Reward   -364.2 | Queue   44
# Step  981 | Reward   -362.4 | Queue   44
# Step  982 | Reward   -343.8 | Queue   42
# Step  983 | Reward   -259.8 | Queue   32
# Step  984 | Reward   -285.0 | Queue   35
# Step  985 | Reward   -367.8 | Queue   44
# Step  986 | Reward   -348.6 | Queue   43
# Step  987 | Reward   -316.2 | Queue   40
# Step  988 | Reward   -306.6 | Queue   38
# Step  989 | Reward   -372.6 | Queue   45
# Step  990 | Reward   -412.8 | Queue   50
# Step  991 | Reward   -402.6 | Queue   49
# Step  992 | Reward   -395.4 | Queue   49
# Step  993 | Reward   -407.4 | Queue   50
# Step  994 | Reward   -431.4 | Queue   52
# Step  995 | Reward   -439.8 | Queue   53
# Step  996 | Reward   -409.2 | Queue   50
# Step  997 | Reward   -345.0 | Queue   43
# Step  998 | Reward   -334.8 | Queue   42
# Step  999 | Reward   -341.4 | Queue   43
# Env signaled done at step 999
#
# ===== Dueling GAT-DQN Evaluation =====
# Total steps executed       : 999
# Total reward accumulated   : -294144.0
# Vehicles completed routes  : 2545
# Active vehicles remaining  : 570
# Avg waiting time per car   : 14.20 s
# Avg travel time (all)      : 157.20 s
